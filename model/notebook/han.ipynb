# %%
from __future__ import print_function, division
import matplotlib.pyplot as plt
import time
import copy
from typing import OrderedDict

import os
import sys
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torch.nn import ReLU
import pandas as pd
from torch_geometric.data import HeteroData
import torch.nn.functional as F
from torch_geometric.nn import GATConv,HGTConv, GCNConv, HANConv, SAGEConv
from torch_geometric.nn import Linear, to_hetero, Sequential
from torch_geometric.loader import NeighborLoader, HGTLoader
sys.path.append('..')
from collect_data.preprocessing.preprocess_refactor import Path
from graph_test import get_data

os.environ['CUDA_VISIBLE_DEVICES'] = '5'
device = torch.device("cuda:5" if torch.cuda.is_available() else "cpu")
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# cuda:5

# %%
data = get_data()
data
# Out:
# HeteroData(
#   spot={
#     train_mask=[5385],
#     valid_mask=[5385],
#     test_mask=[5385],
#     y=[5385],
#     x=[5385, 512]
#   },
#   word={ x=[27262, 300] },
#   (spot, relate, word)={ edge_index=[2, 53850] },
#   (word, revrelate, spot)={ edge_index=[2, 53850] }
# )

# %%
import inspect
import os
import os.path as osp
import re
from collections import OrderedDict
from inspect import Parameter
from itertools import chain
from typing import Callable, List, Optional, Set, get_type_hints
from uuid import uuid1

import torch
from jinja2 import Template
from torch import Tensor
from torch.utils.hooks import RemovableHandle
from torch_scatter import gather_csr, scatter, segment_csr
from torch_sparse import SparseTensor

from torch_geometric.typing import Adj, Size

from torch_geometric.nn.conv.utils.helpers import expand_left
from torch_geometric.nn.conv.utils.inspector import Inspector, func_body_repr, func_header_repr
from torch_geometric.nn.conv.utils.jit import class_from_module_repr
from torch_geometric.nn.conv.utils.typing import (parse_types, resolve_types, sanitize,
                           split_types_repr)


class MessagePassingMy(torch.nn.Module):
    r"""Base class for creating message passing layers of the form

    .. math::
        \mathbf{x}_i^{\prime} = \gamma_{\mathbf{\Theta}} \left( \mathbf{x}_i,
        \square_{j \in \mathcal{N}(i)} \, \phi_{\mathbf{\Theta}}
        \left(\mathbf{x}_i, \mathbf{x}_j,\mathbf{e}_{j,i}\right) \right),

    where :math:`\square` denotes a differentiable, permutation invariant
    function, *e.g.*, sum, mean, min, max or mul, and
    :math:`\gamma_{\mathbf{\Theta}}` and :math:`\phi_{\mathbf{\Theta}}` denote
    differentiable functions such as MLPs.
    See `here <https://pytorch-geometric.readthedocs.io/en/latest/notes/
    create_gnn.html>`__ for the accompanying tutorial.

    Args:
        aggr (string, optional): The aggregation scheme to use
            (:obj:`"add"`, :obj:`"mean"`, :obj:`"min"`, :obj:`"max"`,
            :obj:`"mul"` or :obj:`None`). (default: :obj:`"add"`)
        flow (string, optional): The flow direction of message passing
            (:obj:`"source_to_target"` or :obj:`"target_to_source"`).
            (default: :obj:`"source_to_target"`)
        node_dim (int, optional): The axis along which to propagate.
            (default: :obj:`-2`)
        decomposed_layers (int, optional): The number of feature decomposition
            layers, as introduced in the `"Optimizing Memory Efficiency of
            Graph Neural Networks on Edge Computing Platforms"
            <https://arxiv.org/abs/2104.03058>`_ paper.
            Feature decomposition reduces the peak memory usage by slicing
            the feature dimensions into separated feature decomposition layers
            during GNN aggregation.
            This method can accelerate GNN execution on CPU-based platforms
            (*e.g.*, 2-3x speedup on the
            :class:`~torch_geometric.datasets.Reddit` dataset) for common GNN
            models such as :class:`~torch_geometric.nn.models.GCN`,
            :class:`~torch_geometric.nn.models.GraphSAGE`,
            :class:`~torch_geometric.nn.models.GIN`, etc.
            However, this method is not applicable to all GNN operators
            available, in particular for operators in which message computation
            can not easily be decomposed, *e.g.* in attention-based GNNs.
            The selection of the optimal value of :obj:`decomposed_layers`
            depends both on the specific graph dataset and available hardware
            resources.
            A value of :obj:`2` is suitable in most cases.
            Although the peak memory usage is directly associated with the
            granularity of feature decomposition, the same is not necessarily
            true for execution speedups. (default: :obj:`1`)
    """

    special_args: Set[str] = {
        'edge_index', 'adj_t', 'edge_index_i', 'edge_index_j', 'size',
        'size_i', 'size_j', 'ptr', 'index', 'dim_size'
    }

    def __init__(self, aggr: Optional[str] = "add",
                 flow: str = "source_to_target", node_dim: int = -2,
                 decomposed_layers: int = 1):

        super().__init__()

        self.aggr = aggr
        assert self.aggr in ['add', 'sum', 'mean', 'min', 'max', 'mul', None]

        self.flow = flow
        assert self.flow in ['source_to_target', 'target_to_source']

        self.node_dim = node_dim
        self.decomposed_layers = decomposed_layers

        self.inspector = Inspector(self)
        self.inspector.inspect(self.message)
        self.inspector.inspect(self.aggregate, pop_first=True)
        self.inspector.inspect(self.message_and_aggregate, pop_first=True)
        self.inspector.inspect(self.update, pop_first=True)
        self.inspector.inspect(self.edge_update)

        self.__user_args__ = self.inspector.keys(
            ['message', 'aggregate', 'update']).difference(self.special_args)
        self.__fused_user_args__ = self.inspector.keys(
            ['message_and_aggregate', 'update']).difference(self.special_args)
        self.__edge_user_args__ = self.inspector.keys(
            ['edge_update']).difference(self.special_args)

        # Support for "fused" message passing.
        self.fuse = self.inspector.implements('message_and_aggregate')

        # Support for GNNExplainer.
        self._explain = False
        self._edge_mask = None
        self._loop_mask = None
        self._apply_sigmoid = True

        # Hooks:
        self._propagate_forward_pre_hooks = OrderedDict()
        self._propagate_forward_hooks = OrderedDict()
        self._message_forward_pre_hooks = OrderedDict()
        self._message_forward_hooks = OrderedDict()
        self._aggregate_forward_pre_hooks = OrderedDict()
        self._aggregate_forward_hooks = OrderedDict()
        self._message_and_aggregate_forward_pre_hooks = OrderedDict()
        self._message_and_aggregate_forward_hooks = OrderedDict()
        self._edge_update_forward_pre_hooks = OrderedDict()
        self._edge_update_forward_hooks = OrderedDict()

    def __check_input__(self, edge_index, size):
        the_size: List[Optional[int]] = [None, None]

        if isinstance(edge_index, Tensor):
            assert edge_index.dtype == torch.long
            assert edge_index.dim() == 2
            assert edge_index.size(0) == 2
            if size is not None:
                the_size[0] = size[0]
                the_size[1] = size[1]
            return the_size

        elif isinstance(edge_index, SparseTensor):
            if self.flow == 'target_to_source':
                raise ValueError(
                    ('Flow direction "target_to_source" is invalid for '
                     'message propagation via `torch_sparse.SparseTensor`. If '
                     'you really want to make use of a reverse message '
                     'passing flow, pass in the transposed sparse tensor to '
                     'the message passing module, e.g., `adj_t.t()`.'))
            the_size[0] = edge_index.sparse_size(1)
            the_size[1] = edge_index.sparse_size(0)
            return the_size

        raise ValueError(
            ('`MessagePassing.propagate` only supports `torch.LongTensor` of '
             'shape `[2, num_messages]` or `torch_sparse.SparseTensor` for '
             'argument `edge_index`.'))

    def __set_size__(self, size: List[Optional[int]], dim: int, src: Tensor):
        the_size = size[dim]
        if the_size is None:
            size[dim] = src.size(self.node_dim)
        elif the_size != src.size(self.node_dim):
            raise ValueError(
                (f'Encountered tensor with size {src.size(self.node_dim)} in '
                 f'dimension {self.node_dim}, but expected size {the_size}.'))

    def __lift__(self, src, edge_index, dim):
        if isinstance(edge_index, Tensor):
            index = edge_index[dim]
            return src.index_select(self.node_dim, index)
        elif isinstance(edge_index, SparseTensor):
            if dim == 1:
                rowptr = edge_index.storage.rowptr()
                rowptr = expand_left(rowptr, dim=self.node_dim, dims=src.dim())
                return gather_csr(src, rowptr)
            elif dim == 0:
                col = edge_index.storage.col()
                return src.index_select(self.node_dim, col)
        raise ValueError

    def __collect__(self, args, edge_index, size, kwargs):
        i, j = (1, 0) if self.flow == 'source_to_target' else (0, 1)

        out = {}
        for arg in args:
            if arg[-2:] not in ['_i', '_j']:
                out[arg] = kwargs.get(arg, Parameter.empty)
            else:
                dim = j if arg[-2:] == '_j' else i
                data = kwargs.get(arg[:-2], Parameter.empty)

                if isinstance(data, (tuple, list)):
                    assert len(data) == 2
                    if isinstance(data[1 - dim], Tensor):
                        self.__set_size__(size, 1 - dim, data[1 - dim])
                    data = data[dim]

                if isinstance(data, Tensor):
                    self.__set_size__(size, dim, data)
                    data = self.__lift__(data, edge_index, dim)

                out[arg] = data

        if isinstance(edge_index, Tensor):
            out['adj_t'] = None
            out['edge_index'] = edge_index
            out['edge_index_i'] = edge_index[i]
            out['edge_index_j'] = edge_index[j]
            out['ptr'] = None
        elif isinstance(edge_index, SparseTensor):
            out['adj_t'] = edge_index
            out['edge_index'] = None
            out['edge_index_i'] = edge_index.storage.row()
            out['edge_index_j'] = edge_index.storage.col()
            out['ptr'] = edge_index.storage.rowptr()
            if out.get('edge_weight', None) is None:
                out['edge_weight'] = edge_index.storage.value()
            if out.get('edge_attr', None) is None:
                out['edge_attr'] = edge_index.storage.value()
            if out.get('edge_type', None) is None:
                out['edge_type'] = edge_index.storage.value()

        out['index'] = out['edge_index_i']
        out['size'] = size
        out['size_i'] = size[1] if size[1] is not None else size[0]
        out['size_j'] = size[0] if size[0] is not None else size[1]
        out['dim_size'] = out['size_i']

        return out

    def propagate(self, edge_index: Adj, size: Size = None, **kwargs):
        r"""The initial call to start propagating messages.

        Args:
            edge_index (Tensor or SparseTensor): A :obj:`torch.LongTensor` or a
                :obj:`torch_sparse.SparseTensor` that defines the underlying
                graph connectivity/message passing flow.
                :obj:`edge_index` holds the indices of a general (sparse)
                assignment matrix of shape :obj:`[N, M]`.
                If :obj:`edge_index` is of type :obj:`torch.LongTensor`, its
                shape must be defined as :obj:`[2, num_messages]`, where
                messages from nodes in :obj:`edge_index[0]` are sent to
                nodes in :obj:`edge_index[1]`
                (in case :obj:`flow="source_to_target"`).
                If :obj:`edge_index` is of type
                :obj:`torch_sparse.SparseTensor`, its sparse indices
                :obj:`(row, col)` should relate to :obj:`row = edge_index[1]`
                and :obj:`col = edge_index[0]`.
                The major difference between both formats is that we need to
                input the *transposed* sparse adjacency matrix into
                :func:`propagate`.
            size (tuple, optional): The size :obj:`(N, M)` of the assignment
                matrix in case :obj:`edge_index` is a :obj:`LongTensor`.
                If set to :obj:`None`, the size will be automatically inferred
                and assumed to be quadratic.
                This argument is ignored in case :obj:`edge_index` is a
                :obj:`torch_sparse.SparseTensor`. (default: :obj:`None`)
            **kwargs: Any additional data which is needed to construct and
                aggregate messages, and to update node embeddings.
        """
        decomposed_layers = 1 if self._explain else self.decomposed_layers

        for hook in self._propagate_forward_pre_hooks.values():
            res = hook(self, (edge_index, size, kwargs))
            if res is not None:
                edge_index, size, kwargs = res

        size = self.__check_input__(edge_index, size)

        # Run "fused" message and aggregation (if applicable).
        if (isinstance(edge_index, SparseTensor) and self.fuse
                and not self._explain):
            coll_dict = self.__collect__(self.__fused_user_args__, edge_index,
                                         size, kwargs)

            msg_aggr_kwargs = self.inspector.distribute(
                'message_and_aggregate', coll_dict)
            for hook in self._message_and_aggregate_forward_pre_hooks.values():
                res = hook(self, (edge_index, msg_aggr_kwargs))
                if res is not None:
                    edge_index, msg_aggr_kwargs = res
            out = self.message_and_aggregate(edge_index, **msg_aggr_kwargs)
            for hook in self._message_and_aggregate_forward_hooks.values():
                res = hook(self, (edge_index, msg_aggr_kwargs), out)
                if res is not None:
                    out = res

            update_kwargs = self.inspector.distribute('update', coll_dict)
            out = self.update(out, **update_kwargs)

        # Otherwise, run both functions in separation.
        elif isinstance(edge_index, Tensor) or not self.fuse:
            if decomposed_layers > 1:
                user_args = self.__user_args__
                decomp_args = {a[:-2] for a in user_args if a[-2:] == '_j'}
                decomp_kwargs = {
                    a: kwargs[a].chunk(decomposed_layers, -1)
                    for a in decomp_args
                }
                decomp_out = []

            for i in range(decomposed_layers):
                if decomposed_layers > 1:
                    for arg in decomp_args:
                        kwargs[arg] = decomp_kwargs[arg][i]

                coll_dict = self.__collect__(self.__user_args__, edge_index,
                                             size, kwargs)

                msg_kwargs = self.inspector.distribute('message', coll_dict)
                for hook in self._message_forward_pre_hooks.values():
                    res = hook(self, (msg_kwargs, ))
                    if res is not None:
                        msg_kwargs = res[0] if isinstance(res, tuple) else res
                out = self.message(**msg_kwargs)
                for hook in self._message_forward_hooks.values():
                    res = hook(self, (msg_kwargs, ), out)
                    if res is not None:
                        out = res

                # For `GNNExplainer`, we require a separate message and
                # aggregate procedure since this allows us to inject the
                # `edge_mask` into the message passing computation scheme.
                if self._explain:
                    edge_mask = self._edge_mask
                    if self._apply_sigmoid:
                        edge_mask = edge_mask.sigmoid()
                    # Some ops add self-loops to `edge_index`. We need to do
                    # the same for `edge_mask` (but do not train those).
                    if out.size(self.node_dim) != edge_mask.size(0):
                        edge_mask = edge_mask[self._loop_mask]
                        loop = edge_mask.new_ones(size[0])
                        edge_mask = torch.cat([edge_mask, loop], dim=0)
                    assert out.size(self.node_dim) == edge_mask.size(0)
                    out = out * edge_mask.view([-1] + [1] * (out.dim() - 1))

                aggr_kwargs = self.inspector.distribute('aggregate', coll_dict)
                for hook in self._aggregate_forward_pre_hooks.values():
                    res = hook(self, (aggr_kwargs, ))
                    if res is not None:
                        aggr_kwargs = res[0] if isinstance(res, tuple) else res
                out = self.aggregate(out, **aggr_kwargs)
                for hook in self._aggregate_forward_hooks.values():
                    res = hook(self, (aggr_kwargs, ), out)
                    if res is not None:
                        out = res

                update_kwargs = self.inspector.distribute('update', coll_dict)
                out = self.update(out, **update_kwargs)

                if decomposed_layers > 1:
                    decomp_out.append(out)

            if decomposed_layers > 1:
                out = torch.cat(decomp_out, dim=-1)

        for hook in self._propagate_forward_hooks.values():
            res = hook(self, (edge_index, size, kwargs), out)
            if res is not None:
                out = res

        return out

    def edge_updater(self, edge_index: Adj, **kwargs):
        r"""The initial call to compute or update features for each edge in the
        graph.

        Args:
            edge_index (Tensor or SparseTensor): A :obj:`torch.LongTensor` or a
                :obj:`torch_sparse.SparseTensor` that defines the underlying
                graph connectivity/message passing flow.
                See :meth:`propagate` for more information.
            **kwargs: Any additional data which is needed to compute or update
                features for each edge in the graph.
        """
        for hook in self._edge_update_forward_pre_hooks.values():
            res = hook(self, (edge_index, kwargs))
            if res is not None:
                edge_index, kwargs = res

        size = self.__check_input__(edge_index, size=None)

        coll_dict = self.__collect__(self.__edge_user_args__, edge_index, size,
                                     kwargs)

        edge_kwargs = self.inspector.distribute('edge_update', coll_dict)
        out = self.edge_update(**edge_kwargs)

        for hook in self._edge_update_forward_hooks.values():
            res = hook(self, (edge_index, kwargs), out)
            if res is not None:
                out = res

        return out

    def message(self, x_j: Tensor) -> Tensor:
        r"""Constructs messages from node :math:`j` to node :math:`i`
        in analogy to :math:`\phi_{\mathbf{\Theta}}` for each edge in
        :obj:`edge_index`.
        This function can take any argument as input which was initially
        passed to :meth:`propagate`.
        Furthermore, tensors passed to :meth:`propagate` can be mapped to the
        respective nodes :math:`i` and :math:`j` by appending :obj:`_i` or
        :obj:`_j` to the variable name, *.e.g.* :obj:`x_i` and :obj:`x_j`.
        """
        return x_j

    def aggregate(self, inputs: Tensor, index: Tensor,
                  ptr: Optional[Tensor] = None,
                  dim_size: Optional[int] = None) -> Tensor:
        r"""Aggregates messages from neighbors as
        :math:`\square_{j \in \mathcal{N}(i)}`.

        Takes in the output of message computation as first argument and any
        argument which was initially passed to :meth:`propagate`.

        By default, this function will delegate its call to scatter functions
        that support "add", "mean", "min", "max" and "mul" operations as
        specified in :meth:`__init__` by the :obj:`aggr` argument.
        """
        if ptr is not None:
            ptr = expand_left(ptr, dim=self.node_dim, dims=inputs.dim())
            return segment_csr(inputs, ptr, reduce=self.aggr)
        else:
            return scatter(inputs, index, dim=self.node_dim, dim_size=dim_size,
                           reduce=self.aggr)

    def message_and_aggregate(self, adj_t: SparseTensor) -> Tensor:
        r"""Fuses computations of :func:`message` and :func:`aggregate` into a
        single function.
        If applicable, this saves both time and memory since messages do not
        explicitly need to be materialized.
        This function will only gets called in case it is implemented and
        propagation takes place based on a :obj:`torch_sparse.SparseTensor`.
        """
        raise NotImplementedError

    def update(self, inputs: Tensor) -> Tensor:
        r"""Updates node embeddings in analogy to
        :math:`\gamma_{\mathbf{\Theta}}` for each node
        :math:`i \in \mathcal{V}`.
        Takes in the output of aggregation as first argument and any argument
        which was initially passed to :meth:`propagate`.
        """
        return inputs

    def edge_update(self) -> Tensor:
        r"""Computes or updates features for each edge in the graph.
        This function can take any argument as input which was initially passed
        to :meth:`edge_updater`.
        Furthermore, tensors passed to :meth:`edge_updater` can be mapped to
        the respective nodes :math:`i` and :math:`j` by appending :obj:`_i` or
        :obj:`_j` to the variable name, *.e.g.* :obj:`x_i` and :obj:`x_j`.
        """
        raise NotImplementedError

    def register_propagate_forward_pre_hook(self,
                                            hook: Callable) -> RemovableHandle:
        r"""Registers a forward pre-hook on the module.
        The hook will be called every time before :meth:`propagate` is invoked.
        It should have the following signature:

        .. code-block:: python

            hook(module, inputs) -> None or modified input

        The hook can modify the input.
        Input keyword arguments are passed to the hook as a dictionary in
        :obj:`inputs[-1]`.

        Returns a :class:`torch.utils.hooks.RemovableHandle` that can be used
        to remove the added hook by calling :obj:`handle.remove()`.
        """
        handle = RemovableHandle(self._propagate_forward_pre_hooks)
        self._propagate_forward_pre_hooks[handle.id] = hook
        return handle

    def register_propagate_forward_hook(self,
                                        hook: Callable) -> RemovableHandle:
        r"""Registers a forward hook on the module.
        The hook will be called every time after :meth:`propagate` has computed
        an output.
        It should have the following signature:

        .. code-block:: python

            hook(module, inputs, output) -> None or modified output

        The hook can modify the output.
        Input keyword arguments are passed to the hook as a dictionary in
        :obj:`inputs[-1]`.

        Returns a :class:`torch.utils.hooks.RemovableHandle` that can be used
        to remove the added hook by calling :obj:`handle.remove()`.
        """
        handle = RemovableHandle(self._propagate_forward_hooks)
        self._propagate_forward_hooks[handle.id] = hook
        return handle

    def register_message_forward_pre_hook(self,
                                          hook: Callable) -> RemovableHandle:
        r"""Registers a forward pre-hook on the module.
        The hook will be called every time before :meth:`message` is invoked.
        See :meth:`register_propagate_forward_pre_hook` for more information.
        """
        handle = RemovableHandle(self._message_forward_pre_hooks)
        self._message_forward_pre_hooks[handle.id] = hook
        return handle

    def register_message_forward_hook(self, hook: Callable) -> RemovableHandle:
        r"""Registers a forward hook on the module.
        The hook will be called every time after :meth:`message` has computed
        an output.
        See :meth:`register_propagate_forward_hook` for more information.
        """
        handle = RemovableHandle(self._message_forward_hooks)
        self._message_forward_hooks[handle.id] = hook
        return handle

    def register_aggregate_forward_pre_hook(self,
                                            hook: Callable) -> RemovableHandle:
        r"""Registers a forward pre-hook on the module.
        The hook will be called every time before :meth:`aggregate` is invoked.
        See :meth:`register_propagate_forward_pre_hook` for more information.
        """
        handle = RemovableHandle(self._aggregate_forward_pre_hooks)
        self._aggregate_forward_pre_hooks[handle.id] = hook
        return handle

    def register_aggregate_forward_hook(self,
                                        hook: Callable) -> RemovableHandle:
        r"""Registers a forward hook on the module.
        The hook will be called every time after :meth:`aggregate` has computed
        an output.
        See :meth:`register_propagate_forward_hook` for more information.
        """
        handle = RemovableHandle(self._aggregate_forward_hooks)
        self._aggregate_forward_hooks[handle.id] = hook
        return handle

    def register_message_and_aggregate_forward_pre_hook(
            self, hook: Callable) -> RemovableHandle:
        r"""Registers a forward pre-hook on the module.
        The hook will be called every time before :meth:`message_and_aggregate`
        is invoked.
        See :meth:`register_propagate_forward_pre_hook` for more information.
        """
        handle = RemovableHandle(self._message_and_aggregate_forward_pre_hooks)
        self._message_and_aggregate_forward_pre_hooks[handle.id] = hook
        return handle

    def register_message_and_aggregate_forward_hook(
            self, hook: Callable) -> RemovableHandle:
        r"""Registers a forward hook on the module.
        The hook will be called every time after :meth:`message_and_aggregate`
        has computed an output.
        See :meth:`register_propagate_forward_hook` for more information.
        """
        handle = RemovableHandle(self._message_and_aggregate_forward_hooks)
        self._message_and_aggregate_forward_hooks[handle.id] = hook
        return handle

    def register_edge_update_forward_pre_hook(
            self, hook: Callable) -> RemovableHandle:
        r"""Registers a forward pre-hook on the module.
        The hook will be called every time before :meth:`edge_update` is
        invoked. See :meth:`register_propagate_forward_pre_hook` for more
        information.
        """
        handle = RemovableHandle(self._edge_update_forward_pre_hooks)
        self._edge_update_forward_pre_hooks[handle.id] = hook
        return handle

    def register_edge_update_forward_hook(self,
                                          hook: Callable) -> RemovableHandle:
        r"""Registers a forward hook on the module.
        The hook will be called every time after :meth:`edge_update` has
        computed an output.
        See :meth:`register_propagate_forward_hook` for more information.
        """
        handle = RemovableHandle(self._edge_update_forward_hooks)
        self._edge_update_forward_hooks[handle.id] = hook
        return handle

    @torch.jit.unused
    def jittable(self, typing: Optional[str] = None):
        r"""Analyzes the :class:`MessagePassing` instance and produces a new
        jittable module.

        Args:
            typing (string, optional): If given, will generate a concrete
                instance with :meth:`forward` types based on :obj:`typing`,
                *e.g.*: :obj:`"(Tensor, Optional[Tensor]) -> Tensor"`.
        """
        source = inspect.getsource(self.__class__)

        # Find and parse `propagate()` types to format `{arg1: type1, ...}`.
        if hasattr(self, 'propagate_type'):
            prop_types = {
                k: sanitize(str(v))
                for k, v in self.propagate_type.items()
            }
        else:
            match = re.search(r'#\s*propagate_type:\s*\((.*)\)', source)
            if match is None:
                raise TypeError(
                    'TorchScript support requires the definition of the types '
                    'passed to `propagate()`. Please specificy them via\n\n'
                    'propagate_type = {"arg1": type1, "arg2": type2, ... }\n\n'
                    'or via\n\n'
                    '# propagate_type: (arg1: type1, arg2: type2, ...)\n\n'
                    'inside the `MessagePassing` module.')
            prop_types = split_types_repr(match.group(1))
            prop_types = dict([re.split(r'\s*:\s*', t) for t in prop_types])

        # Find and parse `edge_updater` types to format `{arg1: type1, ...}`.
        if 'edge_update' in self.__class__.__dict__.keys():
            if hasattr(self, 'edge_updater_type'):
                edge_updater_types = {
                    k: sanitize(str(v))
                    for k, v in self.edge_updater.items()
                }
            else:
                match = re.search(r'#\s*edge_updater_types:\s*\((.*)\)',
                                  source)
                if match is None:
                    raise TypeError(
                        'TorchScript support requires the definition of the '
                        'types passed to `edge_updater()`. Please specificy '
                        'them via\n\n edge_updater_types = {"arg1": type1, '
                        '"arg2": type2, ... }\n\n or via\n\n'
                        '# edge_updater_types: (arg1: type1, arg2: type2, ...)'
                        '\n\ninside the `MessagePassing` module.')
                edge_updater_types = split_types_repr(match.group(1))
                edge_updater_types = dict(
                    [re.split(r'\s*:\s*', t) for t in edge_updater_types])
        else:
            edge_updater_types = {}

        type_hints = get_type_hints(self.__class__.update)
        prop_return_type = type_hints.get('return', 'Tensor')
        if str(prop_return_type)[:6] == '<class':
            prop_return_type = prop_return_type.__name__

        type_hints = get_type_hints(self.__class__.edge_update)
        edge_updater_return_type = type_hints.get('return', 'Tensor')
        if str(edge_updater_return_type)[:6] == '<class':
            edge_updater_return_type = edge_updater_return_type.__name__

        # Parse `__collect__()` types to format `{arg:1, type1, ...}`.
        collect_types = self.inspector.types(
            ['message', 'aggregate', 'update'])

        # Parse `__collect__()` types to format `{arg:1, type1, ...}`,
        # specific to the argument used for edge updates.
        edge_collect_types = self.inspector.types(['edge_update'])

        # Collect `forward()` header, body and @overload types.
        forward_types = parse_types(self.forward)
        forward_types = [resolve_types(*types) for types in forward_types]
        forward_types = list(chain.from_iterable(forward_types))

        keep_annotation = len(forward_types) < 2
        forward_header = func_header_repr(self.forward, keep_annotation)
        forward_body = func_body_repr(self.forward, keep_annotation)

        if keep_annotation:
            forward_types = []
        elif typing is not None:
            forward_types = []
            forward_body = 8 * ' ' + f'# type: {typing}\n{forward_body}'

        root = os.path.dirname(osp.realpath(__file__))
        with open(osp.join(root, 'message_passing.jinja'), 'r') as f:
            template = Template(f.read())

        uid = uuid1().hex[:6]
        cls_name = f'{self.__class__.__name__}Jittable_{uid}'
        jit_module_repr = template.render(
            uid=uid,
            module=str(self.__class__.__module__),
            cls_name=cls_name,
            parent_cls_name=self.__class__.__name__,
            prop_types=prop_types,
            prop_return_type=prop_return_type,
            fuse=self.fuse,
            collect_types=collect_types,
            user_args=self.__user_args__,
            edge_user_args=self.__edge_user_args__,
            forward_header=forward_header,
            forward_types=forward_types,
            forward_body=forward_body,
            msg_args=self.inspector.keys(['message']),
            aggr_args=self.inspector.keys(['aggregate']),
            msg_and_aggr_args=self.inspector.keys(['message_and_aggregate']),
            update_args=self.inspector.keys(['update']),
            edge_collect_types=edge_collect_types,
            edge_update_args=self.inspector.keys(['edge_update']),
            edge_updater_types=edge_updater_types,
            edge_updater_return_type=edge_updater_return_type,
            check_input=inspect.getsource(self.__check_input__)[:-1],
            lift=inspect.getsource(self.__lift__)[:-1],
        )
        # Instantiate a class from the rendered JIT module representation.
        cls = class_from_module_repr(cls_name, jit_module_repr)
        module = cls.__new__(cls)
        module.__dict__ = self.__dict__.copy()
        module.jittable = None
        return module

    def __repr__(self) -> str:
        if hasattr(self, 'in_channels') and hasattr(self, 'out_channels'):
            return (f'{self.__class__.__name__}({self.in_channels}, '
                    f'{self.out_channels})')
        return f'{self.__class__.__name__}()'

# %%
from typing import Optional, Tuple, Union

import torch
import torch.nn.functional as F
from torch import Tensor
from torch.nn import Parameter
from torch_sparse import SparseTensor, set_diag

from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.dense.linear import Linear
from torch_geometric.typing import (Adj, NoneType, OptPairTensor, OptTensor,
                                    Size)
from torch_geometric.utils import add_self_loops, remove_self_loops, softmax

from torch_geometric.nn.inits import glorot, zeros


class GATConv(MessagePassing):
    r"""The graph attentional operator from the `"Graph Attention Networks"
    <https://arxiv.org/abs/1710.10903>`_ paper

    .. math::
        \mathbf{x}^{\prime}_i = \alpha_{i,i}\mathbf{\Theta}\mathbf{x}_{i} +
        \sum_{j \in \mathcal{N}(i)} \alpha_{i,j}\mathbf{\Theta}\mathbf{x}_{j},

    where the attention coefficients :math:`\alpha_{i,j}` are computed as

    .. math::
        \alpha_{i,j} =
        \frac{
        \exp\left(\mathrm{LeakyReLU}\left(\mathbf{a}^{\top}
        [\mathbf{\Theta}\mathbf{x}_i \, \Vert \, \mathbf{\Theta}\mathbf{x}_j]
        \right)\right)}
        {\sum_{k \in \mathcal{N}(i) \cup \{ i \}}
        \exp\left(\mathrm{LeakyReLU}\left(\mathbf{a}^{\top}
        [\mathbf{\Theta}\mathbf{x}_i \, \Vert \, \mathbf{\Theta}\mathbf{x}_k]
        \right)\right)}.

    If the graph has multi-dimensional edge features :math:`\mathbf{e}_{i,j}`,
    the attention coefficients :math:`\alpha_{i,j}` are computed as

    .. math::
        \alpha_{i,j} =
        \frac{
        \exp\left(\mathrm{LeakyReLU}\left(\mathbf{a}^{\top}
        [\mathbf{\Theta}\mathbf{x}_i \, \Vert \, \mathbf{\Theta}\mathbf{x}_j
        \, \Vert \, \mathbf{\Theta}_{e} \mathbf{e}_{i,j}]\right)\right)}
        {\sum_{k \in \mathcal{N}(i) \cup \{ i \}}
        \exp\left(\mathrm{LeakyReLU}\left(\mathbf{a}^{\top}
        [\mathbf{\Theta}\mathbf{x}_i \, \Vert \, \mathbf{\Theta}\mathbf{x}_k
        \, \Vert \, \mathbf{\Theta}_{e} \mathbf{e}_{i,k}]\right)\right)}.

    Args:
        in_channels (int or tuple): Size of each input sample, or :obj:`-1` to
            derive the size from the first input(s) to the forward method.
            A tuple corresponds to the sizes of source and target
            dimensionalities.
        out_channels (int): Size of each output sample.
        heads (int, optional): Number of multi-head-attentions.
            (default: :obj:`1`)
        concat (bool, optional): If set to :obj:`False`, the multi-head
            attentions are averaged instead of concatenated.
            (default: :obj:`True`)
        negative_slope (float, optional): LeakyReLU angle of the negative
            slope. (default: :obj:`0.2`)
        dropout (float, optional): Dropout probability of the normalized
            attention coefficients which exposes each node to a stochastically
            sampled neighborhood during training. (default: :obj:`0`)
        add_self_loops (bool, optional): If set to :obj:`False`, will not add
            self-loops to the input graph. (default: :obj:`True`)
        edge_dim (int, optional): Edge feature dimensionality (in case
            there are any). (default: :obj:`None`)
        fill_value (float or Tensor or str, optional): The way to generate
            edge features of self-loops (in case :obj:`edge_dim != None`).
            If given as :obj:`float` or :class:`torch.Tensor`, edge features of
            self-loops will be directly given by :obj:`fill_value`.
            If given as :obj:`str`, edge features of self-loops are computed by
            aggregating all features of edges that point to the specific node,
            according to a reduce operation. (:obj:`"add"`, :obj:`"mean"`,
            :obj:`"min"`, :obj:`"max"`, :obj:`"mul"`). (default: :obj:`"mean"`)
        bias (bool, optional): If set to :obj:`False`, the layer will not learn
            an additive bias. (default: :obj:`True`)
        **kwargs (optional): Additional arguments of
            :class:`torch_geometric.nn.conv.MessagePassing`.

    Shapes:
        - **input:**
          node features :math:`(|\mathcal{V}|, F_{in})` or
          :math:`((|\mathcal{V_s}|, F_{s}), (|\mathcal{V_t}|, F_{t}))`
          if bipartite,
          edge indices :math:`(2, |\mathcal{E}|)`,
          edge features :math:`(|\mathcal{E}|, D)` *(optional)*
        - **output:** node features :math:`(|\mathcal{V}|, H * F_{out})` or
          :math:`((|\mathcal{V}_t|, H * F_{out})` if bipartite.
          If :obj:`return_attention_weights=True`, then
          :math:`((|\mathcal{V}|, H * F_{out}),
          ((2, |\mathcal{E}|), (|\mathcal{E}|, H)))`
          or :math:`((|\mathcal{V_t}|, H * F_{out}), ((2, |\mathcal{E}|),
          (|\mathcal{E}|, H)))` if bipartite
    """
    _alpha: OptTensor

    def __init__(
        self,
        in_channels: Union[int, Tuple[int, int]],
        out_channels: int,
        heads: int = 1,
        concat: bool = True,
        negative_slope: float = 0.2,
        dropout: float = 0.0,
        add_self_loops: bool = True,
        edge_dim: Optional[int] = None,
        fill_value: Union[float, Tensor, str] = 'mean',
        bias: bool = True,
        **kwargs,
    ):
        kwargs.setdefault('aggr', 'add')
        super().__init__(node_dim=0, **kwargs)

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.heads = heads
        self.concat = concat
        self.negative_slope = negative_slope
        self.dropout = dropout
        self.add_self_loops = add_self_loops
        self.edge_dim = edge_dim
        self.fill_value = fill_value

        # In case we are operating in bipartite graphs, we apply separate
        # transformations 'lin_src' and 'lin_dst' to source and target nodes:
        if isinstance(in_channels, int):
            self.lin_src = Linear(in_channels, heads * out_channels,
                                  bias=False, weight_initializer='glorot')
            self.lin_dst = self.lin_src
        else:
            self.lin_src = Linear(in_channels[0], heads * out_channels, False,
                                  weight_initializer='glorot')
            self.lin_dst = Linear(in_channels[1], heads * out_channels, False,
                                  weight_initializer='glorot')

        # The learnable parameters to compute attention coefficients:
        self.att_src = Parameter(torch.Tensor(1, heads, out_channels))
        self.att_dst = Parameter(torch.Tensor(1, heads, out_channels))

        if edge_dim is not None:
            self.lin_edge = Linear(edge_dim, heads * out_channels, bias=False,
                                   weight_initializer='glorot')
            self.att_edge = Parameter(torch.Tensor(1, heads, out_channels))
        else:
            self.lin_edge = None
            self.register_parameter('att_edge', None)

        if bias and concat:
            self.bias = Parameter(torch.Tensor(heads * out_channels))
        elif bias and not concat:
            self.bias = Parameter(torch.Tensor(out_channels))
        else:
            self.register_parameter('bias', None)

        self._alpha = None

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_src.reset_parameters()
        self.lin_dst.reset_parameters()
        if self.lin_edge is not None:
            self.lin_edge.reset_parameters()
        glorot(self.att_src)
        glorot(self.att_dst)
        glorot(self.att_edge)
        zeros(self.bias)

    def forward(self, x: Union[Tensor, OptPairTensor], edge_index: Adj,
                edge_attr: OptTensor = None, size: Size = None,
                return_attention_weights=None):
        # type: (Union[Tensor, OptPairTensor], Tensor, OptTensor, Size, NoneType) -> Tensor  # noqa
        # type: (Union[Tensor, OptPairTensor], SparseTensor, OptTensor, Size, NoneType) -> Tensor  # noqa
        # type: (Union[Tensor, OptPairTensor], Tensor, OptTensor, Size, bool) -> Tuple[Tensor, Tuple[Tensor, Tensor]]  # noqa
        # type: (Union[Tensor, OptPairTensor], SparseTensor, OptTensor, Size, bool) -> Tuple[Tensor, SparseTensor]  # noqa
        r"""
        Args:
            return_attention_weights (bool, optional): If set to :obj:`True`,
                will additionally return the tuple
                :obj:`(edge_index, attention_weights)`, holding the computed
                attention weights for each edge. (default: :obj:`None`)
        """
        # NOTE: attention weights will be returned whenever
        # `return_attention_weights` is set to a value, regardless of its
        # actual value (might be `True` or `False`). This is a current somewhat
        # hacky workaround to allow for TorchScript support via the
        # `torch.jit._overload` decorator, as we can only change the output
        # arguments conditioned on type (`None` or `bool`), not based on its
        # actual value.

        H, C = self.heads, self.out_channels

        # We first transform the input node features. If a tuple is passed, we
        # transform source and target node features via separate weights:
        if isinstance(x, Tensor):
            assert x.dim() == 2, "Static graphs not supported in 'GATConv'"
            x_src = x_dst = self.lin_src(x).view(-1, H, C)
        else:  # Tuple of source and target node features:
            x_src, x_dst = x
            assert x_src.dim() == 2, "Static graphs not supported in 'GATConv'"
            x_src = self.lin_src(x_src).view(-1, H, C)
            if x_dst is not None:
                x_dst = self.lin_dst(x_dst).view(-1, H, C)

        x = (x_src, x_dst)

        # Next, we compute node-level attention coefficients, both for source
        # and target nodes (if present):
        alpha_src = (x_src * self.att_src).sum(dim=-1)
        alpha_dst = None if x_dst is None else (x_dst * self.att_dst).sum(-1)
        alpha = (alpha_src, alpha_dst)

        if self.add_self_loops:
            if isinstance(edge_index, Tensor):
                # We only want to add self-loops for nodes that appear both as
                # source and target nodes:
                num_nodes = x_src.size(0)
                if x_dst is not None:
                    num_nodes = min(num_nodes, x_dst.size(0))
                num_nodes = min(size) if size is not None else num_nodes
                edge_index, edge_attr = remove_self_loops(
                    edge_index, edge_attr)
                edge_index, edge_attr = add_self_loops(
                    edge_index, edge_attr, fill_value=self.fill_value,
                    num_nodes=num_nodes)
            elif isinstance(edge_index, SparseTensor):
                if self.edge_dim is None:
                    edge_index = set_diag(edge_index)
                else:
                    raise NotImplementedError(
                        "The usage of 'edge_attr' and 'add_self_loops' "
                        "simultaneously is currently not yet supported for "
                        "'edge_index' in a 'SparseTensor' form")

        # propagate_type: (x: OptPairTensor, alpha: OptPairTensor, edge_attr: OptTensor)  # noqa
        out = self.propagate(edge_index, x=x, alpha=alpha, edge_attr=edge_attr,
                             size=size)

        alpha = self._alpha
        assert alpha is not None
        self._alpha = None

        if self.concat:
            out = out.view(-1, self.heads * self.out_channels)
        else:
            out = out.mean(dim=1)

        if self.bias is not None:
            out += self.bias

        if isinstance(return_attention_weights, bool):
            if isinstance(edge_index, Tensor):
                return out, (edge_index, alpha)
            elif isinstance(edge_index, SparseTensor):
                return out, edge_index.set_value(alpha, layout='coo')
        else:
            return out

    def message(self, x_j: Tensor, alpha_j: Tensor, alpha_i: OptTensor,
                edge_attr: OptTensor, index: Tensor, ptr: OptTensor,
                size_i: Optional[int]) -> Tensor:
        # Given edge-level attention coefficients for source and target nodes,
        # we simply need to sum them up to "emulate" concatenation:
        alpha = alpha_j if alpha_i is None else alpha_j + alpha_i

        if edge_attr is not None:
            if edge_attr.dim() == 1:
                edge_attr = edge_attr.view(-1, 1)
            assert self.lin_edge is not None
            edge_attr = self.lin_edge(edge_attr)
            edge_attr = edge_attr.view(-1, self.heads, self.out_channels)
            alpha_edge = (edge_attr * self.att_edge).sum(dim=-1)
            alpha = alpha + alpha_edge

        alpha = F.leaky_relu(alpha, self.negative_slope)
        alpha = softmax(alpha, index, ptr, size_i)
        self._alpha = alpha  # Save for later use.
        alpha = F.dropout(alpha, p=self.dropout, training=self.training)
        return x_j * alpha.unsqueeze(-1)

    def __repr__(self) -> str:
        return (f'{self.__class__.__name__}({self.in_channels}, '
                f'{self.out_channels}, heads={self.heads})')

# %%
class GAT(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GATConvMy((-1, -1), hidden_channels, add_self_loops = False)
        #self.lin1 = Linear(-1, hidden_channels)
        self.conv2 = GATConvMy((-1, -1), hidden_channels, add_self_loops = False)
        #self.lin2 = Linear(-1, hidden_channels)
        self.conv3 = GATConvMy((-1, -1), out_channels, add_self_loops = False)
        #self.lin3 = Linear(-1, out_channels)

    def forward(self, x, edge_index):
        x, attention_weights = self.conv1(x, edge_index, return_attention_weights=True) #+ self.lin1(x)
        x = x.relu()
        x = self.conv2(x, edge_index) #+ self.lin2(x)
        x = x.relu()
        x = self.conv3(x, edge_index) #+ self.lin3(x)
        return x

# %%
data = get_data()
data = data.to(device)
model = GAT(hidden_channels=128, out_channels=1)
model = to_hetero(model, data.metadata(), aggr = 'mean').to(device)
model.eval()
out = model(data.x_dict, data.edge_index_dict)
out
# Out:
# ({'spot': tensor([[1.8574],
#           [2.0973],
#           [2.4472],
#           ...,
#           [1.6264],
#           [1.0626],
#           [2.7642]], device='cuda:5', grad_fn=<AddBackward0>),
#   'word': tensor([[1.0276],
#           [0.0000],
#           [0.0000],
#           ...,
#           [0.9041],
#           [0.6399],
#           [0.0000]], device='cuda:5', grad_fn=<AddBackward0>)},
#  {'spot': (tensor([[14381, 23997, 24374,  ..., 10051, 24047,  9016],
#            [    0,     0,     0,  ...,  5384,  5384,  5384]], device='cuda:5'),
#    tensor([[0.0141],
#            [0.0724],
#            [0.1738],
#            ...,
#            [0.0024],
#            [0.0889],
#            [0.0032]], device='cuda:5', grad_fn=<DifferentiableGraphBackward>)),
#   'word': (tensor([[    0,     0,     0,  ...,  5384,  5384,  5384],
#            [14381, 23997, 24374,  ..., 10051, 24047,  9016]], device='cuda:5'),
#    tensor([[0.0103],
#            [1.0000],
#            [0.1323],
#            ...,
#            [1.0000],
#            [1.0000],
#            [0.0902]], device='cuda:5', grad_fn=<DifferentiableGraphBackward>))})

# %%
from typing import Dict, List, Optional, Union

import torch
import torch.nn.functional as F
from torch import Tensor, nn

from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.dense import Linear
from torch_geometric.nn.inits import glorot, reset
from torch_geometric.typing import Adj, EdgeType, Metadata, NodeType
from torch_geometric.utils import softmax


def group(xs: List[Tensor], q: nn.Parameter,
          k_lin: nn.Module) -> Optional[Tensor]:
    if len(xs) == 0:
        return None
    else:
        num_edge_types = len(xs) #1
        out = torch.stack(xs) #(1,5385, 64)
        if out.numel() == 0:
            return out.view(0, out.size(-1))
        attn_score = (q * torch.tanh(k_lin(out)).mean(1)).sum(-1)
        attn = F.softmax(attn_score, dim=0) #1
        out = torch.sum(attn.view(num_edge_types, 1, -1) * out, dim=0) #(5385, 64)
        return out


class HANConvMy(MessagePassingMy):
    r"""
    The Heterogenous Graph Attention Operator from the
    `"Heterogenous Graph Attention Network"
    <https://arxiv.org/pdf/1903.07293.pdf>`_ paper.

    .. note::

        For an example of using HANConv, see `examples/hetero/han_imdb.py
        <https://github.com/pyg-team/pytorch_geometric/blob/master/examples/
        hetero/han_imdb.py>`_.

    Args:
        in_channels (int or Dict[str, int]): Size of each input sample of every
            node type, or :obj:`-1` to derive the size from the first input(s)
            to the forward method.
        out_channels (int): Size of each output sample.
        metadata (Tuple[List[str], List[Tuple[str, str, str]]]): The metadata
            of the heterogeneous graph, *i.e.* its node and edge types given
            by a list of strings and a list of string triplets, respectively.
            See :meth:`torch_geometric.data.HeteroData.metadata` for more
            information.
        heads (int, optional): Number of multi-head-attentions.
            (default: :obj:`1`)
        negative_slope (float, optional): LeakyReLU angle of the negative
            slope. (default: :obj:`0.2`)
        dropout (float, optional): Dropout probability of the normalized
            attention coefficients which exposes each node to a stochastically
            sampled neighborhood during training. (default: :obj:`0`)
        **kwargs (optional): Additional arguments of
            :class:`torch_geometric.nn.conv.MessagePassing`.
    """
    def __init__(
        self,
        in_channels: Union[int, Dict[str, int]],
        out_channels: int,
        metadata: Metadata,
        heads: int = 1,
        negative_slope=0.2,
        dropout: float = 0.0,
        **kwargs,
    ):
        super().__init__(aggr='add', node_dim=0, **kwargs)

        if not isinstance(in_channels, dict):
            in_channels = {node_type: in_channels for node_type in metadata[0]}
        self.heads = heads
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.negative_slope = negative_slope
        self.metadata = metadata
        self.dropout = dropout
        self.k_lin = nn.Linear(out_channels, out_channels)
        self.q = nn.Parameter(torch.Tensor(1, out_channels))

        self.proj = nn.ModuleDict()
        for node_type, in_channels in self.in_channels.items():
            self.proj[node_type] = Linear(in_channels, out_channels)

        self.lin_src = nn.ParameterDict()
        self.lin_dst = nn.ParameterDict()
        dim = out_channels // heads
        for edge_type in metadata[1]:
            edge_type = '__'.join(edge_type)
            self.lin_src[edge_type] = nn.Parameter(torch.Tensor(1, heads, dim))
            self.lin_dst[edge_type] = nn.Parameter(torch.Tensor(1, heads, dim))

        self.reset_parameters()

    def reset_parameters(self):
        reset(self.proj)
        glorot(self.lin_src)
        glorot(self.lin_dst)
        self.k_lin.reset_parameters()
        glorot(self.q)


    def forward(
        self, x_dict: Dict[NodeType, Tensor],
        edge_index_dict: Dict[EdgeType,
                              Adj]) -> Dict[NodeType, Optional[Tensor]]:
        r"""
        Args:
            x_dict (Dict[str, Tensor]): A dictionary holding input node
                features  for each individual node type.
            edge_index_dict (Dict[str, Union[Tensor, SparseTensor]]): A
                dictionary holding graph connectivity information for each
                individual edge type, either as a :obj:`torch.LongTensor` of
                shape :obj:`[2, num_edges]` or a
                :obj:`torch_sparse.SparseTensor`.

        :rtype: :obj:`Dict[str, Optional[Tensor]]` - The output node embeddings
            for each node type.
            In case a node type does not receive any message, its output will
            be set to :obj:`None`.
        """
        H, D = self.heads, self.out_channels // self.heads
        x_node_dict, out_dict = {}, {}

        # Iterate over node types:
        for node_type, x in x_dict.items():
            x_node_dict[node_type] = self.proj[node_type](x).view(-1, H, D)
            out_dict[node_type] = []

        # Iterate over edge types:
        for edge_type, edge_index in edge_index_dict.items():
            src_type, _, dst_type = edge_type #'spot' 'relate' 'word'
            edge_type = '__'.join(edge_type) #'spot__relate__word'
            lin_src = self.lin_src[edge_type] #(1, 8, 8)
            lin_dst = self.lin_dst[edge_type] #(1, 8, 8)

            x_src = x_node_dict[src_type] #(5385, 8, 8)
            x_dst = x_node_dict[dst_type] #(33628, 8, 8)

            alpha_src = (x_src * lin_src).sum(dim=-1) #(5385, 8)
            alpha_dst = (x_dst * lin_dst).sum(dim=-1) #(33628, 8)
            
            # propagate_type: (x_dst: PairTensor, alpha: PairTensor)
            #edge_index (2, 107700)
            #x_src (5385, 8, 8)
            #x_dst (33628, 8, 8)
            #alpha_src (5385, 8)
            #alpha_dst (33628, 8)
            out = self.propagate(edge_index, x=(x_src, x_dst),
                                 alpha=(alpha_src, alpha_dst), size=None) #(33628, 64)
            #何が起こってる？
  
            out = F.relu(out) #(33628 64)
            out_dict[dst_type].append(out)
        # iterate over node types:
        for node_type, outs in out_dict.items():
            out = group(outs, self.q, self.k_lin) #(33628, 64)
            if out is None:
                out_dict[node_type] = None
                continue
            out_dict[node_type] = out

        for k,v in out_dict.items():
        return out_dict


    def message(self, x_j: Tensor, alpha_i: Tensor, alpha_j: Tensor,
                index: Tensor, ptr: Optional[Tensor],
                size_i: Optional[int]) -> Tensor:

        #'spot' 'relate' 'word'のとき
        #x_j (107700, 8, 8)
        #alpha_i (107700, 8)
        #alpha_j (107700, 8)
        #index wordの方のインデックス
        #ptr None
        #size_i, 33628
        alpha = alpha_j + alpha_i #(107700, 8)
        alpha = F.leaky_relu(alpha, self.negative_slope) #(107700, 8)
        alpha = softmax(alpha, index, ptr, size_i) #(107700, 8)
        alpha = F.dropout(alpha, p=self.dropout, training=self.training) #(107700, 8)
        out = x_j * alpha.view(-1, self.heads, 1) #(107700, 8, 8)

        return out.view(-1, self.out_channels) 

    def __repr__(self) -> str:
        return (f'{self.__class__.__name__}({self.out_channels}, '
                f'heads={self.heads})')
# Out:
#   File "/tmp/ipykernel_3757967/174998609.py", line 167
#     return out_dict
#          ^
# IndentationError: expected an indented block

# %%
class GAT(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GATConvMy((-1, -1), hidden_channels, add_self_loops = False)
        #self.lin1 = Linear(-1, hidden_channels)
        self.conv2 = GATConvMy((-1, -1), hidden_channels, add_self_loops = False)
        #self.lin2 = Linear(-1, hidden_channels)
        self.conv3 = GATConvMy((-1, -1), out_channels, add_self_loops = False)
        #self.lin3 = Linear(-1, out_channels)

    def forward(self, x, edge_index):
        x, attention_weights = self.conv1(x, edge_index, return_attention_weights=True) #+ self.lin1(x)
        x = x.relu()
        x = self.conv2(x, edge_index) #+ self.lin2(x)
        x = x.relu()
        x = self.conv3(x, edge_index) #+ self.lin3(x)
        return x, attention_weights

# %%
class HANMy(torch.nn.Module):
    def __init__(self, data, in_channels, out_channels, hidden_channels=128,heads=8):
        super().__init__()
        self.han_conv = HANConvMy(in_channels, hidden_channels, heads=heads,
                                dropout=0.6, metadata=data.metadata())
        self.lin = nn.Linear(hidden_channels, out_channels)

    def forward(self, x_dict, edge_index_dict):
        out = self.han_conv(x_dict, edge_index_dict)
        out = self.lin(out['spot'])
        return out

# %%
model = HANMy(data, in_channels=-1, hidden_channels=64, out_channels=1)
model = model.to(device)

# %%
out = model(data.x_dict, data.edge_index_dict)
# Out:
# collect
# 1 0
# {'alpha_j', 'x_j', 'alpha_i'}
# update_kwargs {}
# torch.Size([1023, 64])
# collect
# 1 0
# {'alpha_j', 'x_j', 'alpha_i'}
# update_kwargs {}
# torch.Size([64, 64])
# collect
# 1 0
# {'alpha_j', 'x_j', 'alpha_i'}
# update_kwargs {}
# torch.Size([5385, 64])
# collect
# 1 0
# {'alpha_j', 'x_j', 'alpha_i'}
# update_kwargs {}
# torch.Size([33628, 64])
# spot torch.Size([5385, 64])
# word torch.Size([33628, 64])
# category torch.Size([64, 64])
# city torch.Size([1023, 64])

# %%
a = torch.tensor([7])
type(a)==torch.Tensor
# Out:
# True

# %%
import torch 
a=torch.tensor([[[1,1],[2,2]] for i in range(3)])
a.size()
# Out:
# torch.Size([3, 2, 2])

# %%
b = torch.tensor([[1,2],[3,4]])
b.size()
# Out:
# torch.Size([2, 2])

# %%
a = torch.rand((2,2,2))
b = torch.rand((2,2,1))
a
# Out:
# tensor([[[0.8457, 0.2872],
#          [0.2235, 0.0055]],
#
#         [[0.6770, 0.6872],
#          [0.0461, 0.2361]]])

# %%
b
# Out:
# tensor([[[0.7986],
#          [0.3554]],
#
#         [[0.8815],
#          [0.4090]]])

# %%
a*b
# Out:
# tensor([[[0.6754, 0.2293],
#          [0.0794, 0.0019]],
#
#         [[0.5967, 0.6057],
#          [0.0189, 0.0966]]])

# %%
data['spot','relate','word']
# Out:
# {'edge_index': tensor([[    0,     0,     0,  ...,  5384,  5384,  5384],
#         [16879, 12199, 20733,  ..., 12023,  8079,  6337]])}

# %%
a = torch.rand((4,3))
b = torch.rand((4,3))
print(a)
print(b)
print(a+b)
# Out:
# tensor([[0.8356, 0.6688, 0.6694],
#         [0.4063, 0.9802, 0.6711],
#         [0.5232, 0.4037, 0.8003],
#         [0.8174, 0.7496, 0.7368]])
# tensor([[0.3358, 0.3990, 0.3982],
#         [0.1482, 0.3865, 0.4923],
#         [0.1061, 0.4758, 0.3176],
#         [0.6484, 0.2710, 0.7525]])
# tensor([[1.1715, 1.0678, 1.0676],
#         [0.5545, 1.3668, 1.1634],
#         [0.6293, 0.8795, 1.1180],
#         [1.4658, 1.0206, 1.4893]])

# %%
df = pd.read_csv('/home/yamanishi/project/trip_recommend/data/df_experience.csv')
df.columns.values
# Out:
# array(['Unnamed: 0', 'Unnamed: 0.1', '観光地名', '都道府県', 'url_q', 'page_view',
#        'latitude', 'longitude', 'city', 'address', 'jalan_url',
#        'category', 'jalan_review_rate', 'jalan_review_count',
#        'jalan_image_url', 'wiki_text', 'jalan_review', 'text_joined',
#        'page_view_rank', 'valid', 'tokenized_text', 'tfidf_topk_index',
#        'tfidf_topk_word', 'city_label', 'category_label'], dtype=object)

# %%
for i,(spot_name, tfidf_topk_word) in enumerate(zip(df['観光地名'], df['tfidf_topk_word'])):
    print(spot_name, tfidf_topk_word)
# Out:
# 絵鞆半島 ['室蘭本線' '内浦湾' '新道' '基部' '白鳥' '室蘭' '半島' '先端' '北海道' '東岸' '太平洋' '支線' '八景'
#  'アイヌ' '景勝' '大橋' '対岸' '名勝' '良港' '西向き']
# 北海道立旭川美術館 ['常磐公園' '美術館' 'ラリック' '展示' '道北' '作品' '旭川' '木工' '北海道' '松園' '常盤' '芸術' '東川'
#  '展覧' '造形' '鑑賞' '歌麿' '上村' 'ルノワール' '出身']
# 八雲町郷土資料館 ['副業' '彫り' '究極' '資料' '北海道' '郷土' '木彫り' '発祥' 'わたくし' 'ょうかん' '士族' '展示' '開拓'
#  'やくも' '阿寒湖畔' 'アイヌ' '八雲' '尾張' 'クマ' '産業']
# 上士幌町鉄道資料館 ['展示' '十勝' '廃止' '運転' '帯広' '国鉄' '鉄道' '上士幌' '駅舎' 'トロッコ' '資料' '糠平' '清水谷' '方面'
#  '当時' '代替' 'びら' '列車' '線路' '路線']
# 元町公園 ['支庁' '函館' '墓地' '洋館' '山手' '北海道庁' '横浜' '番館' '元町' '花見' '地区' '開拓' '西洋' '外国'
#  'ホール' '北海道' '満開' '本通り' '庁舎' '見頃']
# 利尻ふれあい温泉 ['温泉' '炭酸' '入浴' '利尻' '源泉' '湯舟' 'シャンプー' '鴛泊' '水素' '浴槽' '茶褐色' 'うに' '成分' '町営'
#  '金色' 'ホテル' 'ターミナル' 'ツル' 'フェリー' '保養']
# さるふつ温泉 ['ソープ' '枯渇' 'ボディ' '宗谷本線' 'シャンプー' '憩い' 'ホテル' 'サウナ' 'ふつ' '温泉' '入浴' '風呂'
#  '自衛隊' '浴槽' '洗い場' 'タオル' '脱衣' '銭湯' '音威子府' 'トリートメント']
# クロフォード公園 ['平米' 'キハ' '国鉄' '保存' '記念' '蒸気' 'ゾーン' '列車' '機関' '北海道' '三笠' '鉄道' '幌内' 'トロッコ'
#  'dd' '空知' '車両' '展示' '駅舎' '初音']
# 小幌駅 ['トンネル' '列車' '信号' '室蘭本線' '豊浦' '秘境' '複線' '配線' '幌内' '停車' '廃止' '調査' '牛山'
#  '北海道' '方面' '礼文' '乗降' '既設' '番組' '平均']
# サッポロビール博物館 ['見学' 'ビール' '札幌' '工場' 'サッポロ' '麦酒' 'ジンギスカン' 'サッポロビール' '試飲' '北海道' '予約' '恵庭'
#  '製造' 'ラベル' 'クラシック' '開拓' '工程' 'ゴルフ' '出来' '貯金']
# 阿寒湖 ['阿寒' 'アイヌ' '氷上' '雌阿寒岳' '木彫り' 'コタン' '結氷' 'まり' 'マリモ' '湖畔' 'ホテル' '雄阿寒岳' '土産'
#  '釧路' '遊覧' 'ワカサギ' '阿寒湖畔' '温泉' '阿寒湖' '前田']
# 中川町エコミュージアムセンター ['産出' 'ミュージアム' 'エコ' 'アンモナイト' '化石' '博物館' '中川' '地層' '北海道' 'エコール' '中学校' '研修'
#  '光沢' '標本' '佐久' '体育館' '亜紀' '展示' '骨格' 'npo']
# 士別市立博物館 ['雅子' '輪島' '屯田' '和泉' '士別' '親達' '展示' '市立' '功一' '開拓' '冒険' '天塩' '天塩川' '芸術'
#  '博物館' '地域' '化石' '公会堂' '宗谷本線' 'ファイター']
# 大鵬相撲記念館 ['摩周湖' '銅像' '相撲' '展示' '記念' '力士' '弟子屈' 'ファン' '優勝' '回し' '川湯温泉' '大鵬' '横綱'
#  'せんべい' '製菓' '弟子' '卵焼き' '化粧' 'ライバル' '長谷']
# 幌加温泉 ['三国峠' '温泉' '露天風呂' '内湯' '帯広' 'お湯' '携帯' 'びら' '女性' '混浴' '圏外' '旅館' '糠平'
#  '素泊まり' '源泉' '宿泊' '入浴' '内風呂' '電話' '浴槽']
# ニセコアンヌプリ ['北海道' '雄大' 'スキー' '山頂' 'ニセコ' '上級' 'ニセコアンヌプリ' 'パウダースノー' '初心者' 'ゲレンデ' 'ゴンドラ'
#  '羊蹄山' 'コース' '頂上' '積丹' '開場' 'リゾート' '世界' 'アイヌ' '登山']
# つくも水郷公園 ['士別' '閲覧' '市民' '天塩川' 'ゴルフ' 'ゴー' '例規' '北海道' 'アスレチック' 'パーク' 'カート' '条例' '研修'
#  '水郷' 'ボート' '緑地' '風見鶏' '遊具' 'カーリング' '河川']
# 稚内駅 ['駅舎' '終着駅' 'ホーム' '構内' '最果て' '線路' '最北端' '宗谷本線' '特急' '北海道' '稚内' 'キタ' '列車'
#  '鉄道' '宗谷' '防波堤' 'jr' '廃止' 'カラ' '桟橋']
# 別寒辺牛湿原 ['マス' '厚岸' 'カヌー' 'エゾヒグマ' 'ヒメシャクナゲ' 'ラムサール' 'us' 'トミヨ' 'アメ' 'イトヨ' '湿地' '湿原'
#  '上原' 'ヒシ' '車窓' 'タンチョウ' 'イソツツジ' '条約' 'ガンコウラン' 'ha']
# 井上靖記念館 ['悌二郎' '作品' '作家' '孔子' '井上' '東京' 'ラウンジ' 'ノート' '書斎' '展示' '春光' '中原' '旭川' '記念'
#  '世田谷' '文学' '原稿' '彫刻' '応接間' '取材']
# 神仙沼 ['湿地' '天気' '長沼' '神秘' '神仙' 'トレッキング' '感動' '岩内' '積丹' '紅葉' '木々' '池塘' 'レストハウス'
#  'ニセコ' '遊歩道' '湿原' '羊蹄山' '茂み' '高山' '北海道']
# 宮尾登美子文学記念館 ['伊達' '先生' '建て' '登美子' '平屋' 'だて' '宮尾' '執筆' '閉館' '着物' 'お洒落' 'ガラス張り' '記念'
#  '文学' '直木賞' 'ホール' '書斎' 'デザイン' '営利' '法人']
# 道の駅ガーデンスパ十勝川温泉 ['モール' '十勝川温泉' '浦幌' 'コーナー' '道東' '北海道' 'spa' 'ベーカリー' '帯広' '音更' '工房' '十勝'
#  'マルシェ' '協同' '経由' '農産物' '自動車' '温泉' '加工' '公衆']
# 測量山 ['室蘭' '大橋' '白鳥' '夜景' '展望' '工場' '羊蹄山' '送信' 'テレビ塔' '噴火湾' '駒ケ岳' '点灯' 'ライトアップ'
#  '地球' '電波' '階段' '山頂' '標高' '絶景' '北海道']
# 白い恋人パーク ['お菓子' '恋人' 'チョコレート' '土産' 'からくり' 'チョコ' 'ソフトクリーム' 'キャンディ' '見学' 'イルミネーション'
#  '時計' '体験' '札幌' '工場' '製造' '作り' 'パーク' '外国' 'ローズガーデン' '石屋']
# 石狩川 ['開発' 'ダム' '本川' '石狩' '氾濫' '治水' '札幌' '泥炭' '発電' '北海道' '流域' '計画' '千歳' '河川'
#  '水系' '建設' '石狩川' '事業' '水路' '放水']
# いわみざわ公園 ['薔薇' '温室' 'ざわ' 'バラ' '北海道' '岩見沢' 'グリーンランド' 'ばら' '品種' '遊園' 'ローズフェスタ' 'ローズ'
#  '種類' '色彩' '香り' 'レストラン' 'オープン' 'ソフトクリーム' '植物' 'ハマナス']
# 前田森林公園 ['カナール' 'バーベキュー' 'ポプラ' '散歩' 'パーク' '北海道' 'ライラック' '芝生' '前田' '森林公園' '森林' '札幌'
#  '水盤' '並木' 'ゴルフ' '野球' '豊か' '運河' '手稲山' '藤棚']
# 釧路フィッシャーマンズワーフMOO ['店舗' '西武百貨店' 'サンマ' '市場' 'キャッチャー' 'まんま' '飲食' '土産' 'ufo' '商業' '公社' '海産物'
#  'フィッシャーマンズワーフ' '屋台' '食事' 'お菓子' 'テナント' '駄菓子' '釧路' '河畔']
# 北海道立函館美術館 ['展示' '美術' '美術館' '作品' '北海道' '五稜郭' '若冲' '函館' 'タワー' '常設' 'テーマ' 'コレクション' '絵画'
#  '彫刻' '芸術' '東洋' '画家' '伊藤' '開館' '記号']
# 野付半島 ['先端' '立ち枯れ' 'トド' '野付' '砂嘴' '国後島' 'ネイチャー' '半島' '知床' 'エゾシカ' '北海道' 'ワラ' 'ナラ'
#  'センター' '両側' 'エビ' 'キタキツネ' '別海' '流氷' '北海']
# 釧路湿原 ['タンチョウ' '釧路' 'カヌー' '展望' '湿原' 'ノロッコ' '蛇行' '保護' '丹頂鶴' 'オジロワシ' '北海道' '広大'
#  '列車' 'ha' '遊歩道' '釧網本線' 'カヤック' '雄大' '丹頂' '国立']
# 雨竜沼湿原 ['雨竜' 'キロメートル' '北海道' '登山' '天売' '湿原' 'ゲート' '池塘' 'パーク' '高層' 'ラムサール' 'つり橋'
#  '車線' '尾瀬' '条約' '泥炭' '空知' '入山' '標高' '植物']
# 北海道立文学館 ['啄木' '綾子' '武郎' '中島公園' '財団' 'ゆかり' '北海道' '資料' '新選' '札幌' '文学' '有島' '展示' '企画'
#  '常設' '作家' '三浦' '公益' '高橋' '法人']
# 中山峠写真の森美術館 ['ピカソ' '作品' '子ども' '美術館' '北海道' '屋外' '芸術' '彫刻の森' '展示' 'ネット' '彫刻' 'ステンドグラス'
#  '箱根' '中山峠' 'シンフォニー' 'アート' '足湯' '美術' '室内' 'ギャラリー']
# 悲別ロマン座 ['ロマン' 'ドラマ' '倉本' '炭鉱' '喫茶店' '舞台' '映写機' '映画' 'カレー' '放映' '感謝' '守り' '営業'
#  '架空' 'マスター' '脚本' '保存' '青春' '上映' 'テレビ']
# 滝野すずらん丘陵公園 ['ゾーン' '供用' 'エリア' '国営' 'カントリー' '渓流' '北海道' '滝野' '札幌' 'すずらん' 'チューリップ' 'ha'
#  '丘陵' 'スキー' 'ガーデン' 'お花畑' '遊具' '開始' 'コスモス' '中旬']
# 旭岳温泉 ['お湯' '旭川' '入浴' '温泉' '宿泊' 'ウェイ' '露天風呂' 'ロープ' 'ホテル' '帰り' '旅館' '登山' 'スキー'
#  '源泉' '大雪山' '東川' '北海道' '標高' '選手' '竹内']
# 西岡公園 ['給水' '取水' '水道' '陸軍' '真っ暗' '昼休み' '西岡' '野鳥' '豊平峡' '豊平' '観察' '浄水' '豊か'
#  'ヘイケボタル' 'ホタル' '生息' '札幌' '散歩' '水源' '北海道']
# アポイ岳 ['登山' '下山' '馬の背' 'お花畑' '土壌' 'ジオパーク' '標高' '山小屋' '初心者' '頂上' '山脈' '高山' '北海道'
#  '植物' '山荘' '名山' '固有' '認定' 'ダケカンバ' '生育']
# クッチャロ湖 ['コハクチョウ' '北海道' '小沼' '屈斜路湖' '温泉' '砂州' 'キャンプ' '飛来' '観察' '保護' 'オホーツク' '大沼'
#  '条約' '湖畔' 'ラムサール' '白鳥' '水鳥' '稚内' '湿地' 'ハクチョウ']
# 札幌ドーム ['リーグ' '試合' '球場' '球団' 'ハム' '札幌' '北海道' '開催' 'サッカー' 'コンサドーレ' '野球' '本拠地'
#  'ドーム' 'スタンド' 'プロ' '表示' '使用' '主催' 'アリーナ' 'チーム']
# 利尻富士温泉 ['疲れ' '利尻' '足湯' '鴛泊' '入浴' '塩味' '生ビール' 'ハートランド' '温泉' 'フェリー' '送迎' '登山'
#  '利尻富士' 'タンクローリー' '利尻山' 'シャンプー' '含重曹' '露天風呂' 'プール' '食塩']
# えこりん村 ['牧場' 'トマト' '庭園' '動物' '恵庭' 'アルパカ' 'レストラン' 'ピザ' 'ガーデン' '銀河' '野菜' 'man'
#  'ten' 'レース' '刈り' 'パスタ' '食事' 'ビュッフェ' '牧羊' 'ひつじ']
# カトリック元町教会 ['ライトアップ' 'トス' '函館' 'ヨハネ' 'カトリック' '元町' 'ハリス' 'ハリストス' 'ゴシック' '様式' '祭壇' '聖堂'
#  '尖塔' '外観' '教会' '正教会' '風見鶏' '見学' '内部' '屋根']
# 金森赤レンガ倉庫 ['雑貨' 'テナント' 'ライトアップ' '店舗' '衣装' 'レンガ' 'オルゴール' '函館山' '土産' '渡邉' '買い物' '倉庫'
#  '百貨店' '函館' '金森' '明治' 'ショップ' 'bay' 'ショッピング' '朝市']
# フラノマルシェ ['チーズ' 'マルシェ' 'メロン' '野菜' 'ワイン' '土産' '市街地' 'スイーツ' '富良野' 'パン' '活性' '北海道'
#  '広報' 'ドレッシング' 'バン' 'おにぎり' 'ジャム' '特産' 'ルー' '農産物']
# 旭山記念公園 ['一望' '札幌' '円山' '円山公園' '噴水' '夜景' '記念' '展望' '藻岩山' '旭山' '市内' '広場' 'ロマンチック'
#  '水遊び' '市街地' '頂上' 'デート' 'カップル' '温泉' '大倉山']
# 旭岳 ['ウェイ' '姿見の池' '姿見' '登山' 'ロープ' '山頂' '大雪山' '高山' '北海道' '紅葉' '残雪' 'チングルマ' '植物'
#  '頂上' '装備' '服装' '天候' '雪山' 'コース' '絶景']
# 五味温泉 ['入浴' '天然' 'サウナ' '浴用' '飲用' '五味' '名寄' '風呂' 'お湯' '下川' '鉱泉' '含二酸' '源泉' '温泉'
#  '露天風呂' '心臓' '水素' '炭酸泉' '炭酸' '疾患']
# 利根別自然公園 ['原生' '繁殖' 'センター' '北海道' '農業' '程度' '利根' '大正池' 'ざわ' '中央' '親水' '鳴き声' '園地'
#  'ダム' '休養' '岩見沢' 'コース' '保安' '手洗い' 'かん養']
# 夕張市石炭博物館 ['再開' '石炭' '資料' '鉄道' '北海道' '坑道' '存続' '炭鉱' 'sl' '模擬' '号機' '返上' '三菱' '保存'
#  '火災' '博物館' '夕張' '展示' '運営' '管理']
# 恵庭温泉 ['シャンプー' '温泉' '内風呂' '露天風呂' '風呂' 'ソープ' '露天' 'サウナ' '常連' '洗い場' 'ラフォーレ' 'ほのか'
#  '恵庭' 'シャワー' '従業' '脱衣' 'お湯' '女性' 'モール' '食券']
# アートホール東洲館 ['アート' 'ホール' '出身' '正幸' '書家' '美術' '画展' '雅彦' '深川' '作品' '展示' '舞踏' 'ビル' '経済'
#  'デッサン' '洋画' '開催' '市民' '谷口' '美術館']
# 室蘭八幡宮 ['室蘭' '八幡宮' '神社' '竣功' 'クジラ' '八幡' '上演' 'くじら' '境内' '北海道' '階段' '琴平' '石段'
#  '手植え' '三条' '勾配' '神楽' '段数' '三吉' '明治']
# 道の駅おだいとう ['ホタテ' '国後島' '展望' '北方領土' 'ソフトクリーム' '別海' '叫び' '牛乳' 'おだ' '野付' '半島' '国後'
#  '北海道' '売店' 'ソフト' 'バーガー' 'フライ' 'レストラン' 'スタンプ' '羅臼']
# 江差追分会館・江差山車会館 ['展示' '伝習' '大神宮' '民謡' '会館' '木古内' '姥神' '江差' '巡行' '名人' '山車' '渡御' '祭り' '追分'
#  '函館' '実演' 'ニシン' '開館' '優勝' 'ヤマ']
# 真駒内滝野霊園 ['大仏' '霊園' '真駒内' '札幌' 'ふる里' 'ラベンダー' 'モアイ' '滝野' 'すずらん' '洋子' '大仏殿' '霊廟' '安藤'
#  '忠雄' '北海道中央バス' '北方領土' '安倍' '正門' '石像' 'その他']
# 四季彩の丘 ['北海道' 'トラクター' '花畑' 'バギー' 'アルパカ' '美瑛' '入場' '園内' 'ラベンダー' 'カート' '絨毯' '乗り物'
#  '四季' 'カラフル' 'ノロッコ' '料金' 'パッチワーク' '広大' '富良野' '牧場']
# 登別伊達時代村 ['伊達' '登別' 'ショー' 'スリップ' '忍者' '芝居' '登別温泉' 'スタッフ' '江戸' '役者' '屋敷' '手裏剣' '劇場'
#  'タイム' '外国' 'お化け' '体験' '花魁' 'お金' '弓矢']
# 樽前ガロー ['神秘' '案内' '空気' '樽前山' 'ガリ' '北海道' '垂直' '苫小牧' '太古' '火砕流' '看板' '浸食' 'カメラ'
#  '岩肌' '渓谷' '景観' '現地' 'コケ' '斜面' '渓流']
# 然別湖 ['温泉' '北海道' '露天風呂' '遊覧' 'コタン' '然別湖' '湖面' '湖畔' '氷上' 'ネイチャー' '足湯' '帯広' '神秘'
#  'ホテル' '十勝' 'バー' 'グラス' '糠平' '大雪山' '上士幌']
# おびひろ動物園 ['遊園' '動物' 'ヒシ' '北海道' 'アザラシ' 'ゾウ' '旭山' '円山' '帯広' 'キリン' '乗り物' 'トラ'
#  'ホッキョクグマ' 'フラミンゴ' 'ヤス' '遊具' '開園' 'ナナ' 'ライオン' '緑ヶ丘']
# 紫竹ガーデン ['北海道' 'ガーデン' '帯広' '庭園' 'ばあちゃん' 'クレマチス' 'チューリップ' '花畑' '季節' '雑草' '十勝' '手入れ'
#  '広大' '朝食' '種類' 'お花畑' '街道' '入場' 'ビュッフェ' '花壇']
# 道の駅しかべ間歇泉公園 ['大沼公園' 'メートル' 'ドライブ' '勢い' '温泉' 'えび' '足湯' '土産' '御膳' '間隔' 'タオル' '食堂' '迫力'
#  '噴出' '上がり' '北海道' '間歇泉' '間欠泉' '函館' '食事']
# 小清水原生花園 ['網走' '原生花園' '原生' '斜里' '花園' '知床' '小清水' 'オレンジ' 'オホーツク' '北海道' 'ウトロ' '乗降'
#  '釧網本線' 'ヒオウギ' 'スカシユリ' '草原' 'ハマナス' 'もろもろ' '野花' '脳裏']
# 十勝ヒルズ ['帯広' 'レストラン' '北海道' 'ヒルズ' 'ハンガリー' 'バラ' 'ガーデン' 'ラベンダー' '園内' '十勝' '野菜'
#  'ファーム' '小豆' 'バイキング' 'ミラー' '幕別' '料理' 'トンボ' '和食' '前菜']
# 妹背牛温泉 ['露天' '流し' 'ペル' '浴槽' '洗い場' '風呂' 'お湯' '露天風呂' '炭酸' '塩化' '水素' 'サウナ' 'ナトリウム'
#  '温泉' '役場' '入浴' '源泉' '深川' 'ハンバーグ' '毛穴']
# 朝里岳 ['円錐' '斜面' 'スキー' '文庫' '飛行場' '地形' 'isbn' '札幌' '溶岩' '赤井川' 'キロメートル' '削剥' '境界'
#  'メートル' '朝里' '地質' '余市' '山原' '定山渓' '中新']
# オコタンペ湖 ['湖面' '支笏洞' '千歳空港' '支笏湖' '湖水' '恵庭岳' '展望' '分岐' '立ち入り' '東雲' '札幌' '輝き' '通行止め'
#  '北海道' '保護' 'km' 'ビューポイント' '全景' 'キロ' '神秘']
# 江別市ガラス工芸館 ['工芸' '作品' '江別' '半球' 'ガラス' 'レンガ' '製作' '体験' '柿崎' 'べつ' '見学' 'いかん' '野幌' '硝子'
#  'アーティスト' '創作' '開館' '洋館' '作成' '番地']
# 幕別温泉 ['風呂' 'オンドル' '浴場' 'ツル' '幕別' '浴槽' '高台' '帰り' 'パークホテル' '帯広' '源泉' 'ホテル' 'モール'
#  '露天風呂' '十勝' '十勝川温泉' 'トルネード' '温泉' '入浴' 'パック']
# 知床五湖 ['知床五湖' '高架' '連山' 'ヒグマ' 'レクチャー' '知床' 'ガイド' '遊歩道' 'ループ' '出没' '参加' 'ツアー'
#  'コース' 'クマ' '動物' '地上' 'トレッキング' '遺産' '目撃' '遭遇']
# 函館ハリストス正教会 ['イコン' 'ニコライ' '函館山' 'ライトアップ' '函館' '異国' '聖堂' 'ロシア' '元町' '復活' '正教会' '教会'
#  'ハリス' '北海道' 'ハリストス' '外観' 'トス' '主教' '昇天' '領事館']
# かかし古里館 ['廃校' 'かかし' '案山子' '岩内' '古里' '共和' '展示' '入賞' '開拓' 'ウェブサイト' '我が家' '独り' 'どこ'
#  'かん' '小学校' '活用' 'ふるさと' '安政' 'もみ' '町立']
# 竹山高原温泉 ['モール' '露天風呂' '北広島' 'アルカリ性' '千歳' 'お湯' '高原' 'コーヒー' '入浴' '北海道' '温泉' '札幌'
#  '浴場' 'ベッドタウン' '恵庭' '源泉' '温度' '寒空' '薄茶' 'sic']
# 二股ラジウム温泉 ['旅館' '石灰' '風呂' '湯の花' '山奥' 'ドーム' 'ラジウム' '効能' '湯治' 'アトピー' 'シャンプー' '露天風呂'
#  '浴室' '浴槽' '入浴' 'お湯' '二股' '石鹸' '温泉' '放射能']
# 網走市立美術館 ['網走' '市立' '美術館' '道雄' '実技' '展示' '北海道' '常設' '高橋' 'オホーツク' '釧網本線' 'アニメーター'
#  '遠軽' '会館' '市民' '作品' 'db' '石北本線' '監獄' '忠良']
# 定山渓温泉 ['かっぱ' '帰り' '宿泊' '旅館' '札幌' '定山渓' 'ホテル' '温泉' '北海道' '足湯' '紅葉' '小樽' '浴場' '風呂'
#  'ビューホテル' '鯉のぼり' '源泉' 'カッパ' '明治' 'お湯']
# 男山酒造り資料館 ['旭川' '酒造り' '男山' '試飲' '資料' '酒造' '購入' '展示' '酒好き' '酒蔵' '酒粕' '北海道' '木綿' '本家'
#  '山崎' '吟醸' '歌麿' '蔵元' '酒類' '浮世絵']
# 札幌市美香保体育館 ['スケート' '体育館' '札幌' 'オリンピック' 'レンタル' '冬季' 'スケートリンク' '気軽' '野球' 'フィギュア' 'スポーツ'
#  'テニス' 'コート' 'プール' 'カーリング' 'トレーニング' '地下鉄' 'シューズ' '会場' '手ぶら']
# 稚内市開基百年記念塔・北方記念館 ['メートル' '地上' '夜景' '氷雪' '記念' '北方' '開基' '樺太' '林蔵' '間宮' '北海道' '利尻富士' '利尻'
#  '稚内' '宗谷' 'エレベーター' '資料' '展望' 'サハリン' '一望']
# 鴎島 ['新潟' '平内' 'カモメ' 'イカ' '秋田' '仁賀保' 'まつり' '無人島' '江差' '岩手' 'めじ' '快適' '宮城'
#  'かもめ' '海水浴' '刺し' '能登島' 'ニシン' 'なす' '串本']
# 北海道大学植物園 ['敷地' '広大' '竣工' '北方' '札幌' '北海道' '北海道大学' '農学部' '博物館' '民族' '部門' '剥製' '植物'
#  '園内' '大学' '開拓' '温室' 'クラーク' '博物' 'アイヌ']
# 知床岬 ['国後島' '遊覧' '知床' '酔い' 'コース' '羅臼' '突端' '斜里' '北海道' '先端' '半島' 'クルーズ' 'ウトロ'
#  'クルーザー' 'オホーツク' '乗船' 'ヒグマ' '灯台' '果て' 'イルカ']
# 札幌オリンピックミュージアム ['体験' '札幌' 'ジャンプ' '大倉山' 'ウィンタースポーツ' 'オリンピック' 'スキー' '展示' 'スポーツ' 'ボブスレー'
#  'スケート' '大人' 'シミュレーター' '疑似' 'リフト' '競技' 'ウインタースポーツ' 'フィギュア' 'ミュージアム'
#  'クロスカントリー']
# 朝里川温泉 ['札幌' '定山渓' '旅館' 'かんぽ' '帰り' '風呂' 'ホテル' '朝里' '小樽' 'スキー' '宿泊' '北海道' '露天風呂'
#  'お湯' '温泉' '座敷' '気軽' '入浴' '源泉' '身体']
# 大沼国定公園 ['団子' '大沼公園' '大沼' '北海道' 'サイクリング' '国定' '紅葉' '駒ケ岳' '駒ヶ岳' '遊覧' '七飯' '自転車'
#  '函館' 'ボート' '小沼' '小島' 'コース' 'スノーモービル' '湖上' '散歩']
# 市立小樽文学館 ['啄木' '文学' '市立' '小林' '没後' '小樽' '企画' '追悼' '伊藤' '詩人' '特別' '小説' '秀雄' '物語'
#  '石川' 'ゆかり' '秀和' '歌人' '英夫' '作家']
# 鹿の湯 ['浴槽' '湯船' '温度' '白濁' '温泉' '風呂' '硫黄' '那須' '匂い' '湯本' '入浴' '常連' '源泉' '身体'
#  '湯治' '砂時計' '石鹸' 'お湯' '洗い場' '浴場']
# 倶多楽湖 ['クマ' '摩周湖' 'ボート' '倶多楽湖' '登別' '静か' 'カルデラ' '道路' '湖畔' '登別温泉' '地獄谷' '神秘' '火山'
#  '白老' '透明' '牧場' '貸し' 'レストハウス' '飛行機' '湖面']
# ローズガーデンちっぷべつ ['ローズガーデン' '花壇' '観賞' '薔薇' '留萌' '園内' '特産' '役場' '雨竜' 'バラ' 'ジュース' 'ガーデン'
#  '色とりどり' '香り' '種類' '円形' '札幌' 'ローズ' 'レクリェーション' 'ほか']
# 恵庭市郷土資料館 ['北海道' '遺跡' '資料' '松園' '開拓' '恵庭' '記念' '郷土' '門柱' '建立' '近畿大学' '出土' '小学校'
#  'セミナー' 'アイヌ' '展示' 'エコ' '縄文' '用地' '移転']
# 狩勝峠 ['平野' '狩勝峠' '帯広' 'トンネル' '富良野' '新得' '北海道' '十勝' '鉄道' '雄大' '展望' '東道' '代行'
#  '国道' 'ドライブイン' '脱線' '札幌' '閉店' '石狩' '道路']
# 札幌市青少年科学館 ['学習' 'コーナー' '子ども' '札幌' 'リニューアル' '大人' '中学生' '厚別' 'ロボット' '小学生' 'プラネタリウム'
#  '科学' '展示' '体験' '実験' '地下鉄' '力学' '直子' '天文' 'こども']
# 秩父別温泉 ['秩父' '温泉' '露天風呂' 'ナポリ' 'シルク' 'サウナ' '源泉' '風呂' '半額' '浴槽' '入浴' 'タン' '浴場'
#  '替わり' '黄金' 'バラエティー' '岩盤' '個室' '男女' '併設']
# 野付湾 ['両側' '先端' 'センター' 'エゾシカ' 'ワラ' 'エビ' 'トド' '半島' '国後島' '野付' 'ナラ' '知床' '砂嘴'
#  '北海道' 'ネイチャー' '立ち枯れ' 'キタキツネ' '北海' '流氷' '別海']
# 道の駅びふか ['くり' 'チョウザメ' '販売' '天塩川' '肉まん' 'パン' '温泉' '売店' 'コロッケ' 'かぼちゃ' '野菜' '珈琲' '土産'
#  'ミルク' 'ソフトクリーム' '北海道' '軽食' '国道' 'いも' '音威子府']
# 芽登温泉 ['露天風呂' '流し' '宿泊' '混浴' '入浴' 'せせらぎ' 'シマフクロウ' '源泉' '温泉' '内湯' 'お湯' '風呂' 'ダート'
#  '山奥' '露天' '男女' '足寄' '浴槽' '砂利' '帯広']
# 羅臼岳 ['ヒグマ' '活動' '知床' '羅臼' '長靴' '火山' 'テフラ' '羅臼岳' '入口' '名山' '登山' '噴火' '溶岩' 'ガイド'
#  '降下' 'トレッキング' '火砕流' '知床五湖' '半島' '出没']
# 岩見沢市絵画ホール・松島正幸記念館 ['松島' '正幸' '岩見沢' 'ホール' '画伯' '道内' '展示' '警察' '絵画' '祝祭' '作品' '美術館' '北海道中央バス'
#  '講師' 'ゆかり' '保存' 'まつ' '木曜' '形態' '文化']
# 天塩川温泉 ['帰り' '入浴' '天塩川' '天塩' '音威子府' 'お湯' '露天風呂' '温泉' '北海道' '道北' '保養' 'リバーサイドパーク'
#  '宿泊' '清潔' '風呂' '宗谷本線' '住民' '料金' '内湯' '鉱泉']
# 藻岩山 ['観音' '北海道' 'ウェイ' '尾根' 'スキー' 'りす' '登山' '円山' '山頂' '藻岩山' '軍艦' '慈恵' 'ロープ'
#  '溶岩' '札幌' '中腹' 'ハチ' '明治' '山麓' 'ハエ']
# 道の駅知床・らうす ['特産' '昆布' '海鮮' '食堂' 'ウニ' '北海道' '土産' '羅臼' '知床' '海産物' '国後島' '新鮮' '食事' 'ハモ'
#  '購入' '豊富' 'ウトロ' 'ならでは' 'イクラ' '試食']
# 道の駅絵本の里けんぶち ['絵本' 'コーナー' '農産物' '炭火' '直売' '桜岡' '北海道' '旭川' '焼き' '野菜' 'パン' '鶏肉' '国道'
#  '焼き立て' 'プール' '産直' '名寄' 'カレー' '匂い' 'かまぼこ']
# 豊平峡温泉 ['豊平峡' 'カレー' '露天風呂' '温泉' 'ナン' '定山渓' 'インド' 'お湯' '札幌' '風呂' '源泉' '豊平' '入浴'
#  '流し' '帰り' '内風呂' 'かっぱ' 'ライナー' '露天' '洗い場']
# 北邦野草園 ['鷹栖' 'エサ' '観察' 'クルミ' '旭川' '北海道' 'ザゼンソウ' 'エゾリス' 'ガサガサ' 'エゾエンゴサク' 'アイヌ'
#  '野草' '嵐山' '虫除け' 'エゾノリュウキンカ' '野生' '植物' '野鳥' 'チセ' 'サクラソウ']
# 足寄動物化石博物館 ['テーマ' '博物館' '発掘' '体験' 'レプリカ' '展示' '石膏' 'アンモナイト' '足寄' '骨格' '哺乳類' '子ども'
#  '化石' '掘り' '恐竜' 'クジラ' '復元' '入場' '標本' '葉虫']
# 北海道博物館 ['開拓' '野幌' '博物館' '北海道' 'アイヌ' '展示' '文化' 'テーマ' 'ナウマンゾウ' 'マンモス' '森林公園' '札幌'
#  '和人' '生活' '民族' '化石' 'プロローグ' '暮らし' '先住民' '総合']
# 利尻山 ['礼文' '利尻島' '登山' '利尻山' '利尻富士' '利尻' '山頂' '頂上' '鴛泊' '名山' '稚内' '登頂' '北海道'
#  'コース' 'アイゼン' '火山' 'サロベツ' '礼文島' 'パッケージ' 'フェリー']
# 小樽天狗山ロープウェイ ['箱根' '早雲山' 'ゴンドラ' 'パス' '桃源' '北海道中央バス' '富士山' 'ウェイ' '小樽' '天狗山' 'ロープ' '芦ノ湖'
#  '涌谷' '往復' '搬器' 'フリー' '運休' '真っ白' 'ロープウエイ' '天気']
# 十勝千年の森 ['十勝' 'ガーデン' '広大' 'チーズ' '体験' '北海道' '帯広' 'ヤギ' 'セグウェイ' '作り' '敷地' 'ピザ' 'ツアー'
#  'アース' '山羊' '清水' '芝生' '乗馬' '試乗' '園内']
# ウトナイ湖 ['湖畔' '渡り鳥' 'ネイチャー' 'ハクチョウ' '展望' '千歳空港' '鳥獣' '白鳥' 'ホッキ' '飛来' '野鳥' '苫小牧'
#  'マガン' 'サンクチュアリ' '北海道' 'ラムサール' 'ドライブ' '望遠鏡' 'トイレ' '観察']
# JRタワー ['体験' 'net' '済み' '風呂' 'らん' 'マッサージ' 'サウナ' 'スパ' '札幌' '遊び' 'タワー' 'ホテル' '開発'
#  '夜景' 'タオル' '温泉' 'jr' '入浴' 'ミストサウナ' 'ビル']
# 天売島 ['自転車' '島内' '海鳥' '観察' '北海道' 'ウニ' '焼尻島' '羽幌' '離島' 'うに' '一周' '民宿' '繁殖' '天売'
#  '赤岩' 'フェリー' '天売島' '断崖絶壁' '留萌' '野鳥']
# 北海道グリーンランド ['ジェット' '乗り物' '岩見沢' 'ヒシ' '花火' 'アトラクション' '観覧' '北海道' 'コースター' '遊園' 'ヤス' 'ショー'
#  'グリーンランド' 'スキー' '大会' '絶叫' 'イベント' '札幌' '乗り' '興業']
# 千歳アウトレットモール・レラ ['ブランド' '買い物' '千歳空港' '千歳' '北広島' '空港' '店舗' 'アウトレットモール' 'アウトレット' '閉店'
#  'アウトレットパーク' '北海道' '三井' 'コート' '空き' '札幌' 'ラーメン' 'シャトル' 'フード' 'モール']
# 道の駅おとふけ ['中華' '十勝' 'なつ' '帯広' '乳業' 'パイプ' '音更' 'おと' 'バイキング' '特産' 'ふけ' '十勝川温泉' '北海道'
#  '牛乳' 'つば' '外観' 'レストラン' '土産' 'ソフトクリーム' 'バター']
# 釧路湿原国立公園 ['湿原' '釧路' '展望' 'カヌー' 'タンチョウ' 'ノロッコ' '北海道' '丹頂鶴' '丹頂' '蛇行' 'カヤック' 'オジロワシ'
#  '雄大' '広大' '国立' 'トロッコ' '野生' '列車' '遊歩道' 'ビジターセンター']
# 函館市旧イギリス領事館 ['領事' 'おしゃれ' '元町' '洋館' 'ティールーム' 'イギリス' '執務' '英国' '函館' '外観' '西洋' '見学' 'カフェ'
#  '異国' '開港' '領事館' 'アフタヌーン' '内部' '館内' '造り']
# 浦臼神社 ['北海道' 'エゾリス' '新十津川' '群生' '村社' '寿太郎' 'カタクリ' 'エゾエンゴサク' '友成' '誉田' '下旬' 'ゲラ'
#  '神社' 'カメラ' '被写体' '社格' '函館本線' '空知' '開花' '大國']
# 摩周湖 ['ブルー' '弟子屈' 'アイヌ' 'メートル' 'カルデラ' '北海道' '神秘' '展望' '透明' '硫黄山' '摩周' '摩周湖'
#  '晴天' '湖面' '雲海' '川湯温泉' 'レストハウス' '放流' '天気' '阿寒']
# 白神岬 ['津軽海峡' '青森' '最南端' '松前' '白神' '北海道' '最北端' '国道' '青函' '最果て' 'うっかり' '宗谷岬' '灯台'
#  '石碑' '天気' '半島' '納沙布岬' '函館' '本州' '津軽']
# 大雪山層雲峡・黒岳ロープウェイ ['リフト' '大雪山' 'ウェイ' '層雲峡' 'ロープ' '紅葉' '黒岳' 'ロープウエイ' '雲海' 'ペア' '登山' 'net'
#  'らん' '雪山' '山頂' '山々' '頂上' '温泉' '高山' 'ロープウェー']
# 市立室蘭水族館 ['トド' 'ツブ' 'クラゲ' '室蘭' '観覧' 'ショー' 'おでん' '水槽' '規模' 'ペンギン' '行進' '水族館' 'つぶ'
#  'プール' '遊具' '乗り物' 'メリーゴーランド' 'アザラシ' '遊園' '動物']
# 勝山館 ['墳墓' 'やまだ' 'ガイダンス' '築城' '遺物' '史跡' '松前' '勝山' '北海道大' 'スピード' '山城' '控え目'
#  'たてがみ' '空堀' '取締り' '上之' '堅牢' '上と下' '檜山' 'レンタカー']
# トラピスト修道院 ['バター' '坂道' '院長' '見学' '並木' '男性' '函館' '男子' 'ポプラ' '並木道' 'ソフトクリーム' '濃厚' '売店'
#  '聖母' 'クッキー' '修道' '修道院' '予約' 'カトリック' '教会']
# 百合が原公園 ['札幌' '植物' '宿根草' 'ライラック' '温室' 'チューリップ' 'ムスカリ' '庭園' 'ガーデン' 'トレイン' 'ユリ' '列車'
#  'リリー' '遊具' '園内' '散歩' '花壇' '種類' '電車' '緑化']
# マクンベツ湿原 ['水芭蕉' '湿原' '確実' '石狩川' '石狩' '群生' '札幌' 'ミズバショウ' '訪れ' '生地' '湿地' 'ゴールデンウィーク'
#  '近郊' '大群' 'つぼみ' '河口' '遊歩道' '中旬' 'ゴミ' '野鳥']
# トムラウシ温泉 ['硫黄' '登山' '東大' '入浴' '新得' '国民' '料理' 'お湯' '山奥' '砂利' '源泉' '温泉' '宿舎' '北海道'
#  '露天風呂' '秘境' '透明' 'アルカリ性' '無色' '山道']
# 苫小牧市美術博物館 ['店主' '美術館' '苫小牧' 'マンモス' '博物館' '美術' '展示' '勇払' '策定' '図書館' '遺跡' '原野' 'アイヌ'
#  '特別' '計画' '青森' '芸術' '基本' '作品' '置物']
# 阿寒国際ツルセンター ['釧路' '阿寒' '飼育' 'ツル' '給餌' '丹頂鶴' '国際' 'タンチョウ' 'センター' '湿原' '山崎' '空港' '観察'
#  '飛来' '望遠' '北海道' '愛好' '餌付け' 'ウグイ' '越冬']
# 六花の森 ['画家' '坂本' '庭園' '美術館' '小川' '作品' 'お菓子' '帯広' '草花' '十勝' '展示' '北海道' '包装'
#  'ガーデン' '工場' 'ハマナス' '直行' 'ヨーグルト' '点在' 'レストラン']
# 稚内公園 ['稚内' '氷雪' '樺太' '南極' '記念' '短歌' '北方' 'サハリン' '一望' '宗谷岬' '訓練' '高台' '乙女' '市街地'
#  'ノシャップ' 'モニュメント' '観測' '展望' '市内' '慰霊']
# 宮島沼 ['水鳥' '宮島' '渡り鳥' 'マガン' 'ねぐら' '飛来' '美唄' 'シベリア' '望遠鏡' '白鳥' '群れ' '北海道' '湿地'
#  '撮影' 'ピーク' '湖面' '落穂' '野鳥' '滞在' '豆粒']
# サホロリゾートスキー場 ['十勝' 'コース' '初心者' 'パウダー' 'リゾート' 'スキーヤー' 'スキー' '晴天' 'リフト' 'スノーボード' '北海道'
#  'ゲレンデ' '上級' 'ゴンドラ' 'パウダースノー' '新得' '中級' '平野' '滑り' '斜面']
# 真鍋庭園 ['樹木' 'リス' '手入れ' '真正' '真鍋' '北海道' 'エゾリス' '帯広' 'ガーデン' '庭園' 'コース' '苗木' '街道'
#  '十勝' '針葉樹' '生産' '植物' 'モンスター' 'ツリー' 'ヨーロッパ']
# 小樽運河 ['運河' '夜景' '風情' '倉庫' '木骨' '札幌' '沿い' '寿司' '人力車' 'クルーズ' '景観' 'コロナ' 'ガス' '小樽'
#  'ライトアップ' '夕暮れ' '北海道' '海鮮' '土産' '埋立']
# 道の駅ピア21しほろ ['帯広' 'ソフトクリーム' 'リニューアル' 'ポテトチップス' 'ほろ' 'ピア' '十勝' '野菜' 'レストラン' 'じゃがいも'
#  '土産' '食堂' '購入' '特産' 'オープン' 'メニュー' '北海道' 'コーヒー' 'ポテチ' 'じい']
# 日の出岬 ['組合' '小学校' 'オホーツク' '団地' '幌内' '紋別' 'ホテル' '消防' '町立' '郵便' '北海道' '振興'
#  'キャンプサイト' '宗谷' '川尻' '警察' '漁協' '北見' '駐在' 'ホタテ']
# 知床峠 ['知床' '国後島' '開削' '両町' '北海道' '羅臼岳' '羅臼' 'ウトロ' '道路' '北方領土' 'ヒグマ' '横断' '開発'
#  '斜里' '国道' 'カーブ' '網走' '撮影' 'キタキツネ' '陳情']
# 北海道庁旧本庁舎 ['樺太' '建築' '工事' '庁舎' '北海道庁' '見学' '外国' '北海道' 'レンガ' 'れんが' '札幌' '北方領土' '開拓'
#  '本庁' '煉瓦' '外観' '資料' '大通' '展示' 'チューリップ']
# ふるさと銀河線りくべつ鉄道 ['りく' '気動車' 'トロッコ' '踏切' '乗車' 'コース' '銀河' '運転' '車両' '体験' '北見' '鉄道' 'cr' '構内'
#  'べつ' '列車' '線路' '松浦' '営業' '北海道']
# ノーザンアークリゾート ['メビウス' 'キャビン' 'リゾート' 'コース' 'スキー' 'お湯' '温泉' 'ホテル' 'ゴルフ' '北見' 'arc' 'ナイター'
#  'ゲレンデ' 'バーベキュー' 'デビュー' '株式会社' '上級' 'ツイン' '支配人' 'スノボ']
# 春国岱 ['遊歩道' '根室' '観察' '砂丘' '湿地' '干潟' '砂州' '野鳥' '原生' '動物' 'キタキツネ' '森林' 'エゾマツ'
#  '白鳥' '生息' '野生' '北海道' 'タンチョウ' '湿原' 'オジロワシ']
# オロフレ峠 ['登別' '展望' '北海道' '壮瞥' 'カーブ' '洞爺湖' '登別温泉' '洞爺湖温泉' '紅葉' '羊蹄山' '道路' '絶景' '運転'
#  '洞爺' '通行止め' '旧道' 'ドライブ' 'ルート' '温泉' '新道']
# 流氷硝子館 ['流氷' '硝子' 'リサイクル' '体験' 'ガラス' '網走' 'オホーツク' '製品' '製作' 'サンドブラスト' '興産' 'とんぼ'
#  '原料' '留辺蘂' '鉱業' 'アクセサリー' '蛍光' '大使' '北見' '野村']
# 川村カ子トアイヌ記念館 ['館長' '民族' 'チセ' '北海道' '北門' '測量' '生活' '楽器' 'アイヌ' '文化' '文様' '川村' '旭川' '体験'
#  '用品' '伝統' '開拓' '展示' '衣装' '演奏']
# 手宮公園 ['運河' 'ソメイヨシノ' '高台' '競技' '手宮線' 'エゾヤマザクラ' '花見' '小樽' '季節' '栗林' '名所' '北海道'
#  '緑化' '並木' '散歩' '洞窟' '夜景' 'サクラ' '北限' '眺め']
# 神威岬 ['ブルー' '神威' '積丹' '先端' '彼女' '江差' '禁制' '念仏' '小樽' '女人' '松前' '地震' '和人' '灯台'
#  '蝦夷' '北海道' '女性' '余市' 'ニシン' '母艦']
# 苫小牧市緑ヶ丘公園 ['滑り台' 'ボート' '遊具' 'ハイランド' '球場' 'テニス' 'スケート' 'サッカー' '帯広' '金太郎' 'スポーツ' '野球'
#  '苫小牧' '緑ヶ丘' '王子製紙' '庭球' 'リス' 'ローラー' 'コート' '展望']
# 道の駅しらぬか恋問 ['タコ' '釧路' 'レストラン' '土産' 'つぶ' '北海道' '海産物' 'ソフトクリーム' '海岸' 'メニュー' 'ムーンライト'
#  '購入' '帯広' '新鮮' '充実' '休憩' '販売' 'ボリューム' '魚介' '太平洋']
# 北網圏北見文化センター ['センター' '科学' '野付' '開拓' 'パネル' '常設' '観望' '遺跡' '天体' '博物館' '遺物' '美術館'
#  'プラネタリウム' '北見' '観測' '少女' '生活' '出土' '屯田' '展示']
# 北海道立オホーツク流氷科学センター ['オホーツク' '本物' 'ソフトクリーム' '流氷' '濡れ' '生き物' '紋別' 'マイナス' '科学' '展示' 'タオル' '体験'
#  '屋上' 'クリオネ' '北海道' '網走' '部屋' 'べつ' 'カチコチ' '展望']
# 支笏湖 ['苫小牧' 'カルデラ' '樽前山' '支笏湖' '千歳' '湖畔' '千歳空港' '恵庭岳' '恵庭' 'ボート' '温泉' '札幌'
#  'カヌー' '北海道' '透明' '遊覧' 'まつり' '水深' '湖水' '水質']
# 優駿記念館 ['メッセージ' '墓参り' '競馬' 'ブロンズ' '展示' '競走' '記念' 'ファン' '閉館' 'cb' '開館' '名馬' '館主'
#  '等身' '銅像' 'パーク' 'ダジャレ' 'アイス' 'メモリアル' 'ダービー']
# 札幌芸術の森美術館 ['野外' '作品' '美術館' '忠良' 'アトリエ' '芸術' '真駒内' '展示' '美術' '札幌' '彫刻' '佐藤' '敷地' '展覧'
#  '屋外' '豊か' '北海道' 'かんじき' '作家' 'コレクション']
# 神田日勝記念美術館 ['神田' '北海道' '美術' '美術館' '大地' '金次郎' '帯広' '作品' '練馬' '記念' '新潮' '農民' '福原' '画家'
#  '北海道新聞社' 'なつ' '絶筆' '木田' '出品' '画集']
# 釧路川 ['水門' 'カヌー' 'ノロッコ' '河川' '湿原' '屈斜路湖' '蛇行' '釧路' '展望' '雄大' '弟子屈' '分水' '北海道'
#  '下流' '源流' '太平洋' '製紙' '流れ' '河口' '本流']
# 道の駅マオイの丘公園 ['直売' '長沼' 'メロン' '野菜' '北海道' '新鮮' '札幌' '夕張' 'レストラン' 'トウモロコシ' '千歳空港' 'ドライブ'
#  '販売' '豆腐' '果物' '農産物' '買い物' '産直' 'キャベツ' '購入']
# シューパロ湖 ['水域' '人造湖' '鉄道' '逆さ' '森林' '建設' '竣工' '水没' '拡大' '放水' '北海道' 'ダム' '炭鉱' 'トラス'
#  'アンモナイト' '形成' '夕張' '鹿島' '紅葉' '集約']
# 羊蹄山 ['ニセコ' '豆腐' '京極' '試食' '羊蹄' '羊蹄山' 'タンク' 'ペットボトル' 'ポリ' '火山' '湧き水' '倶知安' '容器'
#  '後方' 'コーヒー' '活動' '蛇口' '名水' '噴火' '崩壊']
# サホロリゾート ['十勝' 'コース' '初心者' 'パウダー' 'リゾート' 'スキーヤー' 'スキー' '晴天' 'リフト' 'スノーボード' '北海道'
#  'ゲレンデ' '上級' 'ゴンドラ' 'パウダースノー' '新得' '中級' '平野' '滑り' '斜面']
# 朱鞠内道立自然公園 ['人造湖' 'ダム' '雨竜' '湖畔' 'イタヤカエデ' '名寄' 'ダケカンバ' '形成' '幌加内' '苫前' '北海道' '道内'
#  '湖沼' '標高' '羽幌' '疎林' '士別' '天塩' '水面' 'キバナシャクナゲ']
# ニセコ ['ゴンドラ' 'パウダースノー' 'スキー' 'ニセコ' 'ニセコアンヌプリ' '北海道' '倶知安' 'コース' '地区' '雄大' '初心者'
#  '上級' '岩内' 'リゾート' 'ゲレンデ' '頂上' '羊蹄山' '山頂' '函館本線' '温泉']
# 月形樺戸博物館 ['監獄' '役場' '刑務所' '開拓' '石狩' '囚人' '足かせ' '北海道' '博物館' '寅吉' '五寸釘' '職員' '館内'
#  '改組' '展示' '資料' '網走' '過酷' '本館' '受付']
# 登別マリンパークニクス ['いわし' '水槽' '金魚' 'イワシ' '入場' 'ペンギン' 'アシカ' 'パレード' 'ショー' 'マリンパーク' 'クラゲ' 'イルカ'
#  '水族館' 'べつ' 'タッチプール' '登別' 'アザラシ' '遊園' '散歩' '開業']
# 農試公園 ['遊具' '水遊び' '自転車' 'テニス' 'キャップ' 'ナイター' '上旬' 'ツイン' '広場' '工作' 'ぷちゃぷ' '札幌'
#  'ちゃ' '期間' '練習' 'コート' '下旬' '北海道' '圧雪' 'プール']
# 野付牛公園 ['ボート' '例規' '北見' '涼み' '規則' '都市' '野付' '閲覧' 'ガチョウ' '道東' 'イチイ' '憩い' 'つけ'
#  'アヒル' '鬱蒼' '町名' '社団' '近接' 'トレーニング' '市制']
# 水無海浜温泉 ['着用' '海岸' '水無' '湯船' '温泉' '恵山' '脱衣' '干潮' '海水浴' '露天風呂' '水着' '満潮' '入浴' '函館'
#  '海辺' '海浜' '足湯' '適温' 'ネタ' '灯台']
# 戸田記念墓地公園 ['満開' '石狩' 'ソメイヨシノ' '食堂' '札幌' '墓参り' '記念' '戸田' 'gw' '墓地' '花見' '名所' '納骨'
#  '見事' '北海道' '渋滞' '円山公園' '並木' '時季' '咲き']
# 東川町郷土館 ['旭川' '展示' '郷土' '開拓' '上川' '車両' '役場' '東川' '資料' '電気' 'モハ' '移築' '軌道' '電車'
#  '道草' 'ひがし' '手押し' '大雪山' '東町' '北海道']
# 東川町キトウシ森林公園家族旅行村 ['キト' 'ウシ' 'ケビン' '東川' '活動' '和室' '森林公園' 'スキー' 'コース' '研修' '展望' '旭川' 'ゴルフ'
#  'ゴー' 'キャンプ' '定員' '大雪山' 'カート' 'ゲラ' 'クロスカントリー']
# 拓真館 ['白樺' '作品' '風景' '四季' '美瑛' '富良野' '展示' 'ラベンダー' 'プリント' '前田' 'ギャラリー' '北海道'
#  '廃校' '玄関' 'サイン' '撮影' '入館' '入場' '絵葉書' '小学校']
# ピアソン記念館 ['ヴォーリズ' '夫妻' '北見' '記念' '設計' '宣教師' '北海道' 'メレル' 'アメリカ' '親切' 'pv' '竜馬'
#  'misia' '営利' '建築' 'エリザベス' '網走' '私邸' '活動' '大正']
# トラピスチヌ修道院 ['修道' '修道院' '函館' 'クッキー' '天使' 'バター' '生活' '売店' '創立' 'マリア' '聖母' '見学' '製造'
#  '女子' '聖堂' '神聖' 'ソフトクリーム' '空港' '規律' '外観']
# サンピアザ水族館 ['ドクターフィッシュ' '札幌' '水族館' 'カワウソ' 'アザラシ' '水槽' 'ペンギン' '大人' '生き物' '厚別' 'ショッピング'
#  '地下鉄' '直結' 'ショー' '科学' '規模' 'ヒトデ' 'イルカ' 'エサ' '買い物']
# 礼文岳 ['登山' '礼文' '礼文島' '溪谷社' '利尻' '頂上' '名山' '山頂' '本山' '北海道' 'チシマザサ' 'ピーク' '利尻富士'
#  'コース' 'ロマン' 'キバナシャクナゲ' 'ダケカンバ' 'トイレ' '標高' '焼尻島']
# 積丹岬 ['小樽' '透明' '階段' 'トンネル' 'ブルー' '積丹' '絶景' 'ドライブ' '断崖' '灯台' '展望' '海岸' '感動'
#  '半島' '自信' '北海道' '奇岩' 'うに' 'ウニ' '天気']
# うらかわ優駿ビレッジAERU ['遊具' 'ビレッジ' '浴場' '温泉' '名馬' 'jra' '競走' '乗馬' '宿泊' '部屋' '入浴' '牧場' 'ホテル' '敷地'
#  '滑り台' '放牧' '食事' '並木' '育成' '体験']
# ゴメ島 ['ママ' '小島' 'オホーツク' 'ナイ' '土器' '調査' '著書' '松浦' '原文' '蝦夷' 'カモメ' '沿岸' '宗谷'
#  'マイル' '北海道' '刊行' '安政' '北見' '遺跡' '縄文']
# キロロリゾート ['ヤマハ' 'スキー' 'マウンテン' '北海道' '開発' 'リゾート' 'ホテル' '赤井川' '公社' 'レクリエーション' 'タウン'
#  'シェラトン' 'ゴルフ' '小樽' 'リフト' 'resort' '温泉' 'アクティビティ' 'ゴンドラ' 'ピアノ']
# 和琴温泉 ['露天風呂' '屈斜路' '脱衣' '温泉' '湖畔' '入浴' '温度' '屈斜路湖' 'お湯' 'キャンプ' '勇気' '先客' '水着'
#  'コタン' 'さま' 'おじ' '浴場' '足湯' '半島' '混浴']
# サロマ湖 ['砂州' '展望' '対向' '知床' 'ダート' '絶景' '連山' '北見' '流入' '舗装' '閉塞' '開削' '網走' 'オホーツク'
#  '階段' '南岸' '常呂' '砂利' '北海道' '一望']
# 小樽市総合博物館 ['博物館' '展示' '鉄道' '小樽' '蒸気' '科学' '北海道' '機関' 'sl' '記念' '手宮線' '車両' '屋外' '列車'
#  '運河' '総合' 'アイアン' '客車' '保存' '車台']
# ノースサファリサッポロ ['サファリ' 'ワニ' '体験' '動物' 'らん' 'キツネ' 'アクティビティ' '水陸' 'アドベンチャー' 'ノース' '北海道'
#  'エサ' 'ライオン' 'net' '済み' 'フクロウ' '両用' 'キリン' 'キタキツネ' 'トラ']
# むかわ温泉 ['不全' '塩化' '北海道' '入浴' '慢性' '併設' 'お湯' '温泉' '四季' '疾患' '禁忌' '関節' '浴用' '宿泊'
#  '札幌' '茶褐色' '帰り' '適応症' '苫小牧' '千歳']
# 北海道立サンピラーパーク ['ホコリ' '卓球' '天文台' '名寄' 'アトリエ' '遊具' 'バドミントン' 'ひまわり' '交流' '休暇' 'ドーム'
#  'オートキャンプ' 'サン' '北海道' 'プール' '花畑' '夏期' 'スポーツ' '冬期' '遊び']
# 北海道立噴火湾パノラマパーク ['八雲' 'ロープ' '富士山' '駿河湾' 'パノラマ' '頂上' 'ウェイ' '山頂' 'カフェ' '天気' 'コーヒー' 'パーク'
#  '噴火湾' 'ゴンドラ' '絶景' 'テラス' 'ペット' '足湯' '眺め' 'チケット']
# 神の子池 ['オショロコマ' '伏流' '倒木' '清里' '舗装' '青色' '透明' '砂利' '摩周湖' '神秘' '摩周' 'エメラルド' '湧き水'
#  '水面' '感動' 'ブルー' '北海道' 'ダート' '価値' '看板']
# 帯広百年記念館 ['十勝' '開拓' '展示' 'センター' '出土' '記念' '創造' '博物館' 'アイヌ' '例規' '民族' '土器' '帯広' '埋蔵'
#  '緑ヶ丘' '文化' '遺跡' 'クイズ' 'ナウ' '分館']
# 箱根牧場 ['作り' 'キャラメル' '千歳' '箱根' 'ソーセージ' 'チーズ' 'レストラン' '手作り' 'バター' '体験' '牛乳' '北海道'
#  '牧場' '動物' 'うさぎ' '千歳空港' '迷路' 'ソフトクリーム' '乗馬' '引き']
# 高龍寺 ['完成' '物体' '有形' '乱入' '曹洞宗' '亀田' '独力' '水盤' '達磨' '修道院' '万代' '思い' '本堂'
#  'こうりゅう' '永平寺' '山門' '函館どつく' '函館' '文化財' '信心']
# 白金温泉 ['白樺' '帰り' '入浴' '富良野' 'ホテル' '美瑛' 'ブルー' '十勝' '宿泊' '源泉' '温泉' 'お湯' '白金' 'リバー'
#  '吹上' '大雪山' '流し' '青池' '露天風呂' '風呂']
# 羅臼湖 ['知床' '長靴' '羅臼' '羅臼岳' 'ガイド' 'km' 'トレッキング' 'シカ' '北海道' '必須' '帰着' 'ヒグマ'
#  'ハイキング' '入口' 'スニーカー' '出没' '軽装' '往復' '湖面' '登山']
# 登別温泉 ['泉源' '地獄' 'ぎり' '登別' '北海道' '滝本' '宿泊' '硫黄' '登別温泉' 'ホテル' '間欠泉' '足湯' 'お湯'
#  '温泉' '地獄谷' '白濁' 'クマ' '遊歩道' '和山' '風呂']
# シゲチャンランド ['原著' '支庁' '津別' '美術館' 'イラストレーター' 'オホーツク' 'チャン' 'モス' 'リトル' '大西' '網走' '相生'
#  'デザイン' 'ハン' 'ランド' 'キャラクター' '龍一' 'wild' 'しげ' 'walk']
# 然別湖畔温泉 ['入浴' '湖畔' '流し' '福原' '温泉' 'お湯' '風水' 'ホテル' '糠平' '露天風呂' '源泉' '然別湖' '足湯' '帰り'
#  '遊覧' '北海道' 'コタン' 'カクテル' '拓殖' '氷上']
# 阿寒富士 ['標高' '雄阿寒岳' '雌阿寒岳' '阿寒湖' '阿寒' '噴煙' '山頂' 'オンネトー' '足寄' '活火山' '釧路' '北海道'
#  '湖面' '登山' '円錐' '総合' 'ハイマツ' '火山' '五色沼' '冨士']
# 屈斜路湖 ['屈斜路湖' '温泉' '湖畔' 'カルデラ' '屈斜路' '砂湯' '摩周湖' '北海道' '摩周' '白鳥' 'コタン' '中島' '道東'
#  '火山' '川湯温泉' '足湯' '酸性' '釧路' 'アイヌ' '雄大']
# 円山原始林 ['円山公園' '原始' '動物' '登山' 'リス' '札幌' '円山' '北海道神宮' '頂上' '原生' '山頂' 'カ所' '野生'
#  '地下鉄' 'シマ' '散歩' '森林浴' 'エゾリス' '競技' '遭遇']
# 昭和新山熊牧場 ['エサ' 'クマ' '登別' 'クッキー' 'ヒグマ' 'ちょうだい' 'ポーズ' '昭和新山' '牧場' 'リンゴ' '仕草' 'アピール'
#  'りんご' '動物' '小熊' '有珠山' 'キャッチ' '洞爺湖温泉' '洞爺湖' '迫力']
# 宗谷岬公園 ['実効' '海軍' '最北端' '放送' '大韓航空' '間宮' '宗谷岬' '宗谷' '樺太' '平和' 'ペルー' '建立' '林蔵'
#  '北海道' '慰霊' '稚内' '祈り' '灯台' 'うた' '北緯']
# 層雲峡 ['層雲峡' 'トンネル' '北海道' '銀河' '硫黄' '旭川' '流星' '風呂' '大雪山' '朝陽' '温泉' 'ホテル' '石狩川'
#  '露天風呂' '大雪' 'お湯' 'リゾート' '落石' '節理' '紅葉']
# 温根湯温泉 ['ホテル' 'お湯' 'ツル' '旅館' '北海道' '留辺蘂' '水族館' '温泉郷' '北見' '温泉' 'シャッター' 'アルカリ性'
#  '国道' '足湯' '美肌' '宿泊' '無色' '硫黄' '釧路' '層雲峡']
# ニセコビレッジ ['初心者' 'デラックス' 'ゴンドラ' 'リゾート' 'ゴルフ' 'スキー' 'コース' 'ニセコアンヌプリ' 'ニセコ' 'ヒルトン'
#  '滑り' '北海道' '上級' 'レストラン' '東山' '充実' 'リーフ' 'ピュア' 'ゲレンデ' 'リフト']
# モケウニ沼 ['湿原' 'コケモモ' 'スゲ' '鳥獣' '枯れ木' '湿地' 'オホーツク' '牧場' 'ワタ' '保護' 'アイヌ' '地帯' '散在'
#  '遊歩道' '植物' 'イソツツジ' 'エゾカンゾウ' '旭化成' 'ハンノキ' '原生花園']
# 札幌市円山動物園 ['展示' 'オランウータン' '旭山' '死亡' '円山公園' 'アザラシ' '円山' '繁殖' 'キリン' 'ホッキョクグマ' '成功'
#  'メス' '動物' '国内' 'オオカミ' 'ゾウ' 'シロクマ' '札幌' '完成' '飼育']
# 道の駅かみしほろ ['パン' 'michinoeki' '釧路' '国道' 'ふるさと' 'バルーン' '充電' '帯広' '北海道' '音更' '上士幌' 'ほろ'
#  '空港' 'stand' 'table' 'ナイ' 'la' '商社' '拓殖' 'ev']
# 奥美利河温泉 ['奥さん' '二股' 'アルカリ性' 'ログハウス' '利夫' '森林公園' '編み' '東条' '休業' '金鉱' '温泉' 'セクター'
#  '休養' '源泉' 'min' 'むちゃくちゃ' '電話' '温度' '九郎' '檜山']
# 釧路市動物園 ['遊園' 'ミルク' '北海道' 'ホッキョクグマ' '旭山' 'ココア' '釧路' '動物' 'トラ' 'フクロウ' 'アムール' '国内'
#  'アルパカ' '成功' 'キリン' 'シロクマ' '繁殖' 'ヒグマ' 'シマフクロウ' 'レッサーパンダ']
# 苫小牧市科学センター ['ロシア' '見学' '苫小牧' 'センター' '展示' '予備' '科学' 'プラネタリウム' 'ソ連' 'はまなす' '高速' '宇宙船'
#  '宇宙' 'ステーション' 'バックアップ' 'ソビエト' '乗り物' '本物' '真空' '貴重']
# 銀河の滝 ['繊細' '迫力' '女滝' '優美' '水量' '瀑台' '流星' '柱状' '節理' '断崖' '断崖絶壁' '落差' '白糸' '国道'
#  '温泉' '銀河' '石狩川' '層雲峡' 'トンネル' '大雪山']
# 二条市場 ['海産物' '魚介' '札幌' '海鮮' '北海道' '市場' '新鮮' '二条' 'のれん' 'イクラ' 'カニ' '活気' '台所' '小路'
#  '土産' 'ラーメン' '大通' 'ホッケ' '値段' '店舗']
# 洞爺湖町立火山科学館 ['洞爺湖' '有珠山' '噴火' '火山' 'ビジターセンター' '有料' 'シアター' '科学' '昭和新山' '被害' '勉強' '洞爺'
#  '災害' '迫力' '避難' '洞爺湖温泉' '映像' '展示' '体験' '噴石']
# 美幌峠 ['絶景' '美幌' '美空' 'いも' '北海道' '雲海' '熊笹' '屈斜路湖' '展望' '弟子屈' '歌碑' '天気' 'ひばり'
#  '眼下' '雄大' '道内' '女満別' '感動' 'レストハウス' '知床']
# サラキ岬 ['手づくり' '函館' '木古内' '亀川' '盛り' 'モニュメント' 'フェア' '祭り' 'チューリップ' '国道' '花壇' '咸臨丸'
#  '色とりどり' 'ーーーー' '腹一杯' 'つくし' 'かかし' '幕府' '受賞' 'キロ']
# おけと湖 ['北見' 'ダム' '治水' '人造湖' '網走' '重力' '河川' '流域' '建設' 'ワカサギ' '利水' '開発' '常呂' '鹿の子'
#  '留辺蘂' '毎秒' '交通省' '農業' '上水道' '直轄']
# 十勝エコロジーパーク ['パーク' '十勝' '十勝川温泉' 'エコロジー' 'ドーム' 'キャンプ' '水遊び' 'web' '帯広' 'org' '遊具' '室内'
#  '新聞' '芝生' 'archive' 'コテージ' 'https' 'co' 'http' '遊び']
# キロロスノーワールド ['ヤマハ' '小樽' '長峰' '上級' '余市' 'リゾート' '赤井川' 'リフト' 'ゲレンデ' '初心者' 'スキー' 'コース'
#  '札幌' 'パウダースノー' 'ゴンドラ' '北海道' '朝里' '開発' 'シェラトン' '公社']
# 太陽の丘えんがる公園 ['太陽' '牧場' '園内' '石北本線' 'たいよう' '割り箸' 'ピンク' '遠軽' '滝上' 'ざく' '紋別' 'コスモス'
#  'シバザクラ' 'ひろば' '斜面' '薄曇り' '北海道' 'スカスカ' '紅色' '人前']
# 上野ファーム ['カフェ' '庭園' '宿根草' 'ファーム' '北海道' '納屋' '旭川' 'パスポート' 'イングリッシュ' 'ガーデニング' 'ガーデン'
#  '上野' '射的' 'ドラマ' '街道' '英国' '園内' '気候' 'ナシ' '植物']
# 道の駅阿寒丹頂の里 ['丹頂鶴' '釧路' 'トイレ' 'タンチョウ' '温泉' '美術館' '車中' 'ソフトクリーム' 'ツル' '湿原' '土産' '阿寒湖'
#  '阿寒' 'レストラン' '国際' '道路' '丹頂' 'センター' '北海道' '空港']
# 網走市立郷土博物館 ['トド' '建築' '入館' '剥製' 'オホーツク' '市立' '郷土' '北海道' '貝塚' '田上' 'アイヌ' '博物館' 'はく製'
#  '展示' '網走' 'アザラシ' '動物' '文化' 'ドーム' 'ステンドグラス']
# ノーザンホースパーク ['千歳空港' '競走' '乗馬' '優勝' '馬術' 'ポニー' '牧場' '引退' '馬車' 'サラブレッド' '競馬' '北海道' '体験'
#  'ショー' '自転車' 'ホース' '吉田' '厩舎' '名馬' '不明']
# 甘露泉水 ['鴛泊' '利尻' '利尻富士' '登山' '利尻山' '甘露' '泉水' '名山' '火山' 'コース' 'サロベツ' 'ペットボトル'
#  '天然' '登頂' '登攀' '利尻島' '礼文' '北海道' '名水' '北峰']
# ピンネシリ温泉 ['帰り' '掘削' 'ナトリウム' 'サウナ' '鉱泉' '宗谷本線' '切符' '食事' '入浴' '音威子府' 'マグネシウム' '温泉'
#  '定食' '浴槽' '内湯' '有望' '露天風呂' '源泉' '向かい' '浴用']
# 余市宇宙記念館 ['スペース' 'コーナー' '併設' '体験' '北海道' 'プラネタリウム' '錯覚' '小樽' '余市' '宇宙' '展示' '飛行'
#  'シアター' 'アップル' '毛利' 'スペースシャトル' '記念' '土産' '模型' '熱心']
# 厚岸湖 ['カキ' 'ラムサール' '大橋' '霧多布' '越冬' '厚岸' 'かき' '河川' '海水' '食用' 'めし' '湿原' '養殖' '氏家'
#  '安価' '牡蠣' '高台' '恵み' '待合' 'ha']
# 雄阿寒岳 ['登山' '阿寒' '標高' '活火山' '火山' '雌阿寒岳' '雄阿寒岳' '阿寒湖' '阿寒湖温泉' 'マリモ' '阿寒湖畔' '遊覧'
#  '山頂' 'エゾマツ' 'カルデラ' '道東' '気象庁' '釧路' '代表' '北海道']
# 北海道立ゆめの森公園 ['北海道' '遊び場' 'トロッコ' '遊具' '大人' '中標津空港' '滑り台' 'ゾーン' '屋外' 'トランポリン' '屋内' '室内'
#  'コース' '三輪車' '遊び' 'アスレチック' 'ソリ' 'きば' 'イカダ' 'ゴルフ']
# 紋別市立博物館 ['見ごたえ' '北海道' '現代' '紋別' '文化' '市立' 'オホーツク' '流氷' '剥製' '手作業' '博物館' '動物' '漁業'
#  '旧石器時代' '砂金' '展示' '開拓' '映像' '内容' 'はく製']
# 札幌芸術の森 ['野外' '札幌' 'アート' '敷地' '屋外' 'ステージ' '芸術' '工房' '彫刻' '展示' '美術館' 'アトリエ' '作品'
#  '真駒内' 'クラフト' 'sapporo' '開催' '練習' '制作' 'かんじき']
# 神威岳自然公園 ['パーク' '山頂' '山菜' '斜面' '薬湯' 'ゴルフ' '砂川' '中空' '滝川' 'スキー' '十勝' '連峰' '岳温泉' '神威'
#  '北海道' 'きゅう' 'ハーブ' 'ゲレンデ' '景観' '展望']
# 標津サーモン科学館 ['水槽' 'チョウザメ' 'サケ' '標津' 'サーモン' 'イトウ' 'ドクターフィッシュ' '稚魚' 'イクラ' '産卵' '展示' '体験'
#  '水族館' '科学' 'マス' '人差し指' '魚道' '国後' '飼育' 'ふ化']
# のぼりべつクマ牧場 ['牧場' 'しぐさ' '登別温泉' 'ポーズ' 'ゴンドラ' '登別' '萱野' 'アヒル' 'アイヌ' 'ヒグマ' 'クマ' 'やつ' 'チセ'
#  'ロープ' 'ボス' '迫力' 'エサ' 'ウェイ' 'べつ' 'カラス']
# 厚岸湾 ['湾内' '厚岸' '牡蠣' '海産物' '花咲' '釧路' '大黒島' '漁港' '北海道' 'ビンゴゲーム' 'ココ' '高台' '勧め'
#  '安価' '新鮮' '車窓' 'カキ' '養殖' '霧多布' '定食']
# 天都山 ['網走' '展望' '流氷' '一望' '山頂' '監獄' '標高' '中腹' '博物館' '天都山' '刑務所' '送信' 'さくら'
#  'オホーツク' '知床' '網走湖' '民族' '北海道' '経由' '北方']
# 層雲峡温泉 ['山系' '大雪山' '旅館' '紅葉' '硫黄' 'リゾート' 'お湯' '上川' '温泉' '層雲峡' '露天風呂' 'ホテル' '旭川'
#  '大雪' '朝陽' '風呂' '北海道' '宿泊' '入浴' 'キャニオン']
# 稚内温泉 ['利尻富士' '露天風呂' '温泉' '風呂' '保養' 'お湯' '稚内' '最北端' '宗谷' '入浴' 'ノシャップ' '船員' '内湯'
#  '利尻山' '食事' '富士見' 'パレス' '利尻島' '原油' '熊笹']
# 久種湖 ['湖沼' '湖畔' '北海道' 'キャンプ' 'mg' '水芭蕉' '礼文' '湖岸' '礼文島' 'ミズバショウ' '湿地' '頁岩'
#  'ワカサギ' '利尻' '環境' '環境省' '最北端' '環境庁' '砂岩' '栄養']
# かなやま湖 ['ダム' 'ラベンダー' '石狩川' '金山' 'キャンプ' '河川' '釣り' '富良野' '湖畔' '花火' 'カヌー' 'イトウ' '治水'
#  '放流' '発電' '人造湖' '開発' '利水' 'ワカサギ' '補償']
# 北海道立近代美術館 ['北海道' '美術' '地下鉄' '作品' '常設' '公館' '札幌' '美術館' '展示' '展覧' '近代' '特別' '知事' '芸術'
#  '三岸' '好太郎' '当館' 'シャガール' 'コレクション' 'ポーラ']
# 恵山道立自然公園 ['北海道' '開拓' '札幌' '江別' 'シンボル' '記念' '野幌' '北広島' '広大' '恵山' '散歩' '森林浴' '森林公園'
#  '博物館' '原始' 'ウォーキング' '遊歩道' '原生' '敷地' '紅葉']
# 洞爺温泉 ['湖畔' '虻田' '源泉' 'サンシャイン' 'ロングラン' '入浴' '洞爺湖温泉' '洞爺湖' '帰り' '洞爺' '温泉' 'ホテル'
#  '花火' 'いこい' '透明' '温度' '廃業' 'ツル' 'すべすべ' '無色']
# 丸駒温泉 ['温泉' '入浴' '露天風呂' '支笏湖' '水位' 'お湯' '天然' '温度' '風呂' '旅館' '内湯' '湖面' '千歳' '湖畔'
#  'net' '帰り' '浴場' '済み' '部屋' 'らん']
# 横綱千代の山・千代の富士記念館 ['横綱' '千代' '富士' '力士' '九重' '記念' '稽古' '相撲' '土俵' '福島' '合宿' '偉大' '青函' '親方'
#  '部屋' '展示' '大相撲' '松前' '化粧' '姉さん']
# さっぽろばんけいスキー場 ['ろば' 'ナイター' 'スキー' 'ゲレンデ' '初心者' '札幌' '上級' 'コース' '市内' 'パウダースノー' 'けい' 'モーグル'
#  'レンタル' '中級' 'ハーフ' '北海道' '初級' '競技' 'パイプ' 'sapporo']
# 丸瀬布森林公園いこいの森 ['遠軽' '営林局' 'いこい' '格納庫' '雨宮' '静態' '機関' '鉄道' '軌道' '使用' '蒸気' '保存' 'ディーゼル'
#  '客車' '譲受' '森林' '車両' '昆虫' '営林署' 'スハ']
# 昭和新山 ['噴火' 'ウェイ' 'ロープ' '洞爺湖' '昭和新山' '有珠山' '三松' '火山' '正夫' '壮瞥' '洞爺' '牧場' '洞爺湖温泉'
#  '火口' '活動' '活火山' '北海道' '形成' '溶岩' 'クマ']
# 大雪高原温泉 ['温泉' '長靴' '露天風呂' '紅葉' '遊歩道' '白濁' '層雲峡' '風呂' 'お湯' '内湯' '高原' '登山' '入浴' '山荘'
#  '大雪' '営業' '大雪山' 'ヒグマ' '三国峠' '三笠']
# たきかわスカイパーク ['飛行' 'スカイ' '航空' 'パーク' 'ドラえもん' 'たき' '滝川' 'グライダー' '搭乗' 'セスナ' 'スポーツ' '石狩川'
#  '河川敷' 'パラグライダー' '体験' '恐怖症' '北海道' '飛行機' '上空' '着陸']
# ふきだし公園 ['京極' 'タンク' 'ニセコ' 'ポリ' '遊具' '羊蹄山' 'ペットボトル' 'コーヒー' 'ゼリー' '湧き水' '名水' '羊蹄'
#  'マイナス' 'ソフトクリーム' '雪解け' '珈琲' 'ジンギスカン' '水量' '容器' 'イオン']
# 十勝岳 ['火口' '温泉' '噴火' '登山' '十勝' 'お湯' '上富良野' '露天風呂' '凌雲' '火山' '岳温泉' '標高' '北海道'
#  '入浴' '美瑛' '白金' '吹上' '紅葉' '避難' '富良野']
# 北海道立野幌総合運動公園 ['硬式' '体育' '開場' 'ホッケー' '野幌' '運動公園' '野球' '収容' '江別' 'プール' 'テニス' '下旬' 'はまなす'
#  '大会' '国体' '競技' '北海道' '国民' '完成' '能力']
# 道の駅うとろ・シリエトク ['土産' '斜里' '羅臼' '海産物' 'メニュー' '流氷' '知床' 'ウニ' '定食' 'レストラン' 'ウトロ' '海鮮' '案内'
#  '漬物' 'コーナー' 'いくら' '相席' '鮮魚' '情報' '充実']
# 函館聖ヨハネ教会 ['外観' '正教会' '建築' '見学' '公会' 'ライトアップ' 'デザイン' '函館山' '函館' '屋根' '十字架' '教会' '元町'
#  'ヨーロッパ' 'ヨハネ' 'カトリック' 'トス' 'ハリス' '礼拝' '十字']
# 釧路市こども遊学館 ['砂場' '釧路' 'プラネタリウム' '遊学' '科学' '室内' '遊具' 'こども' '実験' '展示' '遊び' '大人' '市民'
#  'タオル' 'シャボン' '屋内' '有料' '工作' '体験' 'コーナー']
# 総合公園だて歴史の杜 ['宮尾' 'キー' '北海道' '伊達' '物産' '登美子' '開拓' '展示' '藍染' '黎明' '農家' 'だて' '野菜' 'ドン'
#  '記念' '迎賓館' 'レストラン' '沿い' '文学' '工房']
# 穂別博物館 ['骨格' '学名' '発見' '恐竜' '博物館' '新種' '亜紀' 'コドモ' 'アンモナイト' '異常' 'ティラノサウルス' '化石'
#  'ハンマー' '首長' '展示' '発掘' '学習' '復元' '町立' '全身']
# 北海道立北方民族博物館 ['北海道' '博物館' '音声' '流氷' 'アイヌ' '資料' '網走' '生活' '文化' '衣装' '展示' 'オホーツク' '民族'
#  '勉強' '北方' '天都山' 'モンゴル' 'ガイド' 'グリーンランド' '暮らし']
# 樽前山 ['樽前山' '支笏湖' '噴火' '登山' '苫小牧' '山頂' '溶岩' '水蒸気' 'ドーム' '火山' '頂上' '噴煙' 'マグマ'
#  '噴出' '活火山' '降灰' '初心者' '火砕流' '物量' '防災']
# 札幌市アイヌ文化交流センター ['アイヌ' 'センター' '暮らし' '北海道' '民族' '資料' '交流' '生活' '勉強' '展示' '衣装' '札幌' '温泉'
#  '住居' '先住民' '定山渓' '文化' 'チセ' '白老' 'ゴールデンカムイ']
# 美利河温泉 ['函館' '奥さん' '温泉' '三本杉' '入浴' 'むちゃくちゃ' '濾過' '場合' 'ログハウス' '褐色' '乗車' 'ジャグジー'
#  'カルシウム' '長湯' '温水' '塩化' 'サウナ' 'ナトリウム' '結婚' '内湯']
# ボッケ ['アイヌ' '阿寒' 'マリモ' '阿寒湖' '阿寒湖温泉' '阿寒湖畔' '泥火山' '遊歩道' '雄阿寒岳' '雌阿寒岳' 'エコ'
#  'ボコボコ' '釧路' '前田' '遊覧' 'ミュージアム' '湖畔' '硫黄' '噴火' 'センター']
# 北海道立オホーツク公園 ['体験' 'ソフトクリーム' 'オホーツク' '屋上' 'マイナス' '天都山' '部屋' '本物' '展示' '網走' '流氷' '濡れ'
#  'タオル' '生き物' 'クリオネ' 'カチコチ' '展望' '北方' '網走湖' '北海道']
# フラワーパラダイス ['パラダイス' '例規' 'クロッカス' '水仙' '大西' '入園' '花園' '管理' 'フラワー' 'バラ' '閲覧' 'レンギョウ'
#  '北見' '継続' 'ツツジ' 'ムクゲ' '都市' '草花' 'ライラック' 'flower']
# 函館市北洋資料館 ['五稜郭' '資料' 'ホームページ' '船長' '展示' '海里' '函館' '航海' '北海道' '歩み' 'ハーモニー' '財団' '北洋'
#  '漁業' '市電' '樺太' '所在地' 'りょう' 'コーナー' '気さく']
# 霧多布温泉 ['露天風呂' '温泉' '風呂' '浜中' 'ルパン' '牛乳' '霧多布' '昆布' '入浴' 'お湯' 'ソフトクリーム' 'ソフト'
#  '高台' '眺め' '厚岸' '清潔' '湿原' '小松' '北海道' '休憩']
# 塩狩峠記念館 ['旭川' '舞台' '資料' '平方' '綾子' '暴走' '作家' '旧宅' '文学' '記念' '三浦' '復元' '小説' '客車'
#  '長野' '列車' '移築' '執筆' '北海道' '展示']
# 二風谷アイヌ文化博物館 ['アイヌ' '民族' '展示' '平取' '博物館' '文化' '北海道' '萱野' '資料' '白老' '生活' 'チセ' '勉強' '住居'
#  '工芸' '興味' '民芸' '楽器' '先住民' 'びら']
# 釧路市立美術館 ['フィッシャーマンズワーフ' 'センター' '学習' '釧路' '生涯' 'アート' '市立' '出世' '芸術' '開館' '重き' '美術館'
#  '人形' '美術' '魔法' '北海道' 'カラクリ' 'モーター' 'ギャラリー' '暗闇']
# ペシ岬 ['ターミナル' '絶景' 'フェリー' '頂上' '稚内' '登り' '北海道' '展望' '利尻島' '礼文' '礼文島' '利尻山'
#  '利尻富士' '利尻' '鴛泊' '会津' '藩士' '入港' '灯台' '眺め']
# 函館山 ['砲台' '夜景' '山頂' '頂上' 'ロープ' 'ウェイ' '登山' 'コロナ' '要塞' '函館' '展望' '御殿山' '函館山'
#  '北海道' 'ゴンドラ' '漁火' '灯り' 'ハイキング' '昼間' 'ロープーウェイ']
# モエレ沼公園 ['レンタル' 'ノグチ' '札幌' '噴水' 'ガラス' 'ピラミッド' 'イサムノグチ' '水遊び' '設計' '自転車' 'イサム' '作品'
#  'aaa' '遊具' 'マウンド' 'レンタサイクル' '散歩' 'ショー' '人工' '園内']
# 新ひだか町アイヌ民俗資料館 ['ひだ' '民族' 'アイヌ' '頭蓋骨' '文化' '儀礼' '外洋' '北海道' '編み物' '砂金' '漁撈' '図書館' '昆布'
#  '資料' '博物館' '農具' 'ペガサス' '近傍' '民俗' '三石']
# 焼尻島 ['天売' '天売島' 'フェリー' 'サフォーク' '焼尻島' '羽幌' '島内' '自転車' '藩士' '閉校' 'イチイ' '苫前' '放牧'
#  'めん' 'レンタサイクル' 'マクドナルド' '一周' '原生' '北海道' '会津']
# 中原悌二郎記念旭川市彫刻美術館 ['作品' '中原' '旭川' '偕行社' '彫刻' '記念' '将校' '師団' '悌二郎' '美術館' '井上' '展示' '北海道' '春光'
#  '陸軍' '文化財' '重要' '社交' '改修' '工事']
# 日本銀行旧小樽支店金融資料館 ['金庫' '銀行' 'トロ' '体験' 'お札' '紙幣' '重厚' '金融' '資料' 'お金' '勉強' '支店' '小樽' '展示'
#  '運河' '入場' '入館' '北海道銀行' '北海道' '手宮線']
# 有島記念館 ['記念' '北海道' '有島' '虻田' '珈琲' '羊蹄山' '展示' '農場' 'ニセコ' 'モカ' '武郎' 'ソフト' '経歴' '末裔'
#  'タワー' '展望' '作家' '高野' '無償' '連山']
# 道の駅みたら室蘭 ['オアシス' 'みなと' '屋台' '冬期' '白鳥' '北海道' '車中' 'コーナー' '夏期' '室蘭' 'キッズスペース' '土産'
#  '水族館' 'ソフトクリーム' '売店' '大橋' 'くじら' '抹茶' 'うずら' '珈琲']
# アルテピアッツァ美唄 ['安田' '炭鉱' '美唄' 'アート' '小学校' '作品' '展示' '廃校' 'カフェ' '校舎' '芸術' '彫刻' '幼稚園'
#  '大理石' 'npo' 'アルテ' '体育館' '水遊び' '美術館' '北海道']
# 黒松内温泉 ['広間' '極楽' '帰り' '北限' '脱衣' '赤ちゃん' '風呂' 'ちゃん' 'ベビ' '貸切' 'ベッド' '温泉' '露天風呂'
#  '入浴' 'お湯' 'パパ' '浴槽' 'フットパス' 'ツル' '電車']
# 天塩岳道立自然公園 ['札幌' '広大' '森林公園' '散歩' '北広島' 'シンボル' '記念' '開拓' '野幌' '北海道' '江別' '森林浴'
#  'ウォーキング' '博物館' '士別' '原始' '遊歩道' '敷地' 'ヒグマ' '原生']
# 北海道立宗谷ふれあい公園 ['稚内' '宗谷' 'ロッジ' '上旬' '北海道' '定員' 'ゴルフ' 'スノーパーク' '谷間' 'チューブ' '期間' '遊技' '大沼'
#  'コース' 'サイト' '展望' 'パーク' '室内' '広場' '冒険']
# 北海道立十勝エコロジーパーク ['パーク' '十勝' '十勝川温泉' 'エコロジー' 'ドーム' 'キャンプ' '水遊び' 'web' '帯広' 'org' '遊具' '室内'
#  '新聞' '芝生' 'archive' 'コテージ' 'https' 'co' 'http' '遊び']
# 旭岳ロープウェイ ['ロープウエー' 'スキー' '山頂' '山麓' '天女' '標高' '大雪山' 'ウェイ' '姿見の池' '紅葉' '姿見' 'ロープ'
#  '長靴' '東川' '雪山' '遊歩道' '登山' '運行' '北海道' 'ロープウェー']
# 三笠市立博物館 ['恐竜' '石炭' '三笠' '化石' 'アンモナイト' '博物館' '展示' '炭鉱' '資料' '圧巻' '北海道' '爬虫類' '野外'
#  '岩見沢' '生態' '児童' '亜紀' 'クリーニング' '開拓' '監獄']
# 函館市青函連絡船記念館摩周丸 ['資料' '連絡' '見学' '展示' '摩周' '船内' '航海' '函館' '函館どつく' '記念' '青森' '青函' '迫力' '北海道'
#  '甲板' '船体' 'メモリアルシップ' '就航' '操舵' '当時']
# 留萌市海のふるさと館 ['存廃' '償還' 'ファンクラブ' '開館' '廃止' '方針' '企図' '開示' '残高' '圧縮' '財政' 'ふるさと' '一括'
#  '健全' '和山' '留萌' 'ニシン' '営利' '変更' '大町']
# 外国樹種見本林 ['北海道' '旭川' '見本' '文学' '綾子' '外国' '三浦' '記念' '小説' '樹木' '観察' '舞台' 'マツ' '寒冷'
#  '国有' 'チップ' 'ヨーロッパ' '木々' '森林' '静か']
# 市立小樽美術館 ['小樽' '美術館' '市立' 'pdf' 'ゆかり' '中村' '美術家' '文学' '作品' '作家' '展示' '収集' '版画' '美術'
#  '閲覧' '条例' '観覧' '手宮線' '入館' '在住']
# コタン温泉 ['コタン' '露天風呂' '入浴' '屈斜路湖' '男女' '湖畔' '温泉' '野天風呂' '屈斜路' '混浴' '白鳥' '脱衣'
#  'ハクチョウ' '水着' '清掃' '弟子屈' 'アイヌ' '北海道' '東岸' 'ペンション']
# 恵山岬 ['恵山' 'ホテル' '遊歩道' 'ドライブ' '白亜' '水無' '真っ白' 'アスレチック' '背後' 'コントラスト' 'しか' '灯台'
#  '東端' '津軽海峡' '函館' '北海道' '渡島' '一望' '太平洋' '立待岬']
# 朱鞠内湖 ['幌加内' 'カヌー' 'ワカサギ' '北海道' 'ダム' '湖岸' 'マス' '豪雪' '湖畔' '旭川' 'キャンプ' '小惑星' '雨竜'
#  '人造湖' '釣り' '遊覧' 'ボート' 'イトウ' '沖合' '長距離']
# 北海道海鳥センター ['天売' 'センター' '環境省' '機械' '天売島' 'バラ' '海鳥' '保護' '展示' '模型' '野生' '生態' '羽幌'
#  'ジオラマ' 'リュック' '体重' '絶滅' '北海道' '入場' 'ペンギン']
# アポイ岳ジオパーク ['パーク' '渋谷' '展示' '番組' 'キャラクター' 'nhk' 'ワン' '興奮' 'アトラクション' 'テレビ' 'ジオパーク'
#  '体験' 'スタジオ' '朝ドラ' '入場' '大人' '収録' '大河ドラマ' 'mt' '車椅子']
# 和寒町郷土資料館 ['ページ' '蒸気' '教育' 'パネル' '再現' '郷土' '開拓' '水曜' '民家' '器具' '機関' '土器' '資料' '展示'
#  '機具' '農業' '名寄' '箪笥' '木蓮' '配属']
# 新冠温泉 ['太平洋' '露天風呂' '風呂' '温泉' '入浴' '高台' 'コード' 'ツル' '夕陽' 'レコード' 'ログハウス' 'お湯' '帰り'
#  '宿泊' 'らん' 'net' 'ホテル' '疲れ' '食事' 'ドライブ']
# 十勝岳温泉 ['十勝' '凌雲' '温泉' '露天風呂' '標高' '紅葉' 'お湯' '入浴' '雲海' '酸性' '高所' '富良野' '北海道' '登山'
#  '上富良野' '吹上' '硫酸' '源泉' '帰り' '岳温泉']
# エドウィン・ダン記念館 ['エドウィン' '寺島' '競馬' '資料' '真駒内' '記念' '畜産' 'ベルギー' 'ダン' '明治' '北海道' '北海道庁' '蕎麦'
#  '札幌' '研究' '接収' '技術' '事務所' '拠点' '展示']
# 谷地頭温泉 ['露天風呂' '市電' '銭湯' '温泉' 'サウナ' '浴槽' 'お湯' '函館' '茶褐色' '温度' 'タオル' '洗い場' '入浴'
#  '茶色' '函館山' '風呂' '浴場' '市営' '立待岬' '源泉']
# 神楽岡公園 ['焼肉' '神楽岡' '旭川' '上川' '花見' '植物' 'バーベキュー' '神社' 'リス' 'ジンギスカン' '野鳥' 'pdf'
#  'キャンプ' '離宮' '炊事' '区域' '大正' '市道' '河川敷' '閲覧']
# 洞爺湖 ['花火' '洞爺湖' '有珠山' '湖畔' 'キャンプ' '温泉' 'サミット' '中島' 'ホテル' '昭和新山' '羊蹄山' '洞爺'
#  '北海道' '洞爺湖温泉' '遊覧' 'ジオパーク' '湖水' '壮瞥' '漁獲' '噴火']
# 余市川 ['釣り' '余市' '後志' '国道' '下流' '落合' '赤井川' '河口' '河川' '仁木' 'カルデラ' '付近' '中流' '北海道'
#  'アユ' '支流' '生息' '羊蹄' '大江橋' 'ニッカウヰスキー']
# 十勝が丘公園 ['時計' '北海道' '足湯' '十勝川温泉' '十勝' 'モール' '帯広' '音更' '遊具' '芝生' 'ひがし' '温泉' 'onsen'
#  '展望' '下旬' '直径' '演出' '音楽' 'イベント' 'facebook']
# はぼろサンセットビーチ ['海水浴' '花火' '焼尻島' '苫前' '徴収' 'ライブ' 'soul' 'ビーチ' '北海道' 'アーティスト' 'ぼろ' '天売'
#  'サマー' '天売島' '大会' '砂浜' 'サンセットビーチ' '羽幌' 'sunset' 'moon']
# 支笏湖温泉 ['休暇' 'ホテル' '温泉' '支笏湖' '千歳' '露天風呂' '宿泊' '食事' '重曹' 'とろみ' 'お湯' '帰り' 'ツル'
#  'すべすべ' '湖畔' '東岸' '札幌' '入浴' '遊覧' '透明']
# 北海道立オホーツク流氷公園 ['北海道' '紋別' '濡れ' '流氷' 'タオル' '体験' '網走' 'クリオネ' 'オホーツク' '屋上' 'マイナス' '展示' '展望'
#  '本物' 'カチコチ' 'ソフトクリーム' '生き物' 'ブロック' '部屋' '天都山']
# 北海道神宮 ['札幌' '神宮' 'お参り' '円山公園' '北海道' '北海道神宮' '円山' '神社' '宮司' '開拓' '久世' '参拝' '義勇'
#  '御朱印' '明治天皇' '一ノ宮' '判官' '祓い' '蝦夷' '境内']
# オシンコシンの滝 ['知床' '斜里' '階段' '水しぶき' 'ウトロ' '水量' 'マイナス' 'オホーツク' '迫力' '道路' '沿い' '国道' '半島'
#  'イオン' '網走' 'しぶき' '方面' '落差' '知床五湖' '休憩']
# 萱野茂二風谷アイヌ資料館 ['平取' '北海道' '富川' '資料' '先住' '少数' '収集' '民族' '展示' '文化' '館長' 'アイヌ' '萱野' '議員'
#  'チセ' '先住民' '博物館' '研究' '参議院' '暮らし']
# カムイト沼 ['湿地' '宗谷' 'カムイ' 'イトウ' 'ハンノキ' 'ヒオウギ' 'オホーツク' 'ゴゼンタチバナ' '群落' '生息' 'トドマツ'
#  '朝霧' '水生' 'アヤメ' '静謐' '管内' 'アイヌ' '原野' '植物' '重要']
# シリパ岬 ['洞窟' '余市' '海岸' '大黒' '若者' '洞穴' 'アイヌ' '蒸留' '断崖' 'ソーラン' '積丹' 'ニッカウヰスキー'
#  '円山公園' '部落' '北海' 'コタン' 'あの世' '北海道' '演歌' 'ニセコ']
# ナウマン温泉 ['温泉' '内湯' 'ナウ' 'お湯' '宿泊' 'ボリューム' '洗い場' 'ツル' '清潔' 'サウナ' '透明' '露天風呂' '済み'
#  '幕別' 'らん' 'マン' '十勝' 'net' '入浴' '海鮮']
# 上川神社 ['神社' '祈願' '北海道' '階段' 'エゾリス' '鎮守' '天満宮' '旭川' '明治' '神楽岡' '上川' 'みこ' '鳥居'
#  'お守り' '初詣' '境内' '合祀' '大神' 'お守' 'お参り']
# オートリゾート苫小牧アルテン ['コテージ' '苫小牧' 'サイト' '大沼公園' 'オート' '温泉' 'キャンプ' 'バンガロー' 'リゾート' 'キャンピング'
#  'キャビン' '大沼' 'しらかば' 'ハウス' '設備' '小沼' '規格' 'ログハウス' 'オートキャンプ' 'ロフト']
# 西村計雄記念美術館 ['画商' '西村' '平和' '美術館' '祈念' '作品' '沖縄' 'アトリエ' 'パリ' '画伯' '共和' '寄贈' '東京' '連作'
#  '勲章' 'フランス' '画家' '記念' '北海道' '入選']
# オホーツク流氷館 ['体験' '展望' 'ソフトクリーム' '本物' 'オホーツク' '天都山' '部屋' 'マイナス' '屋上' '濡れ' '流氷' '展示'
#  '網走' 'カチコチ' 'タオル' 'クリオネ' 'フウセンウオ' '生き物' '映像' 'ソフト']
# 函館公園 ['噴水' 'くに' '観覧' '乗り物' '動物' '遊園' '五稜郭' 'こども' '函館' '函館山' '花見' '北海道' '市電'
#  '青柳' '博物館' '憩い' '博物' '最古' '遊具' 'トロ']
# 姥神大神宮渡御祭 ['姥神' '渡御' '大神宮' '山車' '頭取' '江差' '囃子' '御輿' '巡行' '切り' '若衆' '役員' '本宮' '実行'
#  '祝儀' '先導' '提灯' '神社' '服装' '名刺']
# 石北峠 ['オホーツク' '展望' '通行' '規制' '紋別' '層雲峡' '北見' '大雪' '三国峠' '標高' '国道' '閉店' '茶屋'
#  '上川' '石北峠' '留辺蘂' '売店' '網走' '旭川' '北海道']
# 美瑛岳 ['連邦' 'キキ' '美瑛' '富良野' '十勝' '温泉' '北海道' '登山' 'ラベンダー' 'パッチワーク' '白金' '連峰' '火山'
#  '大雪山' '鳴き声' 'ナキウサギ' '山頂' 'チングルマ' '坊主' 'なだらか']
# 道立自然公園野幌森林公園 ['瑞穂' '森林公園' '大沢' '広大' '林業' '開拓' '試験場' '北海道' '北広島' '札幌' '記念' 'km' 'コース'
#  '江別' '園地' '野幌' '国有' '森林' '博物館' '天然']
# 洞爺湖温泉 ['虻田' '部屋' '花火' '中島' '湖畔' '有珠山' '北海道' '大会' '洞爺' '洞爺湖' '洞爺湖温泉' 'ロングラン'
#  'イルミネーション' '温泉' 'クマ' '壮瞥' 'ホテル' '足湯' '遊覧' '羊蹄山']
# 豊似湖 ['石屋' 'ヘリコプター' '馬蹄' '製菓' 'クマ' '出没' '祖父' '湖畔' 'すれ違い' 'ナキウサギ' 'ハート' 'マス'
#  'cm' '上空' '運転' '鳴き声' '黄金' 'イトヨ' '遊覧' '襟裳岬']
# 北海道立帯広美術館 ['緑ヶ丘' '北海道' 'バルビゾン' '帯広' '美術館' '邦衛' 'ミュージアム' '斬新' '孫娘' '出演' 'ポスター' '美術'
#  'フランス' '篠山' '共演' '作品' '田中' '普及' '休館' '動物']
# 旭川市博物館 ['大雪' '北海道' '民族' '文化' 'ホール' 'アイヌ' 'クリスタル' '旭川' '展示' '博物館' '暮らし' '生活' '屯田'
#  '奥行' '会議' '資料' '勉強' '楽屋' '間口' '開拓']
# 流星の滝 ['トンネル' '瀑台' '流星' '層雲峡' '銀河' '迫力' '落差' '石狩川' '水量' '落石' 'マイナス' '大雪山' '紅葉'
#  'イオン' '節理' '旭川' '国道' '温泉' '流量' '柱状']
# 北海道駒ヶ岳 ['大沼公園' '活動' 'マグマ' '函館' '噴出' '火口' '火山' '噴火' '登山' '駒ヶ岳' '気象庁' '小沼' '北海道'
#  '駒ケ岳' '大沼' 'vei' '崩壊' '名山' '山頂' '防災']
# 霧多布湿原 ['釧路' '霧多布' 'スゲ' '浜中' 'トラスト' 'ナショナルトラスト' '展望' 'ha' '湿原' 'エゾカンゾウ' '厚岸' 'ワタ'
#  '民有' 'npo' '根室' '活動' '保全' 'センター' '北海道' '黄色']
# 函館市縄文文化交流センター ['中空' '遺跡' '縄文' '土偶' '北海道' '土器' '国宝' '展示' '大船' '函館' '出土' '文化' 'センター'
#  'コンクリート' 'ソフトクリーム' '石器' '交流' '体験' '足形' '唯一']
# ユンニの湯 ['露天風呂' 'net' '温泉' 'らん' 'お湯' '風呂' '済み' '入浴' 'ハーブ' 'コーヒー' '遊び' '宿泊' 'ツル'
#  '体験' 'ランチ' '札幌' 'ログハウス' '部屋' 'サウナ' '帰り']
# 沙流川 ['平取' 'アイヌ' 'ダム' '国道' '北海道' '被害' '家屋' '大橋' 'エナジー' '中流' '死者' '死傷' 'サラ' '遺跡'
#  '河川' '斜里' '先住民' '博物館' 'エコ' '呼び名']
# 福島町青函トンネル記念館 ['工事' '開通' '上映' '横綱' '潜水' '開館' '海底' '直上' '建設' '北海道' '福島' '映像' 'シアター' '重機'
#  'トンネル' '展示' '青函' '記念' '吉岡' '定点']
# 平和通買物公園 ['歩行' '旭川' '活性' '店舗' '商店' '実験' '市民' '恒久' '平和' 'リニューアル' '幅員' '工事' '師団' '社会'
#  '天国' '道路' '検討' '駅前' '買物' '車道']
# 雌阿寒岳 ['山頂' '火山' '雌阿寒岳' '水蒸気' '活動' '火口' '阿寒湖畔' '活火山' '阿寒湖' '野中' '噴火' 'オンネトー'
#  '噴煙' '温泉' '登山' '赤沼' '雄阿寒岳' '阿寒' '遊覧' '活発']
# 北見ハッカ記念館 ['ハッカ' '北見' '工場' '蒸溜' '蒸留' 'ハーブ' '実演' '説明' '記念' '製品' '館長' 'ミント' '抽出' '香り'
#  '展示' '産業' '土産' '北海道' '製造' '親切']
# 伊達温泉 ['お湯' '風呂' '露天風呂' 'リーズナブル' '部屋' 'ジンギスカン' '伊達' '宿泊' '入浴' 'メニュー' '帰り' '登別温泉'
#  '温泉' 'ツル' '食堂' '刺身' '食事' '登別' 'サウナ' '銭湯']
# サッポロさとらんど ['公舎' 'ミルク' 'クロスカントリー' '一服' '都市' '支援' '畜産' '推進' '札幌' '長野' '市民' 'スキー'
#  'サッポロ' '地産' 'pr' '組合' '農業' '牧場' '炊事' '手づくり']
# かみゆうべつチューリップ公園 ['満開' '色とりどり' 'べつ' '風車' 'チューリップ' '種類' '球根' '北海道' '品種' '紋別' 'オホーツク' '開花'
#  'チュウリップ' '花弁' '最盛' 'フェア' '広大' '屯田' '遠軽' '咲き']
# 旭川市旭山動物園 ['入園' 'カバ' 'ペンギン' '動物' '旭山' '旭川' 'ホッキョクグマ' '飼育' '親子' 'キリン' '白熊' '展示' 'トラ'
#  'オオカミ' '行動' 'オランウータン' 'アムール' 'アザラシ' '東門' '完成']
# 網走湖 ['ボート' '網走湖' '湖畔' '網走' 'ワカサギ' '女満別' '酸素' '群落' '氷結' 'et' '降水' 'オホーツク' '窒素'
#  '北海道' '流出' '水芭蕉' '湖面' '大空' 'シジミ' 'ミズバショウ']
# 北海道立真駒内公園 ['コンサート' '北海道' 'イベント' '観戦' '会場' '札幌' '地下鉄' 'スケート' '真駒内' '競技' 'アイスアリーナ'
#  'ライブ' 'アリーナ' 'フィギュア' '開門' '五輪' 'google' 'アイスホッケー' 'inc' 'トイレ']
# 釧路市立博物館 ['骨格' 'マンモス' '市立' 'アイヌ' '炭鉱' '不発' 'はく製' 'タンチョウ' '博物館' '釧路' '展示' '湿原' '埋蔵'
#  '文化' 'くし' '全身' '見学' '石炭' '館内' '標本']
# ハルニレ ['ランチ' 'テラス' 'お洒落' 'ハル' '沢村' 'パン' 'ニレ' 'モーニング' '川上' '軽井沢' '星野' '樹皮' '蕎麦'
#  'ショップ' 'コーヒー' '珈琲' 'var' 'おしゃれ' '星野リゾート' '行列']
# 十勝川温泉 ['足湯' '十勝' '温泉' '宿泊' '北海道' '露天風呂' 'お湯' 'モール' '音更' 'ツル' 'ホテル' '十勝川温泉' '帯広'
#  '泥炭' '入浴' '茶褐色' '商標' 'シーニックバイウェイ' '美人' '風呂']
# 北海道立釧路芸術館 ['展示' '美術館' '三岸' '釧路' '北海道' 'レンガ' '作品' '彫刻' '画家' '根室' '芸術' '千住' '観覧'
#  'ページェント' '好太郎' '収蔵' '中学生' 'もも' '高倉' '帯広']
# 元和台海浜公園 ['水質' 'つぶ' 'イベント' 'ウニ' '遊泳' 'シャワー' 'パラソル' 'プール' 'ホタテ' '函館' '国道' '海水浴'
#  '手づかみ' '更衣' '水浴' '安心' '岩場' '開設' '監視' '環境省']
# オニウシ公園 ['満開' 'you' '室蘭' '北海道' '駒ヶ岳' '函館' '駒ケ岳' '見事' '八重桜' '種類' '花見' '青葉' 'まつり'
#  '展望' 'ソメイヨシノ' '国道' 'フルネーム' 'png' '噴水' 'office']
# 北海道立埋蔵文化財センター ['下記' '北海道' 'センター' '黒曜石' '石器' '調査' '保管' '収蔵' '土器' '埋蔵' '野幌' '文化財' '展示'
#  '江別' '普及' '事業' '開館' '土偶' '啓発' '発掘']
# 博物館網走監獄 ['網走' '監獄' '人形' 'リアル' '開拓' '北海道' '囚人' '博物館' '刑務所' '見学' '過酷' 'ゴールデンカムイ'
#  '展示' '犯罪' '流氷' '労働' '放射状' '生活' '勉強' '食堂']
# 山彦の滝 ['氷柱' 'ヒグマ' '裏側' 'マイナス' '山道' '山荘' 'イオン' '山彦' '紋別' 'ダニ' '水量' '迫力' 'しぶき'
#  'サンダル' '北海道' '市街地' 'ツアー' 'スニーカー' 'ダイナミック' '足場']
# 札幌ステラプレイス ['札幌' '買い物' 'レストラン' 'ショッピング' '映画' 'place' '直結' '飲食' 'カフェ' '便利' '大丸' '洋服'
#  '食事' 'モール' '夜景' 'ファッション' 'ショップ' 'コンコース' 'アベニュー' 'ディズニーストア']
# 八食センター ['乾物' '寿司' '購入' '市場' 'イカ' '海鮮' 'ウニ' '食品' 'サバ' '買い物' 'センター' '食材' '海産物' '青森'
#  '魚介' '新鮮' 'ホタテ' '土産' '八戸' '鮮魚']
# 八戸市縄文学習館 ['文化財' '遺跡' '埋蔵' '青森' '分館' '縄文' '学習' '資料' '支所' '開館' '是川' '考古' '八戸' 'センター'
#  '民俗' '荒谷' '収蔵' '南郷' '竪穴' '展示']
# 三陸復興国立公園 ['海岸' '三陸海岸' '復興' '三陸' '被害' '国立' '気仙沼' '青森' '陸中' '宮城' '牡鹿半島' 'リアス式海岸' '船上'
#  '岩手' '八戸' '宮古' '景勝' '石巻' '半島' '震災']
# 恐山 ['霊場' '鉱山' '硫黄' '荒涼' '地獄' '三途の川' '温泉' 'ガス' '火山' '恐山' 'むつ' '菩提寺' '下北' '極楽'
#  '下北半島' '青森' '風車' '地蔵' '匂い' '入山']
# 弘前八幡宮 ['弘前' '本殿' '住宅' '青森' '四隅' '短冊' '重要' '八幡' '反り' '八幡宮' '藩政' '鳥居' '神社' '七夕'
#  '文化財' '鬼門' '拝殿' '鎮守' '参拝' '遷座']
# 宇曽利湖 ['恐山' '流入' 'むつ' 'ウグイ' '酸性' '河川' '極楽' 'ph' '外輪山' '湖面' '中性' 'カルデラ' '青森' '剣山'
#  '下北半島' '棲息' '賽の河原' '硫黄' '菩提寺' '霊場']
# 芦野池沼群県立自然公園 ['大高森' '三景' '遊覧' '五大堂' '海岸' '大観' 'ため池' '島々' '池沼' '藤枝' '多聞山' '松島湾' '松島'
#  '青森' '太宰' '観山' '福浦' '塩釜' '通院' '宮城']
# 立佞武多の館 ['五所川原' 'ねぷた' '祭り' '展示' '青森' 'ねぶた' '迫力' 'スロープ' 'エレベーター' '本番' '津軽' '圧倒'
#  '出陣' '制作' '立ち' '感動' '実物' '映像' '間近' '入館']
# あおもり北のまほろば歴史館 ['津軽海峡' '展示' '大道寺' '漁船' '北前' 'みちのく' '民俗' '道具' '北方' '縄文' 'みちのく銀行' '青森' '財団'
#  '船大工' '青函' '博物館' '土器' 'ほろ' 'ジャンク' '譲渡']
# 櫛引八幡宮 ['一ノ宮' '櫛引' '南部' '神社' 'くじ' '国宝' '八戸' '八幡宮' '白糸' '流鏑馬' '盛岡' '初詣' '文化財' '根城'
#  '八幡' '境内' '鍍金' '社殿' '荘厳' '本殿']
# 津軽岩木スカイライン ['リフト' 'スカイライン' '道路' '岩木' '青森' '津軽' 'カーブ' '岩木山' '登山' '弘前' '自動車' '連続' '競技'
#  '山頂' '百沢' 'ヒルクライム' '岳温泉' '有料' '沿線' '羽黒']
# 蕪嶋神社 ['ねこ' '参拝' '蕪島' '火災' '繁殖' '再建' '八戸' 'ウミネコ' '神社' '工事' 'フン' '社殿' '火事' '海猫'
#  '種差' '鳥居' 'ヒナ' 'お守り' '階段' '焼失']
# 津軽海峡 ['北海道' 'フェリー' '青函' 'さゆり' '函館' '領海' '津軽海峡' '津軽' '大間' '青森' '海峡' '本州' '半島'
#  '石川' 'トンネル' '海軍' '太平洋' '横断' '大間崎' '艦艇']
# 日本基督教団弘前教会教会堂 ['弘前' '牧師' '青森' '重治' '教会堂' '基督教' '公会' '奥義' '中田' '本多' '教会' 'ノートルダム' '山鹿'
#  '宣教師' '元寺' '聖堂' '明治' 'パリ' '長老' 'ゴシック']
# 瑞楽園 ['庭園' '青森' '完成' '大石' 'ワビサビ' '技法' '弘前' '津軽' '飛石' '楽園' '枯滝' '豪農' '高杉' 'ずい'
#  '名勝' '流派' '庭師' '第一人者' '庄屋' '藩政']
# 弘前公園 ['満開' 'まつり' 'ソメイヨシノ' '岩木山' '津軽' '本丸' '紅葉' '弘前' 'さくら' '青森' '祭り' '追手' '植物'
#  '天守閣' 'ねぷた' '花見' '有料' '循環' '季節' 'ライトアップ']
# 是川遺跡 ['出土' '合掌' '中居' '是川' '土偶' '検出' '土器' '八戸' '石器' '中期' '遺物' '遺跡' '縄文' '前期'
#  '晩期' '泉山' '祈り' '発掘' '堀田' '史跡']
# 浅虫夏泊県立自然公園 ['ヘクタール' '島々' '青森' '海岸' '三景' '遊覧' '多聞山' '福浦' '塩釜' '大観' '大高森' '浅虫' '五大堂'
#  '松島湾' '通院' '松島' '観山' '宮城' '景勝' 'ホテル']
# 黄金崎不老不死温泉 ['ネーミング' '津軽' '青森' '風呂' '不老' '温泉' '不老不死' '深浦' 'お湯' '鉄分' '赤褐色' '入浴' 'インパクト'
#  '半島' '身体' '露天風呂' '塩分' 'しら' 'スベスベ' 'ナトリウム']
# 平舘不老不死温泉 ['不老不死' 'お湯' 'スベスベ' '津軽' '青森' '鉄分' '赤褐色' 'インパクト' '身体' '黄金' '帰り' 'ネーミング'
#  '硫黄' '硫酸' '温泉' '風呂' '半島' '入浴' '浜町' '不老']
# 八甲田山雪中行軍遭難資料館 ['行軍' '歩兵' '資料' '連隊' '説明' '展示' '八甲田' '八甲田山' '装備' '陸軍' '悲劇' '犠牲' '青森' '事件'
#  '当時' '遭難' '指揮' '墓地' '映画' 'ビデオ']
# 青森市森林博物館 ['鉄道' '柳川' 'ヒバ' '木造' '庁舎' '貨車' 'スキー' '様式' '青森' '車両' '博物館' '映画' '建築'
#  'ルネッサンス' '営林局' '八甲田山' '森林' 'ルネサンス' '展示' '生態']
# 夜越山森林公園 ['aomori' '温泉' 'コース' 'オートキャンプ' 'クロスカントリー' '平内' 'クリーン' '東津軽' 'サボテン' '大回転'
#  'ラン' '越山' '町営' '植樹' '森林公園' 'スキー' 'rock' '開催' '青森' '皇后']
# くろくまの滝 ['西津軽' '青森' '滝つぼ' '岩木山' 'たき' '支流' '白神' 'km' '中流' '合掌' '自生' '群落' 'ブナ' '難所'
#  '角川' '辞典' '通行止め' '大小' '河口' '到着']
# 尻屋崎 ['灯台' '大間崎' '尻屋崎' '放牧' 'ゲート' '下北' '下北半島' '津軽海峡' 'むつ' '北東' '青森' '埼灯台' '太平洋'
#  '東通' '本州' '白亜' '最果て' '最北端' '恐山' '道路']
# 八戸市水産科学館 ['水産' 'クラゲ' 'ウミネコ' '入館' 'ドクターフィッシュ' 'イカ' '科学' '水族館' '八戸' '水槽' 'きゅう' '展示'
#  '蕪島' 'コーナー' '探査' 'レストラン' '繁殖' '展望' '大人' '生き物']
# つがる地球村 ['スポーツ' 'ゴルフ' 'キャンプ' '地球' '露天風呂' '森田' 'カレー' 'コテージ' 'お湯' '遊具' 'パター' '温泉'
#  '青森' 'レストラン' '野菜' '自転車' '滑り台' '円形' 'アスレチック' 'テニス']
# 盛美園 ['尾上' '津軽' 'モデル' '青森' '洋風' '洋館' '尖塔' '和風' '美園' 'ジブリ' '宝殿' '庭園' '平川' '西洋'
#  '和洋折衷' '大石' '築山' 'スタジオジブリ' '手入れ' '映画']
# 館鼻公園 ['一望' '八戸' '眺望' 'みなと' '漁港' '港町' '遊具' '展望' '河口' '夜景' '工場' '高台' 'タワー' '青森'
#  '地帯' '大橋' '市場' '市内' 'ちょっと' '測候所']
# 青森県立三沢航空科学館 ['科学' '飛行機' '三沢' '大空' '航空' '展示' 'ys' '戦闘' 'インパルス' '自衛隊' '機体' '大人' '体験'
#  '県立' '基地' '青森' '航空機' '空港' 'ひろば' 'ゾーン']
# 青森県立郷土館 ['青森銀行' '展示' '丸山' '県立' '本店' '出土' '郷土' 'aomori' '棟方' '資料' '遺跡' '分野' '志功'
#  '青森' '博物館' '青柳' 'りんご' 'おもり' '土偶' '本町']
# 青函連絡船メモリアルシップ八甲田丸 ['摩周' '八甲' '操舵' '八甲田' '船室' '船内' '青函' '連絡' '見学' 'メモリアルシップ' '展示' '青森' '甲板'
#  '車両' '岸壁' '津軽海峡' '函館' '田丸' '雑居' '煙突']
# 青森県総合運動公園 ['ジム' 'コート' 'プール' '遊具' 'コンサート' '試合' 'テニス' 'スポーツ' '青森' '総合' '運動公園' '大会'
#  '応援' 'アリーナ' '運動' '屋外' 'wbc' '各層' 'ミニバス' 'ドリカム']
# ...
#  '一新' 'センター' '見学' '興奮' '科学' '参加' '遠心']
# 枕崎駅 ['枕崎' '駅舎' '所在' '開業' '最南端' '終着駅' '行司' '山川' '国鉄' '指宿枕崎線' '鹿児島' '九州旅客鉄道'
#  'ホーム' '所有' '解体' '九州' 'jr' 'スーパーマーケット' '移設' '郵便']
# 鰻温泉 ['お湯' '指宿' '西郷' '温泉' '隆盛' '硫黄' 'どん' '鹿児島' '山川' 'うなぎ' '集落' '公衆' '浴場' '蒸気'
#  '風呂' '区営' '狩り' '浴室' '温度' '民宿']
# 万世特攻平和祈念館 ['知覧' '特攻' '特攻隊' '万世' '悲惨' '遺書' '吹上浜' '遺品' '祈念' '基地' '展示' '隊員' '遺影' '平和'
#  '飛行場' '戦争' '手紙' '鹿児島' '偵察' '陸軍']
# 鹿児島神宮 ['島津' '神宮' '本殿' '八幡宮' '隼人' '山幸' '霧島' '神社' '鹿児島' '大隅' '参拝' '宮参り' '八幡' '勅使'
#  '国分' '拝殿' 'お参り' '文化財' '初午' '社殿']
# 吹上浜海浜公園 ['自転車' 'サイクリングロード' '遊具' '監視' 'プール' 'サイクリング' '所長' '海浜' '吹上浜' '鹿児島' '加世田'
#  '仕事' 'ローラースケート' 'キャンプ' 'ワースト' '面接' 'さつま' '持ち主' 'サッカー' '県立']
# 三島村・鬼界カルデラジオパーク ['ジオ' '竹島' '三島' '硫黄' 'ジオパーク' 'ジオサイト' '黒島' 'ラーメン' '地熱' '八戸' 'ジオパークネットワーク'
#  'どんぶり' '認定' '鹿児島' '種差' '魚介' '蕪島' '地球' 'カルデラ' '三陸海岸']
# 花瀬 ['割れ目' '灯ろう' '川床' '色とりどり' '島津' '国名' '景勝' '薄茶' '斉彬' 'カエデ' '河床' '橋口' '田代'
#  '岩盤' '溶結凝' '手足' '五代' '凝灰岩' '川面' '人々']
# 道の駅たるみず ['レストラン' '海鮮' '温泉' 'びわ' 'たるみ' 'ドライブ' '食事' '休憩' '特産' 'イルカ' '桜島' '物産' '錦江湾'
#  '垂水' '足湯' '鹿児島' 'カンパチ' 'ビワ' '養殖' '土産']
# 枚聞神社 ['神社' '一宮' '島津' '一の宮' '川内' '社殿' '開聞岳' '朱色' '薩摩' '参拝' '鹿児島' '御朱印' '新田' '初詣'
#  '指宿' '美神' '唐船' 'お参り' '別表' '本殿']
# 平内海中温泉 ['屋久島' '水着' '海中' '満潮' '露天風呂' '混浴' '入浴' '開放' '干潮' '平内' '脱衣' '海岸' '温泉' '前後'
#  '潮時' '岩場' 'ダイナミック' '着用' '女性' '勇気']
# 阿久根大島 ['バンガロー' '大島' 'シカ' '鹿児島' '渡船場' '水浴' '海水浴' '離島' '無人島' 'キャンプ' '野生' '阿久根'
#  '南国' '新港' '生息' '渡航' 'マリン' '海運' '台風' '海岸']
# 加計呂麻島 ['ガジュマル' '島内' 'ビーチ' '大島' 'フェリー' '奄美' 'レンタカー' 'シュノーケル' '戦跡' 'サンゴ' '名瀬' '海岸'
#  '海上' '集落' 'タクシー' 'スリ' 'ロケ' 'ダイビング' '瀬戸内' '離島']
# 鹿児島県立吉野公園 ['剥製' '照国' '県立' '火山灰' '博物館' '桜島' '天文' '鹿児島' '別館' 'テン' 'プラネタリウム' '展示' '吉野'
#  'プラネタリューム' '化石' '入館' 'たね' '広場' '都市' '奄美']
# 西方海水浴場 ['薩摩' '白砂青松' '海岸' '鹿児島' '海水浴' '西方' '川内' '奇形' 'コカ' 'ファー' '中旬' 'サー'
#  'コーラボトリング' 'バス停' '最寄り' '人形' '南国' '国道' 'シーズンオフ' 'ょう']
# いおワールドかごしま水族館 ['ジンベイザメ' 'ジンベエザメ' '鹿児島' '水族館' 'ショー' '水槽' '黒潮' '桜島' 'イルカ' '体長' 'さつま' '定置'
#  'かご' '展示' '水路' '生簀' '飼育' 'しま' '捕獲' 'ジャンプ']
# 種子島宇宙センター ['衛星' '種子島' '宇宙' 'ロケット' '発射' '組立' '射場' 'iia' 'ml' '観測' 'ii' '開発' '大崎' '搭載'
#  'センター' 'ツアー' '管制' '固体' '吉信' '試験']
# 奄美パーク ['奄美' '離島' '美術館' '有料' '大島' '映像' '展示' '管制塔' '展望' '敷地' 'パーク' '一村' '田中' 'エリア'
#  '文化' 'ゾーン' '空港' '群島' '勉強' '作品']
# 岩崎美術館 ['鹿児島' '清輝' '工芸' '作品' '岩崎' '指宿' 'いわさき' '美術館' '展示' '絵画' '黒田' '作家' '青児' '美術'
#  '東郷' 'ホテル' 'コレクション' '西郷' '利通' '八郎']
# 錦江湾公園 ['遊具' 'バラ' '錦江湾' 'ロケット' '平川' 'アスレチック' '動物' '桜島' '模型' 'オブジェ' '連れ' '鹿児島'
#  '天文台' '高台' '展望' '広場' '望遠鏡' '子ども' '大人' '電波']
# 種子島 ['中学校' '熊毛' '西之表' '種子島' '運航' '鹿児島' '町立' '市立' '屋久島' '小学校' '統合' '学校' '鉄砲'
#  '出身' '空港' '航空' '遺跡' '航路' '宇宙' '島間']
# 桜島ビジターセンター ['噴火' '鹿児島' 'フェリー' '火山' '溶岩' 'シアター' '桜島' '足湯' 'ビジターセンター' 'なぎさ' '展示' '蜜柑'
#  'マグマ' '乗り場' '温泉' '映像' 'ジュース' 'ターミナル' '火山灰' 'リーフレット']
# 大浜海浜公園 ['海岸' '名瀬' '大浜' '展望' '東シナ海' '浜辺' '雄大' '砂浜' '海洋' '奄美' 'ビーチ' '亜熱帯' '海水浴'
#  '南国' 'キャンプ' 'サンゴ礁' '海浜' '大島' '夕陽' '竜宮']
# 栗野岳温泉 ['温泉' '蒸し風呂' '地獄' '乳白色' '源泉' '入浴' '硫黄' '湯治' 'ラジウム' '蒸し' '湯船' '長湯' '白濁'
#  '湯冷め' '酸性' 'お湯' '八幡' '西郷' '礬泉' 'ドロ']
# 市比野温泉 ['鹿児島' '浴場' 'お湯' '温泉' 'アルカリ' '湯治' '旅館' '川内' '薩摩' '島津' '天下' '入浴' '単純' '公衆'
#  '光久' 'みどり' '女将' '下之' 'スベスベ' '美人']
# 藺牟田池 ['ボート' '飯盛山' 'ラムサール' '浮島' 'アヒル' 'トンボ' '周り' '形成' '鹿児島' '天然記念物' '泥炭'
#  'サイクリング' '白鳥' '火山' '薩摩' '条約' '川内' '自転車' '周囲' 'coco']
# 道の駅いぶすき ['いぶ' '特産' '指宿' '休憩' '鹿児島湾' 'すき' '焼き鳥' 'ソフトクリーム' '展望' '鹿児島' '新鮮' '野菜' '土産'
#  '桜島' 'パン' 'バラ' 'ドライブ' 'マンゴー' 'レストラン' 'パック']
# 薩摩伝承館 ['白水' '伝承' '展示' '薩摩' 'らん' 'ガイド' '説明' '薩摩焼' '指宿' 'net' '美術' '従業' '焼き物' '宿泊'
#  '済み' '遊び' 'ボランティア' '陶器' '鹿児島' '入館']
# 鹿児島県立博物館 ['プラネタリウム' '黎明' 'テン' '展示' '照国' '本館' '桜島' '鹿児島' '資料' '県立' '図書館' '博物館' 'かご'
#  '考古' '博物' '別館' '化石' '天文' '火山灰' '剥製']
# 維新ふるさと館 ['西郷' '鹿児島' '展示' '偉人' 'ドラマ' 'どん' 'シアター' 'ロボット' '維新' '明治維新' '隆盛' 'ふるさと'
#  '薩摩' '大久保' '利通' '地下' '勉強' '大河ドラマ' '幕末' '映像']
# 甑島 ['上甑' '鹿児島' '列島' '串木野' '川内' '薩摩' '平良' '砂州' 'フェリー' 'カノコユリ' '本土' '離島' '長浜'
#  '鹿島' '集落' '小学校' '九州' '中学校' '高速' 'キビナゴ']
# 甑島国定公園 ['上甑' '串木野' '鹿児島' '列島' '雨晴' '薩摩' '海岸' '川内' '連峰' '立山' '鹿島' '平良' '富山'
#  'カノコユリ' '氷見線' '本土' '小学校' '砂州' '長浜' '九州']
# 甲突川 ['水害' '並木' '鹿児島' '利通' '偉人' '石橋' '河川' '散歩' '維新' '花見' '沿い' '大久保' 'ふるさと' '西郷'
#  '市内' '生誕' '遊歩道' '高麗橋' '天保山' '中央']
# 荒平天神 ['ロープ' '鹿屋' 'ロケーション' '神様' '鹿児島' '砂浜' '海岸' '道真' '神社' '鳥居' '神秘' '参拝' '錦江湾'
#  '学問' '天神' '階段' '岩山' '桜島' '菅原' '自力']
# 霧島アートの森 ['オブジェ' '屋外' '草間' '霧島' 'アート' '芸術' '作品' '野外' '展示' '鹿児島' '彌生' '美術館' '美術'
#  'アーティスト' '鑑賞' '屋内' '映え' '弥生' '国内外' 'sns']
# 鹿児島ふれあいスポーツランド ['遊具' '芝生' 'ランド' 'ラグビー' '広場' 'プール' 'サッカー' 'スポーツ' '鹿児島' '屋内' '県立' '運動'
#  'テニス' '管理' '中山' 'レクリエーション' '谷山' '運動公園' '天然' 'ソフトボール']
# 南洲神社 ['参拝' 'どん' '庄内' '西郷' '神社' '西南' '山形' '鹿児島' '隆盛' '遺徳' '荘内' '座像' '酒田' '戦争'
#  '銅像' '幕末' '桜島' '説明' 'ゆかり' '資料']
# 黒潮の森マングローブパーク ['原生' '探検' '鹿児島' '満潮' '体験' 'パーク' 'カヌー' '広大' '名瀬' 'ジャングル' '黒潮' '大島' 'ツアー'
#  'マングローブ' '奄美' 'インストラクター' 'アクティビティ' 'ガイド' '南国' '展望']
# 照国神社 ['鳥居' '斉彬' '薩摩' '鹿児島' '神社' '島津' '参拝' '西郷' '銅像' '祭神' '城山' '照国' '久光' '天文'
#  '境内' '繁華' '忠義' '御朱印' '立派' 'どん']
# 湯之元温泉 ['湯船' '冷泉' '入浴' '炭酸泉' 'お湯' '宮崎' '濃度' '炭酸' '鉱泉' '温泉' '源泉' '交互' 'サイダー' '風呂'
#  '湯治' '薩摩焼' '疲れ' '温度' '褐色' 'ツル']
# 上野原遺跡 ['国分' '住居' '竪穴' '上野原' '火山灰' '縄文' '土器' '遺跡' '桜島' '鹿児島' '集落' '体験' '生活' '埋蔵'
#  '確認' '早期' '発掘' '定住' '復元' '霧島']
# 鹿児島県 ['新幹線' '鹿児島' '放送' 'fm' '川内' '桜島' '屋久島' '奄美' '九州' '種子島' '霧島' '大隅' '薩摩' '大島'
#  '航路' '志布志' '開局' 'ラジオ' '大隅半島' '徳之島']
# 道の駅くにの松原おおさき ['土産' 'あす' 'サザエさん' '特産' 'モニュメント' '焼酎' 'クワガタ' '銀色' '温泉' '大崎' 'オブジェ' 'カブトムシ'
#  '目印' 'オープニング' 'レストラン' '鹿児島' 'さき' 'くに' '志布志' '物産']
# 揖宿神社 ['鹿児島' '群生' '東之' '勅使' '樹齢' '指宿' '有形' '塩土' '本殿' '巨木' '社殿' '岩永' '天命' '文化財'
#  '神社' '天然記念物' '大明神' '摂社' '新宮' '田の神']
# 尚古集成館 ['斉彬' '切子' '産業' '殿様' '遺産' '鹿児島' '島津' '革命' '薩摩' '品々' '展示' '共通' '機械' '幕末'
#  '資料' '工場' '集成' '世界' '博物館' '洋風']
# 池田湖 ['オオウナギ' 'ネッシー' 'パラダイス' '九州' '池田' '巨大' '湖畔' '指宿' '目撃' 'うなぎ' '鹿児島' 'ウナギ'
#  'ネス' 'カルデラ' '生物' '開聞岳' '菜の花' '伝説' '土産' '花畑']
# 鹿児島市立美術館 ['清輝' '常設' '作品' 'モネ' '西郷' '薩摩' '青児' '美術館' '天文' '画家' '鹿児島' '展示' '美術' '特別'
#  '鶴丸' '島津' '黎明' '切子' 'ダリ' '芸術']
# トンボロ ['地形' 'トンボ' '火山' '砂州' '作用' '水面' 'イタリア' '沿岸' 'マグマ' '海底' '干潮' '上甑' '陸地' '海面'
#  '神秘' '特殊' '独特' '島々' '活動' '光景']
# 高千穂峰 ['新燃岳' '霧島' 'ミヤマキリシマ' '韓国' '天孫' '登山' '降臨' '登り' '高千穂' '高千穂峰' '高千穂河原' '鹿児島'
#  '火山' '火口' '頂上' '坂本' '山頂' '下山' '宮崎' '初心者']
# 西郷公園 ['仁王立ち' '土産' '展示' '隆盛' '銅像' '対決' '西郷' '迫力' '空港' '鹿児島' '溝辺' 'レンタカー' '霧島'
#  'どん' '飛行機' '軍服' '入場' '撮影' '人物' '西南']
# 行人岳 ['中継' '不動明王' '雲仙' '普賢岳' '出水' '行人' '川床' '鹿児島' '山頂' '長島' '天草諸島' '天草' 'シベリア'
#  '平尾' '山岳' '煩悩' 'うに' '離合' '線香' '道路']
# 紫尾温泉 ['共同' '神社' '美人' 'さつま' 'トロ' 'スベスベ' 'お湯' '温度' '硫黄' 'ツル' '温泉' '浴場' '源泉' '鹿児島'
#  '宮之城' 'ph' '薩摩' '旅館' '出水' '浴槽']
# 鹿屋市鉄道記念館 ['展示' '電車' '国鉄' '駅舎' '車両' 'トロ' '資料' '鉄道' 'ディーゼル' '博物館' '鹿児島' '鹿屋' '記念'
#  '京都' '保存' '岡山' 'sl' '継承' '機関' '青函']
# 仙巌園 ['集成' '桜島' '錦江湾' '別邸' '鹿児島' '切子' '御殿' '庭園' '園内' '島津' '借景' '斉彬' '殿様' '薩摩'
#  '新駅' '架線' 'どん' '遺産' '体験' '大河ドラマ']
# 桜島 ['噴火' '火山' '火口' 'フェリー' '鹿児島' '桜島' '火山灰' '降灰' '噴出' '活動' '爆発' '溶岩' '噴煙' '南岳'
#  '展望' '観測' '有村' '警戒' '錦江湾' '姶良']
# フラワーパークかごしま ['指宿' '南国' 'イルミネーション' '植物' '鹿児島' 'フラワー' 'マンゴー' 'パーク' '園内' '亜熱帯' 'カート'
#  '長崎鼻' '薩摩半島' '温室' '季節' 'しま' '山川' '展望' '蝶々' '広大']
# 上野原縄文の森 ['竪穴' '集落' '住居' '遺跡' '鹿児島' '上野原' '縄文' '埋蔵' '体験' '発掘' '財団' '展示' '復元' '生活'
#  '早期' '調査' '保存' '定住' '文化財' '再現']
# 漫湖 ['マングローブ' '干潟' '渡り鳥' '那覇空港' '観察' '水鳥' '沖縄' '那覇' '条約' '湿地' 'ラムサール' '飛来'
#  '保護' 'バードウォッチング' 'たいこ' '琉球' '野鳥' '豊見城' '名前' 'シギ']
# 沖縄美ら海水族館 ['イルカ' '水族館' '黒潮' 'ショー' '水槽' 'ジンベイザメ' '那覇' '那覇空港' 'ジンベエザメ' 'マナティー' '海洋'
#  '名護' '沖縄' 'マンタ' '飼育' 'ウミガメ' '巨大' 'サメ' 'エイ' '値上げ']
# 下地島空港 ['航空' '空港' 'パイロット' '訓練' '沖縄' 'チャーター便' '誘致' '自衛隊' '宮古' '飛行場' '飛行機' '就航'
#  'ターミナル' '滑走' '伊良部' '宮古島' '旅客機' '三菱地所' '旅客' 'エンド']
# 与那国島 ['レンタカー' '島内' '診療' '西崎' 'バリ' '台湾' '石垣島' '国境' '遺跡' '西端' '沖縄' '琉球' '離島'
#  'ダイビング' '八重山列島' '与那国島' '海底' '飛行機' 'dr' '原付']
# ピナイサーラの滝 ['マングローブ' 'イオン' '滝の上' '西表' 'マイナス' '参加' '迫力' '滝つぼ' '沖縄' 'ツアー' '西表島'
#  'トレッキング' '落差' 'カヌー' '滝上' 'カヤック' '水量' '神秘' '滝の下' '体験']
# 福州園 ['記念' '庭園' '国際' '福建' 'すっぽん' '県庁' '友好' '園内' '松山' '沖縄' '那覇' 'レール' '久米' '琉球'
#  '中国人' '入園' '締結' '様式' '中国' '異国']
# 渡口の浜 ['海水浴' '大橋' '沖縄' 'パウダー' '海岸' '伊良部島' 'ビーチ' '宮古島' '白砂' 'サラ' '透明' '砂浜' '伊良部'
#  '遠浅' '真っ白' 'エメラルド' 'サンド' '宮古' 'シュノーケル' '西端']
# 国際通り ['三叉路' 'コロナ' '交差点' '琉球' '那覇' '国際' '通り' '停車' '安里' '県庁' '沖縄' '松尾' '土産' 'バス停'
#  '店舗' '繁華' 'マイル' '路線' '市場' '車両']
# 宮古島市総合博物館 ['文化' '宮古島' '宮古' '平良' '展示' '博物館' '総合' '資料' '充実' '民俗' '沖縄' '内容' '支配' 'ユネスコ'
#  '生活' '体制' '冊子' '市町村' '好奇' '知的']
# トロピカルビーチ ['海水浴' '砂浜' 'センター' 'スポーツ' 'マリン' 'bbq' '那覇' '宜野湾' 'ビーチ' '古島' 'バーベキュー'
#  'トロピカル' 'コンベンション' '遠浅' '沖縄' '海浜' 'シャワー' '安心' '遊泳' 'ネット']
# 伊是名島 ['森林公園' '運天' '民宿' '展望' '泡盛' '東方' '沖縄' '住人' '生誕' '今帰仁' 'ハブ' 'フェリー' '北部'
#  '離島' 'ビリ' '本島' 'ビーチ' '北方' '座間味' '民泊']
# 波照間島 ['ニシ' '石垣島' '波照間' '竹富' '島内' '自転車' '最南端' '欠航' '石垣' '八重山' '集落' '星空' 'ビーチ'
#  '離島' '沖縄' 'サトウキビ' '運航' 'ブルー' '発電' 'レンタサイクル']
# 名護湾 ['沖縄' '本島' '名護' 'ドライブ' 'ビーチ' 'コバルトブルー' '本部' '那覇' '眺め' '国津' '北部' '海岸' '湾口'
#  '東シナ海' '半島' '海水浴' '砂浜' 'サミット' '城跡' '真珠']
# 宜野湾市立博物館 ['民俗' '文化' '模型' '資料' '考古' '博物館' '沖縄' '旧石器時代' '分野' '休館' '火曜' '新城' '入館'
#  '美術館' '普天間' '展示' '宜野湾' '市立' '勉強' '祝祭']
# 真栄田岬 ['ビーチ' 'サンゴ礁' 'ダイビング' 'ツアー' 'ダイバー' 'エントリー' 'シャワー' '恩納' 'インストラクター'
#  'シュノーケリング' '洞窟' '沖縄' '参加' 'シュノーケル' '透明' 'サンゴ' 'スキューバダイビング' '体験' '思い出'
#  '名護']
# 古宇利島 ['送水' 'フルーツ' 'ビーチ' 'ハート' '砂浜' '利島' 'パラソル' 'タワー' 'ロック' '本島' 'ドライブ' 'スタッフ'
#  '今帰仁' '感動' 'オーシャン' '沖縄' '大橋' '古宇' '男性' '村立']
# カンピレーの滝 ['八重山' '聖域' 'トレッキング' '交際' '落差' '終点' 'クルーズ' '沖縄' '西表' '軍艦' '上流' '西表島' 'カン'
#  '遊覧' '迫力' 'マングローブ' 'プレー' '竹富' '岩場' '意味']
# 久高島 ['島内' '本島' '離島' 'フェリー' '自転車' '神の島' '斎場' 'レンタサイクル' '南城' 'パワー' '沖縄' '神聖'
#  '琉球' '禁制' '御嶽' '聖地' '神様' '男子' '祈り' '王朝']
# 内間御殿 ['金丸' '竹垣' '地頭' '西原' '旧宅' '神殿' '没後' '大殿' '御殿' '沖縄' 'トタン' '瓦葺' '始祖' '石垣'
#  'ふじ' '盗賊' 'さわ' '改築' '中頭' '大屋']
# 来間島 ['カフェ' '絶景' 'ブルー' 'サトウキビ' '砂浜' '離島' 'ビーチ' '豊か' '宮古' '宮古島' '南西' '展望' '島内'
#  '宮城' 'おしゃれ' '大橋' 'のどか' '沖縄' '前浜' '雑貨']
# 宮古島市熱帯植物園 ['沖縄' '工芸' '南国' '工房' '宮古島' '熱帯' '宮古' '樹木' '体験' '色彩' '生息' '造園' '古島' '入園'
#  '植物' '園内' '亜熱帯' 'デジカメ' 'ならでは' '野鳥']
# 平和祈念公園 ['戦没' '平和' '悲惨' '司令' '戦跡' '県営' '沖縄' '本島' '霊域' '戦争' '資料' '国定' '慰霊' '祈念'
#  '中将' 'ゆり' '大切' '豊か' '恒久' 'アメリカ']
# 砂山ビーチ ['アーチ' '宮古島' '沖縄' '砂山' '砂浜' 'ビーチ' '立ち入り' 'トンネル' '宮古' '人気' '禁止' '真っ青' '金網'
#  'グラデーション' 'コントラスト' 'エメラルド' '白砂' '海水浴' '海岸' '絶景']
# 浦内川 ['沖縄' '西表島' 'マングローブ' '西表' 'ジャングル' '遊覧' '河口' 'トレッキング' '最長' 'カヌー' '船着'
#  'クルーズ' '上流' '干潟' '八重山' 'カヤック' '満喫' '稲葉' '生息' '亜熱帯']
# 伊良部島 ['沖縄' '空港' '宮古島' '宮古' '大橋' 'ビーチ' '伊良部島' '伊良部' '佐良' 'レンタカー' 'エンド' 'ドライブ'
#  '離島' '島内' '佐和田' 'ターミナル' '下地' '平良' 'ブルー' '開通']
# おきなわワールド ['ガラス' 'ショー' '踊り' '沖縄' '琉球' 'ワールド' '鍾乳洞' '洞窟' '鍾乳石' 'ハブ' 'ヘビ' '石垣島' '体験'
#  'エイサー' '王国' 'サー' '神秘' '文化' '探検' '博物']
# 沖縄県総合運動公園 ['体育館' 'スポーツ' '競技' '陸上' '運動公園' '沖縄' '総合' 'プール' 'サッカー' '泡瀬' '遊具' 'テニス'
#  'ボート' '運動' '自転車' 'コート' 'ゾーン' 'ランニング' 'サイクリング' 'キャンプ']
# 沖縄アウトレットモール・あしびなー ['沖縄' 'アウトレット' 'けら' 'アウトレットモール' '買い物' 'ショップ' 'ショッピング' '店舗' '那覇空港' '豊崎'
#  '空港' 'セール' 'ブランド' 'モール' '豊見城' '外国' '商品' 'グッチ' '食事' '那覇']
# 宮古島海宝館 ['細工' '宮古島' '城辺' '館長' '土産' '泡盛' '世界中' '貝殻' 'ガス' '貝類' '沖縄' '展示' '保良' '黒糖'
#  'ミュージアム' '製品' '宮古' 'レストラン' '実証' 'ツアー']
# 由布島 ['蝶々' '西表島' '水牛' 'ブーゲンビリア' 'ツアー' '沖縄' '浅瀬' '離島' '島内' '西表' '牛車' 'おじさん'
#  '石垣島' '植物' '亜熱帯' '竹富' '三味線' 'オオゴマダラ' '楽園' '南国']
# 海軍司令部壕 ['当時' '司令' '自決' '平和' '大田' '悲惨' '沖縄' '戦争' '那覇' '海軍' '防空壕' '電報' '状況' 'ゆり'
#  '飛行場' '兵士' '戦闘' '豊見城' '資料' '部屋']
# 新城海岸 ['シュノーケリング' '沖縄' '砂浜' '海岸' 'シャワー' '新城' 'ビーチ' 'シュノーケル' '宮古島' '更衣' '遠浅'
#  'トイレ' '透明' 'サンゴ礁' 'サンゴ' '珊瑚' 'パラソル' 'ノミ' '宮古' '熱帯魚']
# 普天満宮 ['基地' '琉球' '権現' '御朱印' '宜野湾' '沖縄' '間宮' '熊野' '神社' '天満宮' '参拝' '洞窟' '洞穴' '奥宮'
#  '参詣' '普天間' '巫女' '鍾乳洞' '神道' '社務']
# 小浜島 ['自転車' 'リゾート' 'サトウキビ' '竹富' '八重山' 'シュガー' 'バイク' '西表島' 'ホテル' '島内' 'ビーチ' '大岳'
#  '石垣' '石垣島' '電動' 'ロード' '小浜' '離島' 'フェリー' '沖縄']
# 北大東島 ['南北' '孤島' '製糖' '方言' '開拓' '分布' '沖縄' 'ia' '本島' '固有' '採掘' '危惧' '絶滅' '大東'
#  'パパイヤ' '八丈島' '玉置' '移住' '小笠原諸島' '天然記念物']
# 倉敷ダム ['倉敷' '沖縄' '管理' '取水' '水遊び' '慶山' '展望' '弾薬' '漏水' '建設' 'タワー' 'ピクニック' 'ダム'
#  '不発' '返還' '真水' 'カード' 'ベタ' '事務所' '資料']
# イオンモール沖縄ライカム ['ライ' '沖縄' 'モール' '土産' '買い物' 'フード' 'ショッピング' 'カム' '店舗' '琉球' 'イオン' '水槽' '那覇'
#  '屋慶名' 'コート' '水族館' 'ショップ' '充実' '東陽' '食事']
# 渡嘉敷島 ['沖縄' '離島' 'フェリー' '本島' '高速' '那覇' 'シュノーケリング' 'ビーチ' '諸島' 'シュノーケル' '熱帯魚'
#  'ツアー' 'マリン' '本土' 'ホエールウォッチング' 'ダイビング' '座間味' '帰り' '島内' '透明']
# 八重岳 ['本部' 'アメリカ' '開花' '部隊' '沖縄' '半島' '世帯' '名護' '通信' '本島' '山頂' '宇土' '並木' '北部'
#  'まつり' '放送' 'mhz' '周波数' '免許' '祭り']
# 川平湾 ['グラス' 'ウミガメ' '遊覧' 'レンタカー' '川平' 'エメラルド' '石垣島' '石垣' 'キレイ' 'サンゴ' 'カメ' '透明'
#  '沖縄' 'ブルー' 'ボード' 'ボート' '湾内' '砂浜' '珊瑚' '乗船']
# 浜比嘉島 ['洞穴' '本島' '海中' 'ビーチ' '沖縄' '道路' '琉球' 'パワー' '離島' '浜村' '大橋' '集落' 'isbn'
#  'ハート' '架橋' '地区' '民家' '開闢' 'ドライブ' '工場']
# 末吉公園 ['豊か' '南国' '末吉' '森林浴' '早咲き' '病院' '那覇' 'ジャングル' '史跡' 'レール' '沖縄' '市立' 'モノレール'
#  '散歩' '木々' '植物' '森林' '空気' '市内' '標本']
# うえのドイツ文化村 ['うえの' '救助' '沖縄' 'テーマパーク' '座礁' '文化' 'ドイツ' '宮古島' '宮古' '入場' 'ベルリン' '難破' '異国'
#  '再現' 'チャペル' 'ハート' '皇帝' '本物' '上野' '商船']
# 恩納村博物館 ['資料' '恩納' '展示' 'おんな' '情報' '生活' '暮らし' '博物館' '図書館' '文化' '勉強' '沖縄' 'センター'
#  '入場' '市場' '入館' '見学' '開館' 'ソファー' 'くらし']
# 奥武島の畳石 ['不思議' '六角形' '節理' '甲羅' '久米' '溶岩' '光景' '沖縄' 'キャンプ' '干潮' 'はて' '島内' '海岸' '深層'
#  'ウミガメ' 'トライアスロン' '階段' '割れ目' 'ビーチ' '幾何']
# 吉野海岸 ['宮古島' 'サンゴ' 'ビーチ' '吉野' '海岸' 'シュノーケリング' '熱帯魚' '砂浜' '沖縄' '宮古' 'シャワー' '更衣'
#  '透明' 'シュノーケル' 'サンゴ礁' '珊瑚' '城辺' 'シーズンオフ' 'おだやか' '海水浴']
# 屋我地島 ['ビーチ' 'サトウキビ' '集配' 'ラジオ' '中継' '受信' 'のどか' '島内' 'マングローブ' '今帰仁' '本島' '大橋'
#  '名護' '沖縄' '楽園' '番号' '古宇' '郵便' '利島' 'ドライブ']
# 津堅島 ['貝塚' '人参' '離島' '民宿' '栽培' '沖縄' 'ニンジン' '本島' 'フェリー' 'ダイビング' '診療' 'にんじん' '御嶽'
#  'ビーチ' 'リー' 'ハー' 'リーフ' 'マリン' '島内' '無人島']
# 瀬底ビーチ ['沖縄' 'ビーチ' 'シュノーケル' 'ヒルトン' '砂浜' 'シュノーケリング' '透明' '伊江島' 'マリン' '離島' '遊泳'
#  '遠浅' '海水浴' '珊瑚' 'ホテル' '本島' 'リゾート' 'パラソル' 'エメラルド' 'ネット']
# ブセナ海中公園 ['観察' 'ボート' '水族館' '水中' '熱帯魚' '海中' 'サンゴ' '透明' 'グラス' 'カラフル' '展望' '沖縄' 'ボード'
#  '海底' '名護' '天然' '螺旋' 'シャトル' '先端' '階段']
# 阿嘉島 ['マリリン' 'ビーチ' 'フェリー' '離島' 'シュノーケル' '沖縄' '那覇' 'シュノーケリング' '座間味' 'サンゴ'
#  'ダイビング' '諸島' '北浜' '島内' 'シロ' '集落' '珊瑚' '帰り' '本島' '透明']
# ムーンビーチ ['沖縄' '砂浜' '宿泊' 'ムーン' 'ハワイ' '海水浴' 'プライベート' 'ホテル' '透明' 'ビーチ' '恩納' 'リゾート'
#  '南国' '西海岸' 'ヤシ' 'パラソル' 'プール' 'セット' '遊泳' 'サン']
# 大岳 ['展望' '西表' '八重山諸島' '大岳' '八重山' '小浜' '頂上' '階段' '島々' '西表島' '電動' '島内' '石垣'
#  '東屋' '標高' '黒島' '自転車' '絶景' '一望' '大相撲']
# 斎場御嶽 ['御嶽' '斎場' '門口' '入口' '本島' '最奥' '物産' '森林' '王国' '遺産' '東陽' '聖地' '琉球' '禁制'
#  '増加' '南城' '那覇' '沖縄' '休息' '入場']
# 道の駅かでな ['軍機' '離陸' '沖縄' '屋上' '離発着' '飛行場' '爆音' '滑走' '飛行機' '空軍' '戦闘' '基地' '土産' '展望'
#  '離着陸' '休憩' '一望' 'ハンバーガー' '軍用' 'バーガー']
# 佐喜眞美術館 ['基地' '戦争' '沖縄' '美術館' '普天間' '屋上' '展示' '俊夫' '上原' '飛行場' 'テーマ' '中城' '平和' '丸木'
#  '宜野湾' '反戦' '作品' '夫妻' '見ごたえ' '私設']
# 具志堅用高記念館 ['ボクサー' 'リング' 'トロフィー' 'ベルト' 'ボクシング' 'チャンピオン' '記念' '現役' '試合' '防衛' '石垣島'
#  'グローブ' '展示' '石垣' '世界' '記録' '映像' 'フライ' '王座' 'モニター']
# 海中道路 ['本島' '車線' '沖縄' 'エメラルド' '石油' 'はし' '天気' '半島' 'あや' '宮城' '海中' 'ドライブ' '道路'
#  'サイド' '満潮' 'レンタカー' 'マリン' 'グリーン' 'オープンカー' '左右']
# 野底岳 ['山頂' '頂上' '伝承' '登山' '石垣島' '石垣' '林道' '強制' '黒島' '移住' '恋人' '恋仲' 'オモト' '絶景'
#  '最短' 'サトウキビ' '悲しみ' '山登り' '農道' '役人']
# 東南植物楽園 ['楽園' 'net' '南国' 'レストラン' '遊び' '植物' '亜熱帯' 'カピバラ' 'らん' '沖縄' '動物' 'イルミネーション'
#  '東南' '体験' '園内' '済み' 'カート' 'ランチ' 'バイキング' 'バード']
# 大石林山 ['奇岩' '沖縄' 'コース' 'パワー' '大石' 'ガジュマル' '林山' '名護' '本島' '亜熱帯' '国頭' '那覇空港'
#  'カルスト' 'bt' '最北端' '北部' '石灰岩' '国立' '展望' '与論島']
# 伊平屋島 ['スノーケル' '本島' '離島' '与論島' 'フェリー' '沖縄' '運天' '今帰仁' '最北端' '泡盛' 'キャンプ' 'マラソン'
#  '南西諸島' 'レンタカー' '本部' '酒造' '島尻' '有人' '渡船' '島内']
# 佐和田の浜 ['巨岩' '独特' '光景' '点々' '海岸' '岩場' '伊良部島' '佐和田' 'ビーチ' '伊良部' 'ドライブ' '遠浅' '干潮'
#  '沖縄' '点在' '砂浜' '空港' '宮古' '宮古島' '津波']
# 沖縄県立博物館・美術館 ['那覇' '美術館' 'もろ' '文化' '県立' '展示' '沖縄' '博物館' 'まち' '館長' '常設' '琉球' '新都' '作品'
#  'レール' '企画' '計画' '新館' '現代' '問題']
# 竹富島 ['公民館' '議会' 'フェリー' '沖縄' '集落' '牛車' '石垣島' '石垣' '竹富' '自転車' '八重山' '島民' '島内'
#  '憲章' '水牛' '御嶽' '離島' '桟橋' '種子' 'ビーチ']
# 南大東島 ['製糖' '飛行機' 'サトウキビ' '沖縄' '離島' 'クレーン' '大東' '玉置' '上陸' 'フェリー' '隆起' '島内' '開拓'
#  '鍾乳洞' '鍾乳石' '入植' '本島' '那覇空港' '那覇' '湖沼']
# 粟国島 ['凝灰岩' 'ダイビング' '飛行機' 'ハブ' 'ソテツ' '鍾乳洞' '那覇' 'フェリー' '離島' '沖縄' 'レンタカー'
#  'サトウキビ' '山羊' '島内' 'ビーチ' '運航' '手つかず' '便数' 'km' '村営']
# 嘉数高台公園 ['陣地' '部隊' '普天間' 'アメリカ' '基地' '沖縄' '戦い' '高台' '戦車' '戦闘' '大隊' '激戦' '歩兵' '師団'
#  '連隊' '戦力' '攻撃' '高地' '展望' '反撃']
# ネオパークオキナワ ['名護' 'エサ' '園内' 'フラミンゴ' '沖縄' '動物' '軽便鉄道' '放し飼い' 'net' '済み' 'ネオ' '飼育' 'パーク'
#  '動植物' '体験' '繁殖' 'らん' 'モルモット' 'ゾウガメ' 'バード']
# 瀬長島 ['グスク' '飛行機' '琉球' '沖縄' '本島' '空港' '那覇空港' '豊見城' 'リゾート' 'ハンバーガー' '商業' '食事'
#  '離発着' 'テラス' '離着陸' '那覇' 'ショッピング' 'カフェ' '飲食' 'ショップ']
# 名護城 ['名護' '北山' '城跡' '一望' '沖縄' '国頭' '森林' '名所' 'オリオンビール' 'グスク' '今帰仁' '石垣' '城郭'
#  '階段' '展望' '中央' '高台' '眺め' '遺構' 'さくら']
# 渡名喜島 ['民家' 'アクティブ' 'のどか' '満喫' '集落' 'ビーチ' '離島' 'くぎ' '無人島' '島民' '沖縄' 'ダイビング' '本島'
#  '静か' '人口' 'フェリー' '那覇' '行き' 'ウミガメ' '透明']
# イムギャーマリンガーデン ['遊歩道' '展望' '宮古島' 'シュノーケル' 'シュノーケリング' 'ビーチ' '入り江' 'サンゴ' '初心者' '穏やか' '外海'
#  '入江' '透明' '宮古' '珊瑚' 'ダイビング' '海水浴' 'マリン' 'ノミ' '海浜']
# DMMかりゆし水族館 ['景品' 'クイズ' '着用' '沖縄' 'ナマケモノ' '水族館' '映像' '水槽' 'マスク' '展示' '動物' '生き物'
#  'ベビーカー' '障害' '手帳' '正解' 'アプリ' '強要' '内容' '出口']
# 西表島 ['マングローブ' '沖縄' '西表' 'ツアー' '石垣島' 'ジャングル' '上原' 'カヌー' '大原' '竹富' '西表島' '石垣'
#  '水牛' '白浜' 'カヤック' '離島' '中継' '八重山' 'マラリア' 'トレッキング']
