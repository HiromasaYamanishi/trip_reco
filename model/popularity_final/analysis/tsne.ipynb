# %%
spot_emb = torch.load('/home/yamanishi/project/trip_recommend/model/popularity_final/data/spot_emb.pt').cpu().detach().numpy()
df = pd.read_csv('/home/yamanishi/project/trip_recommend/data/jalan/spot/experience_light.csv')
from sklearn.manifold import TSNE
def visualize(h, color):
    z = TSNE(n_components=2, random_state=30).fit_transform(h)

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %%
visualize(spot_emb, np.log10(df['review_count'].values))

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['pref_label']=le.fit_transform(df['prefecture'])

# %%
df['pref_label']
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 42847    39
# 42848    39
# 42849    39
# 42850    39
# 42851    46
# Name: pref_label, Length: 42852, dtype: int64

# %%
visualize(spot_emb, df['pref_label'].values)

# %%
def get_jenre(text):
    text = text.split(',')[0]
    return text
df['jenre_'] = df['jenre'].apply(get_jenre)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['jenre_label']=le.fit_transform(df['jenre_'])
visualize(spot_emb, df['jenre_label'])
