# %%
from recommendation import get_data
data = get_data(category=True, city=True, prefecture=True)

# %%
data
# Out:
# HeteroData(
#   (city, cityadj, city)=[2, 8445],
#   spot={
#     train_mask=[42852],
#     valid_mask=[42852],
#     test_mask=[42852],
#     y=[42852],
#     x=[42852, 512]
#   },
#   word={ x=[68340, 600] },
#   category={ x=[290, 290] },
#   city={
#     x=[1709, 12],
#     y=[1709],
#     train_mask=[1709],
#     valid_mask=[1709],
#     test_mask=[1709]
#   },
#   pref={
#     x=[47, 32],
#     y=[47],
#     train_mask=[47],
#     valid_mask=[47],
#     test_mask=[47]
#   },
#   user={
#     x=[28251, 128],
#     user_pos=[2146716],
#     user_neg=[2146716],
#     item_pos=[2146716],
#     item_neg=[2146716]
#   },
#   (spot, relate, word)={ edge_index=[2, 642780] },
#   (word, revrelate, spot)={ edge_index=[2, 642780] },
#   (spot, has, category)={ edge_index=[2, 94658] },
#   (category, revhas, spot)={ edge_index=[2, 94658] },
#   (spot, belongs, city)={ edge_index=[2, 42852] },
#   (city, revbelong, spot)={ edge_index=[2, 42852] },
#   (pref, prefadj, pref)={ edge_index=[2, 172] },
#   (city, belong, pref)={ edge_index=[2, 1991] },
#   (pref, rebelong, city)={ edge_index=[2, 1991] },
#   (user, visit, spot)={ edge_index=[2, 2146716] },
#   (spot, revvisit, user)={ edge_index=[2, 2146716] }
# )

# %%
a = [torch.rand(2,3), torch.rand(2,3), torch.rand(2,3)]
print(a)
torch.stack(a, dim=1).size()
torch.mean(torch.stack(a, dim=1), dim=1)
# Out:
# [tensor([[0.2804, 0.7629, 0.5385],
#         [0.6592, 0.8089, 0.4567]]), tensor([[0.6985, 0.2272, 0.7313],
#         [0.3959, 0.5283, 0.0289]]), tensor([[0.4874, 0.2388, 0.7617],
#         [0.7477, 0.3847, 0.7999]])]
# tensor([[0.4888, 0.4096, 0.6771],
#         [0.6009, 0.5740, 0.4285]])

# %%
df = pd.read_csv('/home/yamanishi/project/trip_recommend/model/recommendation/result/result.csv')
df.head()
# Out:
#     recall  accuracy  best_epoch model_type  num_layers     lr  \
# 0  0.00172    0.0021           0        hgt           5  0.002
#
#    hidden_channels  concat  loss_city_weight  loss_category_weight  \
# 0               64   False                 0                     0
#
#    city_pop_weight  spot_pop_weight  data_word  data_category  data_city  \
# 0                0                0       True           True       True
#
#    data_prefecture  Unnamed: 16
# 0             True     -0.74926

# %%
torch.cat(a, dim=1).size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1593218/408217136.py in <module>
# ----> 1 torch.cat(a, dim=1).size()
#
# NameError: name 'a' is not defined

# %%
from torch_geometric.nn.conv import HANConv, HGTConv
conv = HANConv(in_channels=-1, out_channels=128, metadata=data.metadata())
conv = HGTConv(in_channels=-1, out_channels=128, metadata=data.metadata(), heads=4, group='mean')

# %%
device = 'cuda:0'
data.to(device)
conv.to(device)
conv(data.x_dict, data.edge_index_dict)
# Out:
# {'spot': tensor([[-0.0288, -0.0596,  0.0634,  ...,  0.0194,  0.0320,  0.0303],
#          [-0.0655, -0.0652,  0.0009,  ...,  0.0245,  0.0261,  0.0752],
#          [ 0.0032, -0.0506,  0.0455,  ..., -0.0364, -0.0711,  0.0404],
#          ...,
#          [-0.0679, -0.0551,  0.0629,  ..., -0.0462,  0.0336,  0.0534],
#          [-0.0356, -0.0256,  0.0379,  ..., -0.0378,  0.0169,  0.0432],
#          [-0.0527, -0.0557,  0.0059,  ..., -0.0278,  0.0228, -0.0088]],
#         device='cuda:0', grad_fn=<AddmmBackward0>),
#  'word': tensor([[-1.9727e-01,  9.5084e-04, -3.6135e-03,  ...,  8.4128e-03,
#            1.4423e-01,  1.6481e-01],
#          [-4.8239e-01,  3.6992e-01, -1.3637e-01,  ..., -4.3266e-01,
#            5.1114e-01,  4.1980e-01],
#          [-6.1266e-02,  2.3281e-01,  2.4414e-01,  ..., -1.4070e-01,
#            2.7913e-01,  2.4021e-01],
#          ...,
#          [-1.5504e-01,  1.2582e-01,  3.5365e-02,  ...,  3.5207e-02,
#            1.3466e-01,  9.7789e-02],
#          [-3.3779e-01,  1.4885e-01,  3.5253e-04,  ..., -1.0494e-01,
#            2.4108e-01,  2.9037e-01],
#          [-3.7264e-01, -6.7972e-02, -1.1386e-01,  ..., -2.3530e-02,
#            1.6451e-01,  1.6476e-01]], device='cuda:0', grad_fn=<AddmmBackward0>),
#  'category': tensor([[ 0.0495, -0.1097, -0.1559,  ..., -0.0381, -0.0797, -0.0710],
#          [ 0.0613, -0.0997, -0.1573,  ..., -0.0401, -0.0685, -0.0766],
#          [ 0.0392, -0.1532, -0.2028,  ..., -0.0118, -0.1524, -0.0801],
#          ...,
#          [ 0.0352, -0.1832, -0.2957,  ...,  0.0090, -0.2266, -0.0007],
#          [-0.0070,  0.1019, -0.1172,  ..., -0.0292,  0.1018, -0.0442],
#          [-0.0140, -0.1229, -0.2420,  ..., -0.0004, -0.2959, -0.1905]],
#         device='cuda:0', grad_fn=<AddmmBackward0>),
#  'city': tensor([[ 0.0328,  0.0161, -0.1453,  ..., -0.5576, -0.3054,  0.4657],
#          [ 0.0328,  0.0213, -0.1397,  ..., -0.5694, -0.3263,  0.4651],
#          [ 0.0278,  0.0093, -0.1386,  ..., -0.5517, -0.3001,  0.4496],
#          ...,
#          [-0.1347,  0.0478, -0.1412,  ...,  0.1227, -0.0351, -0.0502],
#          [-0.1336,  0.0523, -0.0978,  ...,  0.1348, -0.0130, -0.0577],
#          [-0.1355,  0.0762, -0.1026,  ...,  0.1237, -0.0133, -0.0774]],
#         device='cuda:0', grad_fn=<AddmmBackward0>),
#  'pref': tensor([[ 0.0073,  0.0769,  0.0995,  ...,  0.0829,  0.0330,  0.0058],
#          [ 0.0210,  0.1089,  0.1303,  ...,  0.1562,  0.0681,  0.0079],
#          [ 0.0220,  0.1446,  0.1093,  ...,  0.1671,  0.0713, -0.0088],
#          ...,
#          [-0.0135,  0.0994,  0.1389,  ...,  0.0695,  0.0071,  0.0364],
#          [-0.0132,  0.0895,  0.1351,  ...,  0.0763, -0.0041,  0.0263],
#          [ 0.0073,  0.0769,  0.0995,  ...,  0.0829,  0.0330,  0.0058]],
#         device='cuda:0', grad_fn=<AddmmBackward0>),
#  'user': tensor([[ 0.3736,  0.2245,  0.2194,  ...,  0.0921,  0.0496,  0.2695],
#          [ 0.2076,  0.2346,  0.4196,  ..., -0.1019,  0.2494,  0.1900],
#          [ 0.3117,  0.2745,  0.2168,  ..., -0.0075,  0.2386,  0.1758],
#          ...,
#          [ 0.1663,  0.0923,  0.2790,  ...,  0.1148,  0.2970,  0.1021],
#          [ 0.2276,  0.0389,  0.4117,  ...,  0.0136,  0.1172,  0.2376],
#          [ 0.0577,  0.1364,  0.1584,  ...,  0.0273,  0.2344,  0.2192]],
#         device='cuda:0', grad_fn=<AddBackward0>)}

# %%
str(True)
# Out:
# 'True'

# %%
data
# Out:
# HeteroData(
#   spot={
#     train_mask=[42852],
#     valid_mask=[42852],
#     test_mask=[42852],
#     y=[42852],
#     x=[42852, 512]
#   },
#   word={ x=[68340, 600] },
#   user={
#     x=[28251, 128],
#     user_pos=[2146716],
#     user_neg=[2146716],
#     item_pos=[2146716],
#     item_neg=[2146716]
#   },
#   (spot, relate, word)={ edge_index=[2, 642780] },
#   (word, revrelate, spot)={ edge_index=[2, 642780] },
#   (user, visit, spot)={ edge_index=[2, 2146716] },
#   (spot, revvisit, user)={ edge_index=[2, 2146716] }
# )

# %%
from torch_geometric.nn import HeteroLinear
linear = HeteroLinear(-1, 128, len(data.x_dict.keys()))
linear(data.x_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1404893/2198845325.py in <module>
#       1 from torch_geometric.nn import HeteroLinear
#       2 linear = HeteroLinear(-1, 128, len(data.x_dict.keys()))
# ----> 3 linear(data.x_dict)
#
# ~/.pyenv/versions/miniconda3-latest/envs/study_group/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: forward() missing 1 required positional argument: 'type_vec'

# %%
import torch.nn as nn
encoder_layer = nn.TransformerEncoderLayer(d_model=512, nhead=8)
transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=6)
src = torch.rand(10, 32, 512)
out = transformer_encoder(src)

# %%
transformer_encoder(torch.rand(500,5,512))
# Out:
# tensor([[[ 1.6938, -0.4604,  1.3951,  ..., -0.4941, -0.1565,  0.1207],
#          [-0.3422, -0.8063,  1.7492,  ..., -1.3343,  0.0558, -0.4790],
#          [-0.4813, -0.8356,  1.6242,  ..., -1.1597, -0.1464,  0.4727],
#          [-1.4184, -0.7773,  1.1830,  ..., -0.4891, -0.2813,  0.2164],
#          [ 0.0397, -1.0320,  2.3576,  ..., -0.6497, -0.9610, -0.2784]],
#
#         [[ 0.4420, -0.3877,  1.7163,  ..., -0.1106, -0.7346,  0.9244],
#          [-0.1781, -0.4102,  1.5294,  ...,  0.1275,  0.0566,  0.1262],
#          [-0.6370,  0.1568,  1.3207,  ..., -0.6263,  0.0112,  0.0030],
#          [-0.0536, -0.5924,  0.6969,  ...,  0.0097,  0.2753,  0.1213],
#          [ 0.1633, -0.7276,  0.8970,  ..., -1.2248,  0.3632,  0.3481]],
#
#         [[ 0.3711, -1.0998,  0.9549,  ..., -1.2546, -0.4199, -0.5805],
#          [-0.1377, -0.2571,  2.1186,  ..., -1.5979,  0.2015,  0.6335],
#          [-0.5531, -0.0821,  1.8383,  ..., -0.7377, -0.6298, -0.5093],
#          [-0.7340, -0.2288,  1.8524,  ..., -1.0687,  0.0162, -0.3630],
#          [ 0.7371, -0.9965,  1.9730,  ..., -1.2137, -0.0316,  0.0717]],
#
#         ...,
#
#         [[-0.4870,  0.0138,  2.1676,  ..., -0.2814, -0.6144,  0.2921],
#          [ 0.1980, -0.0733,  1.8731,  ..., -1.0945,  0.1359, -0.4555],
#          [-0.7795, -0.9379,  1.2111,  ..., -0.1065, -0.2139, -0.3499],
#          [-0.3763, -0.8503,  1.8444,  ..., -1.0195, -0.2007,  0.7681],
#          [-0.2902, -0.8631,  1.4756,  ..., -0.6824,  0.4965,  0.0477]],
#
#         [[ 1.0050, -1.7037,  1.3315,  ..., -1.1765, -0.3682,  0.2243],
#          [ 0.6261, -0.5859,  1.4916,  ..., -0.1692,  0.0391,  0.3627],
#          [ 0.2630, -1.2344,  1.4022,  ...,  0.0544, -0.1731,  0.2316],
#          [-0.1656, -0.7900,  1.3989,  ...,  0.1352,  0.2122, -0.3346],
#          [-1.0832, -1.0494,  0.7050,  ..., -0.7774, -0.9132, -0.3734]],
#
#         [[ 0.2282, -0.0589,  2.0781,  ...,  0.0991, -0.2499,  0.3366],
#          [-0.5337,  0.3532,  0.7976,  ..., -1.2043,  0.7101, -0.1559],
#          [-0.8075, -0.3104,  1.9782,  ..., -1.4204, -0.2532,  0.2996],
#          [-0.2494, -0.2972,  1.2792,  ..., -0.5165,  0.0572,  0.0180],
#          [-0.2853,  0.2441,  1.5665,  ..., -0.2167,  0.0788,  0.1864]]],
#        grad_fn=<NativeLayerNormBackward0>)

# %%
import os
 
isempty = os.stat('/home/yamanishi/project/trip_recommend/model/recommendation/result.csv').st_size == 0
print(isempty)
# Out:
# True

# %%
a = 0.224151533535
round(a,5)
# Out:
# 0.22415

# %%
a=np.array(['a','b','c'])
with open('log.txt', 'w') as f:
    f.write('train','max', a.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1678411/3764139079.py in <module>
#       1 a='いなり'
#       2 with open('log.txt', 'w') as f:
# ----> 3     f.write('train','max', a)
#
# TypeError: write() takes exactly one argument (3 given)

# %%
import torch.nn as nn
gru = nn.GRUCell(128,128)

# %%
gru(torch.rand(512,128), torch.rand(512,128)).shape
# Out:
# torch.Size([512, 128])

# %%
a = torch.rand(3,2)
print(a)
print(a.norm(2))
a.norm(2).pow(2)
# Out:
# tensor([[0.0282, 0.8086],
#         [0.4328, 0.8383],
#         [0.5413, 0.9000]])
# tensor(1.6272)
# tensor(2.6476)

# %%
import os
jalan_dir = '/home/yamanishi/project/trip_recommend/data/jalan/graph'
spot_x = torch.from_numpy(np.load('/home/yamanishi/project/trip_recommend/data/jalan/graph/spot_img_emb_multi_ResNet.npy'))

# %%
spot_x = torch.mean(spot_x.reshape(-1, 5, 512), dim=1)

# %%
spot_x.shape
# Out:
# torch.Size([42852, 512])

# %%
torch.mean(spot_x)
# Out:
# tensor(0.7121)

# %%
spot_x[0]
# Out:
#         0.3168, 0.0830, 0.1732, 1.4999, 0.9242, 0.1878, 2.5052, 0.4909, 0.5692,
#         0.1358, 0.7856, 0.6913, 0.9858, 0.1073, 1.6467, 2.1078, 0.2059])

# %%
a = torch.rand(5,3)
torch.nn.init.normal_(a,0, 0.1)
a
# Out:
# tensor([[ 0.0856, -0.0886,  0.1073],
#         [ 0.0795,  0.0068,  0.0853],
#         [-0.1042, -0.0900, -0.0025],
#         [-0.0044,  0.1520,  0.0773],
#         [ 0.0649,  0.0260,  0.0695]])

# %%
df = pd.read_csv('/home/yamanishi/project/trip_recommend/model/popularity/result/result.csv', names=['cor', 'best_epoch', 'model_type', 'num_layers','lr','hidden_channels', 'concat', 
                        'city_pop_weight','data_word' , 'data_category', 'data_city', 'data_pref'])

# %%
df.head()
# Out:
#        cor  best_epoch model_type  num_layers      lr  hidden_channels  \
# 0  0.79733         339       ggnn           4  0.0001              320
# 1  0.76015         649       sage           2  0.0001              128
# 2  0.80031         359       ggnn           4  0.0001              320
# 3  0.78286         319       ggnn           2  0.0001              128
# 4  0.78397         569     ggnnv2           2  0.0001              128
#
#    concat  city_pop_weight  data_word  data_category  data_city  data_pref
# 0   False                0       True           True       True       True
# 1   False                0       True           True       True       True
# 2   False                0       True           True       True       True
# 3   False                0       True           True       True       True
# 4   False                0       True           True       True       True

# %%
df[df['model_type']=='hgt']
# Out:
#         cor  best_epoch model_type  num_layers      lr  hidden_channels  \
# 6   0.76224         299        hgt           2  0.0001              128
# 13  0.77095         209        hgt           2  0.0001              256
# 20  0.75981         189        hgt           2  0.0001              384
# 28  0.76689         259        hgt           3  0.0001              128
# 35  0.76390         259        hgt           3  0.0001              256
# 43  0.77383         199        hgt           3  0.0001              384
# 50  0.76744         329        hgt           4  0.0001              128
# 57  0.77089         259        hgt           4  0.0001              256
# 65  0.76994         179        hgt           4  0.0001              384
# 72  0.76266         339        hgt           5  0.0001              128
# 78  0.77399         279        hgt           5  0.0001              256
#
#     concat  city_pop_weight  data_word  data_category  data_city  data_pref
# 6    False                0       True           True       True       True
# 13   False                0       True           True       True       True
# 20   False                0       True           True       True       True
# 28   False                0       True           True       True       True
# 35   False                0       True           True       True       True
# 43   False                0       True           True       True       True
# 50   False                0       True           True       True       True
# 57   False                0       True           True       True       True
# 65   False                0       True           True       True       True
# 72   False                0       True           True       True       True
# 78   False                0       True           True       True       True

# %%
df[df['model_type']=='sage']
# Out:
#         cor  best_epoch model_type  num_layers      lr  hidden_channels  \
# 1   0.76015         649       sage           2  0.0001              128
# 9   0.74957         349       sage           2  0.0001              256
# 16  0.75552         359       sage           2  0.0001              384
# 25  0.77734         659       sage           3  0.0001              128
# 32  0.77156         349       sage           3  0.0001              256
# 38  0.77036         359       sage           3  0.0001              384
# 47  0.77505         539       sage           4  0.0001              128
# 53  0.78030         329       sage           4  0.0001              256
# 60  0.78058         279       sage           4  0.0001              384
# 69  0.78649         609       sage           5  0.0001              128
# 75  0.78561         359       sage           5  0.0001              256
# 81  0.79016         309       sage           5  0.0001              384
#
#     concat  city_pop_weight  data_word  data_category  data_city  data_pref
# 1    False                0       True           True       True       True
# 9    False                0       True           True       True       True
# 16   False                0       True           True       True       True
# 25   False                0       True           True       True       True
# 32   False                0       True           True       True       True
# 38   False                0       True           True       True       True
# 47   False                0       True           True       True       True
# 53   False                0       True           True       True       True
# 60   False                0       True           True       True       True
# 69   False                0       True           True       True       True
# 75   False                0       True           True       True       True
# 81   False                0       True           True       True       True

# %%
df[df['model_type']=='ggnn']
# Out:
#         cor  best_epoch model_type  num_layers      lr  hidden_channels  \
# 0   0.79733         339       ggnn           4  0.0001              320
# 2   0.80031         359       ggnn           4  0.0001              320
# 3   0.78286         319       ggnn           2  0.0001              128
# 11  0.78498         279       ggnn           2  0.0001              256
# 19  0.79322         229       ggnn           2  0.0001              384
# 26  0.78873         479       ggnn           3  0.0001              128
# 33  0.78993         309       ggnn           3  0.0001              256
# 40  0.79776         249       ggnn           3  0.0001              384
# 48  0.79622         659       ggnn           4  0.0001              128
# 55  0.79327         359       ggnn           4  0.0001              256
# 61  0.80076         289       ggnn           4  0.0001              384
# 71  0.79438         669       ggnn           5  0.0001              128
# 76  0.80337         509       ggnn           5  0.0001              256
# 83  0.80010         459       ggnn           5  0.0001              384
#
#     concat  city_pop_weight  data_word  data_category  data_city  data_pref
# 0    False                0       True           True       True       True
# 2    False                0       True           True       True       True
# 3    False                0       True           True       True       True
# 11   False                0       True           True       True       True
# 19   False                0       True           True       True       True
# 26   False                0       True           True       True       True
# 33   False                0       True           True       True       True
# 40   False                0       True           True       True       True
# 48   False                0       True           True       True       True
# 55   False                0       True           True       True       True
# 61   False                0       True           True       True       True
# 71   False                0       True           True       True       True
# 76   False                0       True           True       True       True
# 83   False                0       True           True       True       True

# %%
df[df['model_type']=='ggnnv4']
# Out:
#         cor  best_epoch model_type  num_layers      lr  hidden_channels  \
# 8   0.79070         499     ggnnv4           2  0.0001              128
# 14  0.79130         299     ggnnv4           2  0.0001              256
# 21  0.79566         259     ggnnv4           2  0.0001              384
# 27  0.79074         649     ggnnv4           3  0.0001              128
# 34  0.79759         529     ggnnv4           3  0.0001              256
# 41  0.80158         379     ggnnv4           3  0.0001              384
# 45  0.79629         699     ggnnv4           4  0.0001              128
# 54  0.80972         679     ggnnv4           4  0.0001              256
# 62  0.81213         649     ggnnv4           4  0.0001              384
# 66  0.74803         699     ggnnv4           5  0.0001              128
# 74  0.79768         689     ggnnv4           5  0.0001              256
# 82  0.79879         549     ggnnv4           5  0.0001              384
#
#     concat  city_pop_weight  data_word  data_category  data_city  data_pref
# 8    False                0       True           True       True       True
# 14   False                0       True           True       True       True
# 21   False                0       True           True       True       True
# 27   False                0       True           True       True       True
# 34   False                0       True           True       True       True
# 41   False                0       True           True       True       True
# 45   False                0       True           True       True       True
# 54   False                0       True           True       True       True
# 62   False                0       True           True       True       True
# 66   False                0       True           True       True       True
# 74   False                0       True           True       True       True
# 82   False                0       True           True       True       True

# %%
df[df['model_type']==]
